# %%
from nltk.corpus import twitter_samples
import nltk
from nltk.tag import pos_tag
from nltk.stem.wordnet import WordNetLemmatizer

# %%
positive_tweets = twitter_samples.strings('positive_tweets.json')
negative_tweets = twitter_samples.strings('negative_tweets.json')
text = twitter_samples.strings('tweets.20150430-223406.json')

# %%
type(twitter_samples)
# Out:
# nltk.corpus.reader.twitter.TwitterCorpusReader

# %%
tweet_tokens = twitter_samples.tokenized('positive_tweets.json')

# %%
tweet_tokens
# Out:
# [['#FollowFriday',
#   '@France_Inte',
#   '@PKuchly57',
#   '@Milipol_Paris',
#   'for',
#   'being',
#   'top',
#   'engaged',
#   'members',
#   'in',
#   'my',
#   'community',
#   'this',
#   'week',
#   ':)'],
#  ['@Lamb2ja',
#   'Hey',
#   'James',
#   '!',
#   'How',
#   'odd',
#   ':/',
#   'Please',
#   'call',
#   'our',
#   'Contact',
#   'Centre',
#   'on',
#   '02392441234',
#   'and',
#   'we',
#   'will',
#   'be',
#   'able',
#   'to',
#   'assist',
#   'you',
#   ':)',
#   'Many',
#   'thanks',
#   '!'],
#  ['@DespiteOfficial',
#   'we',
#   'had',
#   'a',
#   'listen',
#   'last',
#   'night',
#   ':)',
#   'As',
#   'You',
#   'Bleed',
#   'is',
#   'an',
#   'amazing',
#   'track',
#   '.',
#   'When',
#   'are',
#   'you',
#   'in',
#   'Scotland',
#   '?',
#   '!'],
#  ['@97sides', 'CONGRATS', ':)'],
#  ['yeaaaah',
#   'yippppy',
#   '!',
#   '!',
#   '!',
#   'my',
#   'accnt',
#   'verified',
#   'rqst',
#   'has',
#   'succeed',
#   'got',
#   'a',
#   'blue',
#   'tick',
#   'mark',
#   'on',
#   'my',
#   'fb',
#   'profile',
#   ':)',
#   'in',
#   '15',
#   'days'],
#  ['@BhaktisBanter',
#   '@PallaviRuhail',
#   'This',
#   'one',
#   'is',
#   'irresistible',
#   ':)',
#   '#FlipkartFashionFriday',
#   'http://t.co/EbZ0L2VENM'],
#  ['We',
#   "don't",
#   'like',
#   'to',
#   'keep',
#   'our',
#   'lovely',
#   'customers',
#   'waiting',
#   'for',
#   'long',
#   '!',
#   'We',
#   'hope',
#   'you',
#   'enjoy',
#   '!',
#   'Happy',
#   'Friday',
#   '!',
#   '-',
#   'LWWF',
#   ':)',
#   'https://t.co/smyYriipxI'],
#  ['@Impatientraider',
#   'On',
#   'second',
#   'thought',
#   ',',
#   'there',
#   '’',
#   's',
#   'just',
#   'not',
#   'enough',
#   'time',
#   'for',
#   'a',
#   'DD',
#   ':)',
#   'But',
#   'new',
#   'shorts',
#   'entering',
#   'system',
#   '.',
#   'Sheep',
#   'must',
#   'be',
#   'buying',
#   '.'],
#  ['Jgh', ',', 'but', 'we', 'have', 'to', 'go', 'to', 'Bayan', ':D', 'bye'],
#  ['As',
#   'an',
#   'act',
#   'of',
#   'mischievousness',
#   ',',
#   'am',
#   'calling',
#   'the',
#   'ETL',
#   'layer',
#   'of',
#   'our',
#   'in-house',
#   'warehousing',
#   'app',
#   'Katamari',
#   '.',
#   'Well',
#   '…',
#   'as',
#   'the',
#   'name',
#   'implies',
#   ':p',
#   '.'],
#  ['#FollowFriday',
#   '@wncer1',
#   '@Defense_gouv',
#   'for',
#   'being',
#   'top',
#   'influencers',
#   'in',
#   'my',
#   'community',
#   'this',
#   'week',
#   ':)'],
#  ['Who',
#   "Wouldn't",
#   'Love',
#   'These',
#   'Big',
#   '...',
#   'Juicy',
#   '...',
#   'Selfies',
#   ':)',
#   '-',
#   'http://t.co/QVzjgd1uFo',
#   'http://t.co/oWBL11eQRY'],
#  ['@Mish23615351',
#   'follow',
#   '@jnlazts',
#   '&',
#   'http://t.co/RCvcYYO0Iq',
#   'follow',
#   'u',
#   'back',
#   ':)'],
#  ['@jjulieredburn',
#   'Perfect',
#   ',',
#   'so',
#   'you',
#   'already',
#   'know',
#   "what's",
#   'waiting',
#   'for',
#   'you',
#   ':)'],
#  ['Great',
#   'new',
#   'opportunity',
#   'for',
#   'junior',
#   'triathletes',
#   'aged',
#   '12',
#   'and',
#   '13',
#   'at',
#   'the',
#   'Gatorade',
#   'series',
#   '!',
#   'Get',
#   'your',
#   'entries',
#   'in',
#   ':)',
#   'http://t.co/of3DyOzML0'],
#  ['Laying',
#   'out',
#   'a',
#   'greetings',
#   'card',
#   'range',
#   'for',
#   'print',
#   'today',
#   '-',
#   'love',
#   'my',
#   'job',
#   ':-)'],
#  ["Friend's",
#   'lunch',
#   '...',
#   'yummmm',
#   ':)',
#   '#Nostalgia',
#   '#TBS',
#   '#KU',
#   '.'],
#  ['@RookieSenpai',
#   '@arcadester',
#   'it',
#   'is',
#   'the',
#   'id',
#   'conflict',
#   'thanks',
#   'for',
#   'the',
#   'help',
#   ':D',
#   "here's",
#   'the',
#   'screenshot',
#   'of',
#   'it',
#   'working'],
#  ['@oohdawg_', 'Hi', 'liv', ':)', ')'],
#  ['Hello',
#   'I',
#   'need',
#   'to',
#   'know',
#   'something',
#   'can',
#   'u',
#   'fm',
#   'me',
#   'on',
#   'Twitter',
#   '?',
#   '?',
#   '—',
#   'sure',
#   'thing',
#   ':)',
#   'dm',
#   'me',
#   'x',
#   'http://t.co/W6Dy130BV7'],
#  ['#FollowFriday',
#   '@MBandScott_',
#   '@Eric_FLE',
#   '@pointsolutions3',
#   'for',
#   'being',
#   'top',
#   'new',
#   'followers',
#   'in',
#   'my',
#   'community',
#   'this',
#   'week',
#   ':)'],
#  ['@rossbreadmore',
#   "I've",
#   'heard',
#   'the',
#   'Four',
#   'Seasons',
#   'is',
#   'pretty',
#   'dope',
#   '.',
#   'Penthouse',
#   ',',
#   'obvs',
#   '#Gobigorgohome',
#   'Have',
#   'fun',
#   "y'all",
#   ':)'],
#  ['@gculloty87',
#   'Yeah',
#   'I',
#   'suppose',
#   'she',
#   'was',
#   'lol',
#   '!',
#   'Chat',
#   'in',
#   'a',
#   'bit',
#   'just',
#   'off',
#   'out',
#   'x',
#   ':)',
#   ')'],
#  ['Hello',
#   ':)',
#   'Get',
#   'Youth',
#   'Job',
#   'Opportunities',
#   'follow',
#   '>',
#   '>',
#   '@tolajobjobs',
#   '@maphisa301'],
#  ['💅🏽', '💋', '-', ':)', ')', ')', "haven't", 'seen', 'you', 'in', 'years'],
#  ['@Bosslogic',
#   '@amellywood',
#   '@CW_Arrow',
#   '@ARROWwriters',
#   'Thank',
#   'you',
#   '!',
#   ':-)'],
#  ['@johngutierrez1',
#   'hope',
#   'the',
#   'rest',
#   'of',
#   'your',
#   'night',
#   'goes',
#   'by',
#   'quickly',
#   '...',
#   'I',
#   'am',
#   'off',
#   'to',
#   'bed',
#   '...',
#   'got',
#   'my',
#   'music',
#   'fix',
#   'and',
#   'now',
#   'it',
#   'is',
#   'time',
#   'to',
#   'dream',
#   ':)'],
#  ['Spiritual',
#   'Ritual',
#   'Festival',
#   '(',
#   'Népal',
#   ')',
#   'Beginning',
#   'of',
#   'Line-up',
#   ':)',
#   'It',
#   'is',
#   'left',
#   'for',
#   'the',
#   'line-up',
#   '(',
#   'y',
#   ')',
#   'See',
#   'more',
#   'at',
#   ':',
#   '...',
#   'http://t.co/QMNz62OEuc'],
#  ['@ke7zum',
#   'Hey',
#   'Sarah',
#   '!',
#   'Send',
#   'us',
#   'an',
#   'email',
#   'at',
#   'bitsy@bitdefender.com',
#   'and',
#   "we'll",
#   'help',
#   'you',
#   'asap',
#   ':)'],
#  ['@izzkamilhalda', 'lols', '.', ':D'],
#  ['MY',
#   'kik',
#   '-',
#   'hatessuce',
#   '32429',
#   '#kik',
#   '#kikme',
#   '#lgbt',
#   '#tinder',
#   '#nsfw',
#   '#akua',
#   '#cumshot',
#   ':)',
#   'http://t.co/TnHJD36yzf'],
#  ['@KalinWhite', 'come', 'to', 'my', 'house', ':)', ')', ')'],
#  ['#nsn_supplements',
#   ',',
#   'Effective',
#   'press',
#   'release',
#   'distribution',
#   'with',
#   'results',
#   '!',
#   ':)',
#   '[',
#   'link',
#   'removed',
#   ']',
#   '#PressRelease',
#   '#NewsDistribution'],
#  ['Hi',
#   'BAM',
#   '!',
#   '@BarsAndMelody',
#   'Can',
#   'you',
#   'follow',
#   'my',
#   'bestfriend',
#   '@969Horan696',
#   '?',
#   'She',
#   'loves',
#   'you',
#   'a',
#   'lot',
#   ':)',
#   'See',
#   'you',
#   'in',
#   'Warsaw',
#   '<3',
#   'Love',
#   'you',
#   '<3',
#   'x46'],
#  ['everyone',
#   'watch',
#   'the',
#   'documentary',
#   'Earthlings',
#   'on',
#   'YouTube',
#   ':-)'],
#  ['@jamiefigsxx',
#   'follow',
#   '@jnlazts',
#   '&',
#   'http://t.co/RCvcYYO0Iq',
#   'follow',
#   'u',
#   'back',
#   ':)'],
#  ['#FollowFriday',
#   '@MichelBauza',
#   '@InvataOnline',
#   'for',
#   'being',
#   'top',
#   'supports',
#   'in',
#   'my',
#   'community',
#   'this',
#   'week',
#   ':)'],
#  ['buuuuuuuut', 'oh', 'well', ':-)'],
#  ['@leisuremarkltd',
#   '@NoshandQuaff',
#   '@aktarislam',
#   '@keanebrands',
#   '@HeritageSilver',
#   'I',
#   'am',
#   'looking',
#   'forward',
#   'to',
#   'visiting',
#   'next',
#   'week',
#   '#letsgetmessy',
#   'Jo',
#   ':-)'],
#  ['@sehunshinedaily',
#   'if',
#   'it',
#   'makes',
#   'u',
#   'feel',
#   'better',
#   'i',
#   'never',
#   'have',
#   'nor',
#   'will',
#   'see',
#   'anyone',
#   'in',
#   'kpop',
#   'in',
#   'the',
#   'flesh',
#   ':D'],
#  ['@Joyster2012',
#   '@CathStaincliffe',
#   'Good',
#   'for',
#   'you',
#   ',',
#   'girl',
#   '!',
#   '!',
#   'Best',
#   'wishes',
#   ':-)'],
#  ['@_Kimimi',
#   'A',
#   'great',
#   'enough',
#   'reason',
#   'to',
#   'listen',
#   'to',
#   'one',
#   'epic',
#   'soundtrack',
#   '.',
#   ':D'],
#  ['@AquaDesignGroup',
#   'Thank',
#   'you',
#   'for',
#   'the',
#   'shout',
#   'out',
#   '.',
#   'Have',
#   'a',
#   'great',
#   'Friday',
#   ':)'],
#  ['I',
#   'added',
#   'a',
#   'video',
#   'to',
#   'a',
#   '@YouTube',
#   'playlist',
#   'http://t.co/yzpfsMxUq0',
#   'im',
#   'back',
#   'on',
#   'twitch',
#   'and',
#   'today',
#   'it',
#   'going',
#   'to',
#   'be',
#   'league',
#   ':)',
#   '-',
#   '1',
#   '/',
#   '4'],
#  ['Would',
#   'love',
#   'to',
#   'see',
#   'you',
#   'dear',
#   'in',
#   '#Jordan',
#   ':)',
#   'waiting',
#   'you',
#   '!',
#   '@FIRDOZ',
#   ':)',
#   '@VisitJordan',
#   '@dannyprol'],
#  ['@ABNORMAL_ANA92', 'oh', ',', 'okay', ':D', 'thanks', '!'],
#  ['@sssniperwolf',
#   'like',
#   'how',
#   'to',
#   'fake',
#   'gameplays',
#   ';)',
#   'haha',
#   'Im',
#   'kidding',
#   ',',
#   'im',
#   'kidding',
#   '.',
#   'You',
#   'do',
#   'good',
#   'stuff',
#   ':)',
#   '.'],
#  ['@dennislami', '@Dicle_Aygur', ',', 'yeah', 'exactly', ':)'],
#  ['Our',
#   'new',
#   'product',
#   'line',
#   'is',
#   'in',
#   'our',
#   '#etsy',
#   'shop',
#   'now',
#   '!',
#   'Check',
#   'it',
#   'out',
#   ':)',
#   'http://t.co/h8exCTLQxg',
#   '#boxroomcrafts'],
#  ['@PeakYourMind',
#   'I',
#   'hope',
#   'your',
#   'vacation',
#   'is',
#   'going',
#   'great',
#   '!',
#   ':D'],
#  ['@groovinshawn',
#   'they',
#   'are',
#   'rechargeable',
#   'and',
#   'it',
#   'normally',
#   'comes',
#   'with',
#   'a',
#   'charger',
#   'when',
#   'u',
#   'buy',
#   'it',
#   ':)'],
#  ['#FollowFriday',
#   '@France_Espana',
#   '@reglisse_menthe',
#   '@CCI_inter',
#   'for',
#   'being',
#   'top',
#   'engaged',
#   'members',
#   'in',
#   'my',
#   'community',
#   'this',
#   'week',
#   ':)'],
#  ['Well',
#   "she's",
#   'asleep',
#   'and',
#   'I',
#   'have',
#   'no',
#   'one',
#   'to',
#   'talk',
#   'to',
#   'sooo',
#   'someone',
#   'text',
#   'me',
#   ':)'],
#  ['@brynybrath',
#   '@smallcappy',
#   'Yes',
#   ',',
#   'I',
#   'suppose',
#   '.',
#   'I',
#   'bet',
#   "he'll",
#   'have',
#   'a',
#   'blue',
#   'fit',
#   'after',
#   'hearing',
#   'her',
#   'speech',
#   'today',
#   '.',
#   'Pity',
#   ':-)'],
#  ['Green',
#   'gardens',
#   ',',
#   'midnight',
#   'sun',
#   ',',
#   'beautiful',
#   'canals',
#   'dasvidaniya',
#   'till',
#   'next',
#   'visit',
#   '.',
#   ':)'],
#  ['@KeithRParsons',
#   'are',
#   'you',
#   'scouting',
#   'SG',
#   'for',
#   'a',
#   'future',
#   'WLAN',
#   'pros',
#   'conference',
#   'here',
#   'in',
#   'Asia',
#   '?',
#   ':)'],
#  ['@Cecilie_Hell',
#   '@420evilangel',
#   '@wazimotometal',
#   '@durooooooo',
#   '@spigranty',
#   'Good',
#   'for',
#   'u',
#   ',',
#   'better',
#   'change',
#   'it',
#   'to',
#   'lollipop',
#   '🍭',
#   ':)',
#   '.'],
#  ['We', '<3', 'u', 'Nez', ':)', '#AGNEZMO', 'https://t.co/cGViMHSINz'],
#  ['@LittleMix',
#   'Follow',
#   'me',
#   'Please',
#   ':)',
#   'This',
#   'is',
#   'my',
#   'Big',
#   'Dream',
#   ':)'],
#  ['@Elemaaan', 'oley', 'be', ':D'],
#  ['"',
#   '@CowokAddict',
#   ':',
#   'Mama',
#   'is',
#   'the',
#   'only',
#   'reason',
#   'why',
#   'I',
#   'stand',
#   'stronger',
#   'up',
#   'to',
#   'now',
#   '!',
#   ':)',
#   '"'],
#  ['@MacatangayApril',
#   'follow',
#   '@jnlazts',
#   '&',
#   'http://t.co/RCvcYYO0Iq',
#   'follow',
#   'u',
#   'back',
#   ':)'],
#  ['@tk_kjk_kndr',
#   '@boukendreamer',
#   'OH',
#   'MY',
#   'GOD',
#   'MISTY',
#   ',',
#   'MY',
#   'BABY',
#   'IS',
#   'SO',
#   'CUTE',
#   '!',
#   '!',
#   '!',
#   ':D'],
#  ['@BhaktisBanter',
#   'I',
#   'love',
#   'blue',
#   ':)',
#   '#FlipkartFashionFriday',
#   'http://t.co/HnbinH35ES'],
#  ['@CarcassDrop',
#   'Woohoo',
#   '!',
#   "Can't",
#   'wait',
#   ':)',
#   'Have',
#   'you',
#   'signed',
#   'up',
#   'yet',
#   ',',
#   'or',
#   'still',
#   'thinking',
#   'about',
#   'it',
#   '?',
#   'MKa'],
#  ['i', 'have', 'liam', 'access', 'now', ':)', ')'],
#  ['@SyuhxdxTengku', 'most', 'welcome', ':)'],
#  ['Stats',
#   'for',
#   'the',
#   'day',
#   'have',
#   'arrived',
#   '.',
#   '1',
#   'new',
#   'follower',
#   'and',
#   'NO',
#   'unfollowers',
#   ':)',
#   'via',
#   'http://t.co/p6K6SiH58a',
#   '.'],
#  ['@sluttywife2',
#   'you',
#   "shouldn't",
#   'be',
#   'surprised',
#   '...',
#   'you',
#   'have',
#   'an',
#   'amazing',
#   'figure',
#   ':)'],
#  ['#FollowFriday',
#   '@murtishaw',
#   '@aqui_fr',
#   '@FRTechStartups',
#   'for',
#   'being',
#   'top',
#   'influencers',
#   'in',
#   'my',
#   'community',
#   'this',
#   'week',
#   ':)'],
#  ['#HappyBirthdayEmilyBett',
#   '@emilybett',
#   ':)',
#   'Wishing',
#   'you',
#   'all',
#   'the',
#   'best',
#   'you',
#   'beautiful',
#   ',',
#   'sweet',
#   ',',
#   'talented',
#   ',',
#   'amazing',
#   '…',
#   'https://t.co/humtC1tr3I'],
#  ['2',
#   'plans',
#   'for',
#   'the',
#   'day',
#   'down',
#   'the',
#   'drain',
#   'great',
#   ':)',
#   ':'],
#  ['@x123456789tine', '@5SOS_FAHUpdates', 'gotta', 'love', 'timezones', ':p'],
#  ['are',
#   'your',
#   'parents',
#   'proud',
#   'of',
#   'you',
#   '—',
#   'lol',
#   ',',
#   'not',
#   'in',
#   'the',
#   'least',
#   ':D',
#   'maybe',
#   'sometimes',
#   'they',
#   'get',
#   'happy',
#   'because',
#   'of',
#   'my',
#   'grades',
#   ',',
#   'al',
#   '...',
#   'http://t.co/bJjeGIOOGU'],
#  ['Grande', ':)', 'https://t.co/gsaaxNpR8u'],
#  ['Manila_bro',
#   'has',
#   'chosen',
#   'to',
#   'follow',
#   'me',
#   'on',
#   'Twitter',
#   '!',
#   'http://t.co/lKXZWXN1fb',
#   '.',
#   'Thanks',
#   'for',
#   'the',
#   'follow',
#   ':)'],
#  ['@syazwanzainal',
#   'sure',
#   'let',
#   'me',
#   'know',
#   'when',
#   "you're",
#   'around',
#   '..',
#   'at',
#   'this',
#   'side',
#   'of',
#   'the',
#   'world',
#   '#eh',
#   'u',
#   'too',
#   'take',
#   'care',
#   ':-)'],
#  ['#FollowFriday',
#   '@michae1green',
#   '@superninjaalan',
#   '@Doug_Laney',
#   'for',
#   'being',
#   'top',
#   'new',
#   'followers',
#   'in',
#   'my',
#   'community',
#   'this',
#   'week',
#   ':)'],
#  ['finally', 'the', 'fucking', 'weekend', ':)'],
#  ['REAL', ':)'],
#  ['@LoLEsportspedia', 'thanks', ':D'],
#  ['Hi',
#   'BAM',
#   '!',
#   '@BarsAndMelody',
#   'Can',
#   'you',
#   'follow',
#   'my',
#   'bestfriend',
#   '@969Horan696',
#   '?',
#   'She',
#   'loves',
#   'you',
#   'a',
#   'lot',
#   ':)',
#   'See',
#   'you',
#   'in',
#   'Warsaw',
#   '<3',
#   'Love',
#   'you',
#   '<3',
#   'x45'],
#  ['YES',
#   '!',
#   'I',
#   'Joined',
#   '#HushedCallWithFraydoe',
#   'for',
#   'a',
#   'call',
#   '&',
#   'gift',
#   'from',
#   '@_Fraydoe',
#   '<3',
#   'Gotta',
#   'Get',
#   '@HushedApp',
#   ':D',
#   'http://t.co/VaLVe8omdT'],
#  ['@YasLarry', 'yeahhh', ':)'],
#  ['can',
#   'I',
#   'DM',
#   'you',
#   '&',
#   'make',
#   'your',
#   'night',
#   'better',
#   ':)',
#   ')',
#   ')'],
#  ['just',
#   'joined',
#   'the',
#   '#HushedPinWithSammy',
#   'Event',
#   ':D',
#   'Might',
#   'get',
#   'to',
#   'Text',
#   'with',
#   '@SammyWilk',
#   'for',
#   'a',
#   'day',
#   '!',
#   'Luv',
#   'U',
#   '@HushedApp',
#   'http://t.co/kGfgawdHy9'],
#  ['Would',
#   'really',
#   'appreciate',
#   'it',
#   'if',
#   'you',
#   'share',
#   'this',
#   'video',
#   'around',
#   ':)',
#   'https://t.co/MhK3B3wOpQ'],
#  ['Hello',
#   ':)',
#   'Get',
#   'Youth',
#   'Job',
#   'Opportunities',
#   'follow',
#   '>',
#   '>',
#   '@tolajobjobs',
#   '@xhebenkewu_9920'],
#  ['@TomParker', 'oh', 'wow', '!', '!', 'That', 'is', 'beautiful', 'tom', ':)'],
#  ['Love',
#   'You',
#   '@darlingIXHAI22',
#   '@SyreenAnne',
#   ':)',
#   ')',
#   'https://t.co/wx7yRrE7sV'],
#  ['I',
#   'added',
#   'a',
#   'video',
#   'to',
#   'a',
#   '@YouTube',
#   'playlist',
#   'http://t.co/HVVPhSYakA',
#   'im',
#   'back',
#   'on',
#   'twitch',
#   'and',
#   'today',
#   'it',
#   'going',
#   'to',
#   'be',
#   'league',
#   ':)',
#   '-',
#   '1',
#   '/',
#   '3'],
#  ['#FollowFriday',
#   '@AmericanOGrain',
#   '@PecomeP',
#   '@APaulicand',
#   'for',
#   'being',
#   'top',
#   'supports',
#   'in',
#   'my',
#   'community',
#   'this',
#   'week',
#   ':)'],
#  ['@ZaynZaynmalik30',
#   'follow',
#   '@jnlazts',
#   '&',
#   'http://t.co/RCvcYYO0Iq',
#   'follow',
#   'u',
#   'back',
#   ':)'],
#  ['Gym', 'Monday', "can't", 'wait', ':)', '.', 'Likes'],
#  ['@HarNiLiZaLouis',
#   'Hey',
#   ',',
#   "here's",
#   'your',
#   'invite',
#   'to',
#   'join',
#   'Scope',
#   'as',
#   'an',
#   'influencer',
#   ':)',
#   'http://t.co/rZgZtQ2fJT'],
#  ['Those', 'friends', 'know', 'themselves', ':)'],
#  ['waiting', 'for', 'nudes', ':-)'],
#  ['@JacobWhitesides', 'go', 'sleep', 'u', '!', ':)', ')', ')'],
#  ['Stats',
#   'for',
#   'the',
#   'day',
#   'have',
#   'arrived',
#   '.',
#   '1',
#   'new',
#   'follower',
#   'and',
#   'NO',
#   'unfollowers',
#   ':)',
#   'via',
#   'http://t.co/RB8pMNgMEo',
#   '.'],
#  ['My', 'birthday', 'is', 'a', 'week', 'today', '!', ':D'],
#  ['@metalgear_jp',
#   '@Kojima_Hideo',
#   'I',
#   'want',
#   "you're",
#   'T-shirts',
#   '!',
#   'They',
#   'are',
#   'so',
#   'cool',
#   '!',
#   ':D'],
#  ['@AxeRade',
#   'haw',
#   'phela',
#   'if',
#   'am',
#   'not',
#   'looking',
#   'like',
#   'Mom',
#   'obviously',
#   'am',
#   'looking',
#   'like',
#   'him',
#   ':)'],
#  ['@zaynmalik',
#   'prince',
#   'charming',
#   'on',
#   'stage',
#   ':)',
#   'x',
#   'https://t.co/OnVFhzt5fZ'],
#  ['i', 'have', 'really', 'good', 'luck', ':)'],
#  ['Stats',
#   'for',
#   'the',
#   'day',
#   'have',
#   'arrived',
#   '.',
#   '1',
#   'new',
#   'follower',
#   'and',
#   'NO',
#   'unfollowers',
#   ':)',
#   'via',
#   'http://t.co/XzsOGaC4zK',
#   '.'],
#  ['#FollowFriday',
#   '@straz_das',
#   '@DCarsonCPA',
#   '@GH813600',
#   'for',
#   'being',
#   'top',
#   'engaged',
#   'members',
#   'in',
#   'my',
#   'community',
#   'this',
#   'week',
#   ':)'],
#  ['@twentyonepilots', '@fujirock_jp', 'tylers', 'hipster', 'glasses', ':D'],
#  ['@MartyRafenstein',
#   'Hey',
#   'Marty',
#   '!',
#   '!',
#   'Glad',
#   'to',
#   'see',
#   'on',
#   'Twitter',
#   '.',
#   ':)'],
#  ['@UKBusinessLunch',
#   'Hi',
#   'we',
#   'will',
#   'be',
#   'joining',
#   'you',
#   'again',
#   'today',
#   ':)'],
#  ['@LAfitnessUKhelp', 'done', 'thanks', ':-)'],
#  ['Its',
#   'already',
#   'afternoon',
#   ',',
#   'lets',
#   'read',
#   'Al',
#   'Kahfi',
#   'before',
#   'the',
#   'day',
#   'finish',
#   ':)'],
#  ['OhmyG',
#   '!',
#   'yaya',
#   'dub',
#   '@mainedcm',
#   'im',
#   'done',
#   'doing',
#   'to',
#   'stalk',
#   'your',
#   'ig',
#   'accnt',
#   '..',
#   'GONDOOO',
#   'MOO',
#   'TOLOGOOO',
#   ':)',
#   'HAHA'],
#  ['@rozbabes',
#   "Here's",
#   'your',
#   'invite',
#   'to',
#   'become',
#   'a',
#   'Scope',
#   'influencer',
#   ':)',
#   'Details',
#   'here',
#   ':',
#   'http://t.co/ipJ2yOiGet'],
#  ['#FollowFriday',
#   '@NGourd',
#   '@Locita',
#   '@D_Robert_Kelly',
#   'for',
#   'being',
#   'top',
#   'influencers',
#   'in',
#   'my',
#   'community',
#   'this',
#   'week',
#   ':)'],
#  ['@kevinthewhippet',
#   '@Cassie_Spaniel',
#   '@Bracken_Nelson',
#   '@BellisimoBella1',
#   '@SpanielHarry',
#   'thanks',
#   ':)',
#   'zzz',
#   'xx'],
#  ['Physiotherapy',
#   'Friday',
#   'is',
#   'my',
#   'hashtag',
#   'for',
#   'today',
#   '.',
#   'Custom',
#   '!',
#   ':-)'],
#  ['@Cjlopez21',
#   'you',
#   'know',
#   'I',
#   'will',
#   '💪',
#   'Monica',
#   'and',
#   'I',
#   'miss',
#   'you',
#   'to',
#   ',',
#   'yeah',
#   'sounds',
#   'good',
#   'to',
#   'me',
#   ':)'],
#  ['"',
#   'Good',
#   'morning',
#   ',',
#   'beautiful',
#   ':)',
#   '"',
#   "That's",
#   'all',
#   'it',
#   'takes',
#   '.'],
#  ['Hi',
#   'BAM',
#   '!',
#   '@BarsAndMelody',
#   'Can',
#   'you',
#   'follow',
#   'my',
#   'bestfriend',
#   '@969Horan696',
#   '?',
#   'She',
#   'loves',
#   'you',
#   'a',
#   'lot',
#   ':)',
#   'See',
#   'you',
#   'in',
#   'Warsaw',
#   '<3',
#   'Love',
#   'you',
#   '<3',
#   'x43'],
#  ['@MandaScapinello',
#   'oh',
#   'yeah',
#   '?',
#   '?',
#   'I',
#   'am',
#   'definitely',
#   'going',
#   'to',
#   'try',
#   'it',
#   'tonight',
#   'then',
#   '!',
#   ':)',
#   'we',
#   'took',
#   'your',
#   'advice',
#   'too',
#   '!',
#   'We',
#   'are',
#   'in',
#   'Treviso',
#   'now',
#   '!'],
#  ['@morallosanthony',
#   'follow',
#   '@jnlazts',
#   '&',
#   'http://t.co/RCvcYYO0Iq',
#   'follow',
#   'u',
#   'back',
#   ':)'],
#  ['@NIKKIERIOZZI',
#   'Hi',
#   '!',
#   'Would',
#   'you',
#   'like',
#   'an',
#   '@imPastel',
#   'concert',
#   '?',
#   'Let',
#   'me',
#   'know',
#   'your',
#   'city',
#   'and',
#   'country',
#   'and',
#   "I'll",
#   'start',
#   'working',
#   'on',
#   'it',
#   '!',
#   'Thanks',
#   ':)'],
#  ['Fine',
#   ',',
#   '...',
#   'Have',
#   'a',
#   'gorgeous',
#   'Friday',
#   ',',
#   'friend',
#   '!',
#   '!',
#   '..',
#   ';',
#   'xo',
#   '..',
#   '-',
#   ':)',
#   ')',
#   'https://t.co/JmpkZP2DaI'],
#  ['Oven',
#   'roasted',
#   'garlic',
#   'in',
#   'olive',
#   'oil',
#   ',',
#   'sun',
#   'dried',
#   'tomatoes',
#   ',',
#   'some',
#   'dried',
#   'basil',
#   ',',
#   'and',
#   'century',
#   'tuna',
#   ':)',
#   'https://t.co/EsCc9QhLob'],
#  ['@HostMyOffice',
#   '@NigelPWhittaker',
#   '@lemezma',
#   '@TWBC_Business',
#   '@_TheBunkerJL',
#   'Right',
#   'back',
#   'atchya',
#   '!',
#   'Have',
#   'a',
#   'great',
#   'day',
#   'everyone',
#   ':)'],
#  ['@TeamTall17',
#   '@FlashHayer',
#   'but',
#   "doesn't",
#   'even',
#   'follow',
#   'back',
#   ':-)'],
#  ['The',
#   'future',
#   'is',
#   'almost',
#   'here',
#   'then',
#   ':)',
#   'https://t.co/rolE3ZCL97'],
#  ['#FollowFriday',
#   '@Michelploria',
#   '@MyFrenchCity',
#   '@jasoncreation',
#   'for',
#   'being',
#   'top',
#   'new',
#   'followers',
#   'in',
#   'my',
#   'community',
#   'this',
#   'week',
#   ':)'],
#  ['No', 'chance', ':)'],
#  ['@ChiAB2486',
#   '@MrCliveC',
#   '@PCDKirkwood',
#   '@DC_ARVSgt',
#   '@COPS_President',
#   '@EmWilliamsCCCU',
#   '@LauraRGallagher',
#   '@Hall11Kate',
#   '@LaMinx541',
#   '@JohnTarbet71',
#   'cheers',
#   ':)'],
#  ['@thatguycalledP', 'go', 'po', 'for', 'ice', 'cream', ':)', ')'],
#  ['@19strawberry66', 'I', 'agree', '100', '%', ':)'],
#  ['@SpazzyTsukihara', 'hehehehe', 'thats', 'the', 'point', ':p'],
#  ['@KalinWhite', 'next', 'time', 'just', 'stay', 'home', ':)'],
#  ['@Gculloty87', 'thanks', ':)'],
#  ['#FollowFriday',
#   '@digitalplace2be',
#   '@intlboost',
#   '@_lafontpresse',
#   'for',
#   'being',
#   'top',
#   'supports',
#   'in',
#   'my',
#   'community',
#   'this',
#   'week',
#   ':)'],
#  ['@stayfaboo', 'it', 'will', 'be', 'up', 'soon', ',', 'i', 'promise', ':)'],
#  ['Web',
#   'Whatsapp',
#   'volta',
#   'a',
#   'funcionar',
#   'com',
#   'iPhone',
#   'jailbroken',
#   '.',
#   ':-)'],
#  ['@crustyolddeen',
#   '(',
#   'I',
#   'plan',
#   'on',
#   'watching',
#   'it',
#   'later',
#   ')',
#   'at',
#   '34',
#   'mins',
#   'Leia',
#   'appears',
#   'as',
#   'a',
#   'hologram',
#   'from',
#   'R2D2',
#   'w',
#   'a',
#   'message',
#   'for',
#   'Obi',
#   'Wan',
#   'as',
#   'he',
#   'sits',
#   'w',
#   'Luke',
#   ':)'],
#  ['@Mburu__',
#   'Inter',
#   '3',
#   'UCL',
#   ',',
#   'Arsenal',
#   '...',
#   'Small',
#   'team',
#   ',',
#   'Right',
#   '!',
#   ':)'],
#  ['Just',
#   'passing',
#   'by',
#   ':)',
#   '🚂',
#   '(',
#   '@',
#   'Dewsbury',
#   'Railway',
#   'Station',
#   '(',
#   'DEW',
#   ')',
#   '-',
#   '@nationalrailenq',
#   'in',
#   'Dewsbury',
#   ',',
#   'West',
#   'Yorkshire',
#   ')',
#   'https://t.co/DvBssHbrfx'],
#  ['@ClearlyArticle', ':)', 'its', '430', 'am', 'smh'],
#  ['@uptommosass',
#   "it's",
#   '9:25',
#   'am',
#   'here',
#   ':)',
#   'I',
#   'live',
#   'in',
#   'Scotland',
#   ':)',
#   "it's",
#   'strange',
#   'to',
#   'imagine',
#   'what',
#   '?',
#   '-',
#   'Megan',
#   'xx'],
#  ['@bookmyshow',
#   '!',
#   '#MasaanToday',
#   '#MasaanToday',
#   'A4',
#   '...',
#   'Shweta',
#   'Tripathi',
#   '!',
#   '#MasaanToday',
#   '#MasaanToday',
#   '-',
#   '.',
#   ':-)',
#   '.',
#   '-',
#   '..',
#   ','],
#  ['@WforWoman',
#   '5',
#   '.',
#   'Over',
#   '20',
#   'W',
#   'kurtas',
#   '!',
#   'And',
#   'my',
#   'Mom',
#   'has',
#   'about',
#   'half',
#   'the',
#   'number',
#   'I',
#   'have',
#   ':D',
#   '#WSaleLove'],
#  ['Ah',
#   '!',
#   'Hello',
#   'back',
#   'Larry',
#   '!',
#   '@TransworldBooks',
#   ':)',
#   'https://t.co/8XhjJb4jtH'],
#  ['Anyway', 'my', 'Friday', 'is', 'looking', 'kinda', 'gooood', ':)'],
#  ['@jhun_hunyo',
#   'follow',
#   '@jnlazts',
#   '&',
#   'http://t.co/RCvcYYO0Iq',
#   'follow',
#   'u',
#   'back',
#   ':)'],
#  ['Lol',
#   '.',
#   'Well',
#   '.',
#   "That's",
#   'life',
#   ':)',
#   'thank',
#   'God',
#   'it',
#   'enn',
#   'you',
#   'https://t.co/GLoCEIjGQQ'],
#  ['@OJBJ',
#   '@holmesjsamuel',
#   'surely',
#   'this',
#   'could',
#   'be',
#   'your',
#   'warmup',
#   'this',
#   'morning',
#   '?',
#   '?',
#   '?',
#   'Coming',
#   'on',
#   '15th',
#   'to',
#   'Bath',
#   ':)',
#   'xx'],
#  ['Dum',
#   'Dum',
#   'Andar',
#   '-',
#   'Ram',
#   'Sampath',
#   ',',
#   'Sona',
#   'Mohapatra',
#   '&',
#   'Samantha',
#   'Edwards',
#   'Mein',
#   'Tulane',
#   'to',
#   'razi',
#   'razi',
#   ',',
#   'Wah',
#   '!',
#   "That's",
#   'Josh',
#   ':)',
#   'http://t.co/ul8MARDfhm'],
#  ['@justinbieber', ':)', 'always', 'smile'],
#  ['@darlakim_', 'picture', '.', ':)'],
#  ['@arsenalnewsasit',
#   'Thanks',
#   'again',
#   ',',
#   'your',
#   'time',
#   '16.20',
#   'right',
#   '?',
#   "That's",
#   'perfect',
#   'timing',
#   'for',
#   'me',
#   'here',
#   ':)',
#   '.'],
#  ['#FollowFriday',
#   '@IzywayLesExpats',
#   '@na4innov',
#   '@InXpressCoAzur',
#   'for',
#   'being',
#   'top',
#   'engaged',
#   'members',
#   'in',
#   'my',
#   'community',
#   'this',
#   'week',
#   ':)'],
#  ['@Juleeyaanaa', 'i', 'know', ':)', ')'],
#  ['#GiveItUp',
#   'We',
#   'have',
#   'already',
#   'given',
#   'up',
#   'our',
#   'gas',
#   'subsidy',
#   'long',
#   'back',
#   'when',
#   'this',
#   'initiative',
#   'was',
#   'proposed',
#   '..',
#   'Feeling',
#   'so',
#   'delighted',
#   'having',
#   'done',
#   'that',
#   '!',
#   '!',
#   ':)'],
#  ['@dayloladay', 'I', 'missed', 'this', 'yesterday', '!', '!', ':-)'],
#  ['Hi',
#   'BAM',
#   '!',
#   '@BarsAndMelody',
#   'Can',
#   'you',
#   'follow',
#   'my',
#   'bestfriend',
#   '@969Horan696',
#   '?',
#   'She',
#   'loves',
#   'you',
#   'a',
#   'lot',
#   ':)',
#   'See',
#   'you',
#   'in',
#   'Warsaw',
#   '<3',
#   'Love',
#   'you',
#   '<3',
#   'x42'],
#  ['@jaimeemelanie_',
#   'lmaoo',
#   '!',
#   'The',
#   'best',
#   'songs',
#   'ever',
#   '<3',
#   'We',
#   'shall',
#   'have',
#   'our',
#   'own',
#   'little',
#   'throwback',
#   'this',
#   'week',
#   '(',
#   'y',
#   ')',
#   ':p'],
#  ['@Clazziebritchas',
#   'then',
#   'go',
#   'to',
#   'the',
#   'outlying',
#   'islands',
#   ',',
#   'such',
#   'as',
#   'Cheung',
#   'Chau',
#   ',',
#   'Mui',
#   'Wo',
#   '...',
#   'totally',
#   'different',
#   ':)',
#   ')'],
#  ['#KFCkitchentours',
#   'Kitchen',
#   'is',
#   'so',
#   'clean',
#   '.',
#   "I'm",
#   'totally',
#   'amazed',
#   ':)',
#   '@KFC_India'],
#  ['@cybelxxx',
#   'follow',
#   '@jnlazts',
#   '&',
#   'http://t.co/RCvcYYO0Iq',
#   'follow',
#   'u',
#   'back',
#   ':)'],
#  ['@Jana7380',
#   'on',
#   'the',
#   'cusp',
#   'of',
#   'testing',
#   'the',
#   'waters',
#   ',',
#   'hope',
#   'yours',
#   'is',
#   'rewarding',
#   ':)'],
#  ['#FollowFriday',
#   '@BroadcastBeat',
#   '@InSunWeTrust',
#   '@conseilsmkg',
#   'for',
#   'being',
#   'top',
#   'influencers',
#   'in',
#   'my',
#   'community',
#   'this',
#   'week',
#   ':)'],
#  ['arummzz',
#   ':',
#   "Let's",
#   'go',
#   '...',
#   "I'll",
#   'drive',
#   'for',
#   'you',
#   ':p',
#   '#traveling',
#   '#traveler',
#   '#yogyakarta',
#   '#jeep',
#   '#Indonesia',
#   '#instamood',
#   '…',
#   'https://t.co/s7y4Ys5JeU'],
#  ['Anyone', 'wanna', 'skype', 'me', '?', ':D'],
#  ['@agylyxa',
#   'may',
#   'i',
#   'look',
#   'so',
#   ',',
#   'bit',
#   'i',
#   'am',
#   'a',
#   'real',
#   'nice',
#   'friendly',
#   'girl',
#   ':-)'],
#  ['Im', 'not', 'like', 'them', '.', 'But', 'i', 'can', 'pretend', '~', ':)'],
#  ['watching', 'where', 'we', 'are', 'concert', 'film', ':)'],
#  ['Congratulations',
#   '@amisharanka95',
#   ',',
#   "you're",
#   'the',
#   'winner',
#   'to',
#   'our',
#   '#CheesyDelights',
#   'contest',
#   ':)',
#   'Please',
#   'DM',
#   'us',
#   'your',
#   'address',
#   'and',
#   'contact',
#   'number',
#   '!'],
#  [':)',
#   'Have',
#   'a',
#   'great',
#   'weekend',
#   'guys',
#   '!',
#   'https://t.co/DLDKLpeTAb'],
#  ['#FollowFriday',
#   '@CLARAROJASG',
#   '@BF_P2C',
#   '@MyBusiness_Plan',
#   'for',
#   'being',
#   'top',
#   'new',
#   'followers',
#   'in',
#   'my',
#   'community',
#   'this',
#   'week',
#   ':)'],
#  ['@PuaMagasiva',
#   'it',
#   'was',
#   'cool',
#   'seeing',
#   'you',
#   'film',
#   'today',
#   '!',
#   ':)'],
#  ['Check',
#   'out',
#   'Email',
#   'Marketing',
#   '24/7',
#   ':',
#   'http://t.co/O5fjR7oEqk',
#   'you',
#   "won't",
#   'regret',
#   'if',
#   'you',
#   'buy',
#   'it',
#   ':)'],
#  ['@vineshpomal',
#   'LOL',
#   '.',
#   'Come',
#   'join',
#   'us',
#   '...',
#   'See',
#   'u',
#   'in',
#   'around',
#   '14',
#   'hours',
#   'if',
#   'u',
#   'leave',
#   'now',
#   ',',
#   'without',
#   'delays',
#   '.',
#   ':)'],
#  ['Actually',
#   'very',
#   'easy',
#   'doing',
#   'like',
#   'this',
#   ',',
#   'it',
#   'must',
#   'be',
#   'a',
#   'station',
#   'I',
#   'guess',
#   'where',
#   'the',
#   'train',
#   "'",
#   'wd',
#   'take',
#   'at',
#   'least',
#   'an',
#   'hour',
#   'for',
#   'shifting',
#   'its',
#   'engine',
#   'etc',
#   ':-)'],
#  ['sunburn', 'is', 'peeling', ':-)'],
#  ['@Sexdate_gratis',
#   'Visit',
#   'my',
#   'blog',
#   'http://t.co/UzOAqroWKx',
#   'thanks',
#   ':D'],
#  ['@TikoSD',
#   'Hi',
#   '!',
#   'Would',
#   'you',
#   'like',
#   'an',
#   '@imPastel',
#   'concert',
#   '?',
#   'Let',
#   'me',
#   'know',
#   'your',
#   'city',
#   'and',
#   'country',
#   'and',
#   "I'll",
#   'start',
#   'working',
#   'on',
#   'it',
#   '!',
#   'Thanks',
#   ':)'],
#  ['@no1_razorstan',
#   'then',
#   'talk',
#   'to',
#   'me',
#   '.',
#   'I',
#   'can',
#   'help',
#   'you',
#   ':)'],
#  ['"',
#   '@CassTheTrainer',
#   ':',
#   'A',
#   'Huge',
#   '&',
#   'Warm',
#   'Welcome',
#   'to',
#   '@VodkaBlond',
#   ':-)',
#   ')',
#   '"',
#   '☆',
#   'finally',
#   'we',
#   'complete',
#   'the',
#   'triangle',
#   '!',
#   '☆'],
#  ['@LucienneDiver',
#   'I',
#   'live',
#   'in',
#   'Northern',
#   'Ireland',
#   '.',
#   ':)',
#   'what',
#   'sights',
#   'have',
#   'you',
#   'seen',
#   '?'],
#  ['@Mecastor01Mica',
#   'follow',
#   '@jnlazts',
#   '&',
#   'http://t.co/RCvcYYO0Iq',
#   'follow',
#   'u',
#   'back',
#   ':)'],
#  ['#FollowFriday',
#   '@Z_Intl_Agency',
#   '@Tivipro',
#   '@compexly',
#   'for',
#   'being',
#   'top',
#   'supports',
#   'in',
#   'my',
#   'community',
#   'this',
#   'week',
#   ':)'],
#  ['Stats',
#   'for',
#   'the',
#   'day',
#   'have',
#   'arrived',
#   '.',
#   '1',
#   'new',
#   'follower',
#   'and',
#   'NO',
#   'unfollowers',
#   ':)',
#   'via',
#   'http://t.co/6prugvmOuC',
#   '.'],
#  ['@imraina',
#   'feeling',
#   'smthng',
#   'smthng',
#   'fr',
#   'u',
#   '...',
#   'lol',
#   '...',
#   'wanna',
#   'hug',
#   'u',
#   '...',
#   'XOXO',
#   '...',
#   'love',
#   'uu',
#   'jaann',
#   'take',
#   'care',
#   ':',
#   '*',
#   ':)',
#   ')',
#   '<3',
#   ':',
#   '"',
#   ')'],
#  ['thanks', 'mom', ':)'],
#  ['Thanks',
#   '#TopNewFollowers',
#   '@BestOfFicPad',
#   '@MrCFluegel',
#   '@JeanMarcPN',
#   'Happy',
#   'to',
#   'connect',
#   ':)'],
#  ['@MooseAllain',
#   '@MeatBingo',
#   'that',
#   'is',
#   'the',
#   'just',
#   'most',
#   'wonderful',
#   'thing',
#   ',',
#   "it's",
#   'made',
#   'me',
#   'feel',
#   'all',
#   'fluffy',
#   'inside',
#   '.',
#   'Great',
#   'pirouette',
#   ',',
#   'Moose',
#   ':D'],
#  ['@KristophCajon',
#   'I',
#   'have',
#   'a',
#   'trip',
#   'to',
#   'philly',
#   'in',
#   'December',
#   'so',
#   'after',
#   'that',
#   ':)',
#   "I'd",
#   'love',
#   'to',
#   'come',
#   'out',
#   'there',
#   'dude',
#   '.'],
#  ['Hi',
#   'BAM',
#   '!',
#   '@BarsAndMelody',
#   'Can',
#   'you',
#   'follow',
#   'my',
#   'bestfriend',
#   '@969Horan696',
#   '?',
#   'She',
#   'loves',
#   'you',
#   'a',
#   'lot',
#   ':)',
#   'See',
#   'you',
#   'in',
#   'Warsaw',
#   '<3',
#   'Love',
#   'you',
#   '<3',
#   'x41'],
#  ['The',
#   'question',
#   'is',
#   'flawed',
#   '.',
#   'Pain',
#   "doesn't",
#   'negate',
#   'strength',
#   ':)',
#   'https://t.co/77TbkS2Djw'],
#  ['@ReflectKnives',
#   'You',
#   'went',
#   'solo',
#   'because',
#   'these',
#   'moves',
#   "weren't",
#   'being',
#   'made',
#   ':D'],
#  ['hey',
#   'my',
#   'fav',
#   'nirvana',
#   'song',
#   'is',
#   'smells',
#   'like',
#   'teen',
#   'spirit',
#   'rip',
#   'amy',
#   'winehouse',
#   ':-)',
#   ')',
#   ')'],
#  ['#FollowFriday',
#   '@CCIdeLYON',
#   '@CCI_95',
#   '@CPNERI_ESIGROUP',
#   'for',
#   'being',
#   'top',
#   'engaged',
#   'members',
#   'in',
#   'my',
#   'community',
#   'this',
#   'week',
#   ':)'],
#  ["Let's",
#   'go',
#   '...',
#   "I'll",
#   'drive',
#   'for',
#   'you',
#   ':p',
#   '#traveling',
#   '#traveler',
#   '#yogyakarta',
#   '#jeep',
#   '#Indonesia',
#   '#instamood',
#   '…',
#   'https://t.co/s7y4Ys5JeU'],
#  ['did',
#   'we',
#   'name',
#   'the',
#   'couple',
#   'yet',
#   '?',
#   '?',
#   '#TomHiddleston',
#   '#ElizabethOlsen',
#   '?',
#   '?',
#   '#yaytheylookgreat',
#   ':)',
#   ')'],
#  ['I',
#   'love',
#   'you',
#   'all',
#   'goodnight',
#   '.',
#   'Vid',
#   'going',
#   'up',
#   'when',
#   'I',
#   'wake',
#   'up',
#   'you',
#   'all',
#   'with',
#   'love',
#   'this',
#   'one',
#   ':)'],
#  ['This',
#   'weekend',
#   'I',
#   'am',
#   'gonna',
#   'shoot',
#   'the',
#   'lovely',
#   '@NarakuBrock',
#   'again',
#   '<3',
#   '!',
#   'Here',
#   'a',
#   'picture',
#   'I',
#   'made',
#   'of',
#   'her',
#   'last',
#   'time',
#   ':D',
#   'http://t.co/s3e2dmpt24'],
#  ['anyway', ':-)'],
#  ['Itty',
#   'Bitty',
#   'Teenie',
#   'Bikini',
#   ':)',
#   'http://t.co/A2oxW0ZI3g',
#   'http://t.co/jn7KSfHwRc'],
#  ['I',
#   'just',
#   'joined',
#   'the',
#   '#HushedPinWithSammy',
#   'Event',
#   ':D',
#   'Might',
#   'get',
#   'to',
#   'Text',
#   'with',
#   '@SammyWilk',
#   'for',
#   'a',
#   'day',
#   '!',
#   'Luv',
#   'U',
#   '@HushedApp',
#   'http://t.co/czdow1i44W'],
#  ['Always',
#   'so',
#   'much',
#   'fun',
#   'when',
#   '4th',
#   'hour',
#   'gets',
#   'together',
#   '.',
#   ':)',
#   'Ending',
#   'the',
#   'night',
#   'with',
#   'ice',
#   'cream',
#   'and',
#   'Xfiles',
#   '.',
#   'Content',
#   '.'],
#  ['@aangelayap', 'easy', ':D'],
#  ['@NTtownend',
#   'yes',
#   ',',
#   'be',
#   'surprised',
#   'if',
#   'we',
#   "don't",
#   'see',
#   'a',
#   'bit',
#   'of',
#   'rain',
#   'today',
#   '...',
#   ':)'],
#  ['@ReyesFraulein',
#   'follow',
#   '@jnlazts',
#   '&',
#   'http://t.co/RCvcYYO0Iq',
#   'follow',
#   'u',
#   'back',
#   ':)'],
#  ['To',
#   'all',
#   '@fatpunkstudio',
#   'have',
#   'a',
#   'fabulous',
#   'Friday',
#   'and',
#   'keep',
#   'up',
#   'the',
#   'fantastic',
#   'work',
#   '!',
#   '!',
#   ':)',
#   ')'],
#  ['@justinbieber',
#   'can',
#   'you',
#   'please',
#   'follow',
#   'me',
#   '@caitecat1209',
#   '♡',
#   '♡',
#   '♡',
#   'please',
#   'jb',
#   'follow',
#   'me',
#   'I',
#   'love',
#   'you',
#   'always',
#   'and',
#   'forever',
#   '.',
#   "I'm",
#   'a',
#   'belieber',
#   '♡',
#   '♡',
#   '♡',
#   ':)',
#   'I',
#   'love',
#   'u'],
#  ['#FollowFriday',
#   '@DiploMix',
#   '@CCI_entreprises',
#   '@CCI_92',
#   'for',
#   'being',
#   'top',
#   'influencers',
#   'in',
#   'my',
#   'community',
#   'this',
#   'week',
#   ':)'],
#  ['Morning', 'all', '!', ':)'],
#  ['@FranchiSeedsUK', 'good', 'to', 'hear', ':)'],
#  ['@LusciousLyndee1',
#   'Nighty',
#   'night',
#   '!',
#   "Don't",
#   'let',
#   'the',
#   'bed',
#   'bugs',
#   'bite',
#   ':D'],
#  ['@Bonsplansblog',
#   'Very',
#   'beautiful',
#   'this',
#   'bracelet',
#   '!',
#   'good',
#   'idea',
#   ':)'],
#  ['@guywilliamsguy',
#   'waiting',
#   'for',
#   'you',
#   'at',
#   'the',
#   'foundry',
#   '.',
#   'Where',
#   'you',
#   'at',
#   '?',
#   '?',
#   ':)'],
#  ['@KalinWhite', 'I', 'like', 'that', 'game', ':)'],
#  ['@suzannepanter',
#   '@kevinbacon',
#   '@katosman',
#   'Ah',
#   '!',
#   'Now',
#   'it',
#   'makes',
#   'sense',
#   '...',
#   "Didn't",
#   'see',
#   'the',
#   'pic',
#   'on',
#   'my',
#   'effing',
#   'phone',
#   'last',
#   'night',
#   '.',
#   'Woot',
#   ':)',
#   'x'],
#  ['@Derek_GTA',
#   'Hi',
#   'Derek',
#   ',',
#   'you',
#   'could',
#   'try',
#   'using',
#   'ParkShare',
#   'in',
#   'Gloucestershire',
#   'http://t.co/qIF9AyAlkc',
#   ':)'],
#  ['Aaaahhh',
#   'man',
#   ',',
#   'this',
#   'track',
#   'is',
#   'a',
#   'traffic',
#   'stress',
#   'reliever',
#   '.',
#   ':)'],
#  ['#FollowFriday',
#   '@elevents2',
#   '@JoussotFrench_J',
#   '@NYIBF',
#   'for',
#   'being',
#   'top',
#   'new',
#   'followers',
#   'in',
#   'my',
#   'community',
#   'this',
#   'week',
#   ':)'],
#  ['@El1neW', "How're", 'you', 'today', 'my', 'dear', '?', ':)'],
#  ['@Jesutomisin', 'I', 'hear', 'you', 'guys', 'want', 'Arbeloa', '.', ':D'],
#  ['@ShawnMendes',
#   'turning',
#   '17',
#   'in',
#   '15',
#   'days',
#   '...',
#   'omg',
#   '.',
#   'at',
#   'least',
#   'we',
#   'have',
#   'only',
#   '3',
#   'years',
#   'difference',
#   ':)'],
#  ['@matteomeacci',
#   'Well',
#   ',',
#   'they',
#   'say',
#   'Europe',
#   'is',
#   'on',
#   'the',
#   'rise',
#   'again',
#   ',',
#   'but',
#   'I',
#   'find',
#   'that',
#   'hard',
#   'to',
#   'believe',
#   ':)'],
#  ['@WforWoman',
#   '#WSaleLove',
#   'uncountable',
#   'coz',
#   'we',
#   'love',
#   'unlimited',
#   ':)'],
#  ['Yes',
#   ',',
#   'of',
#   'course',
#   ':)',
#   '#TeamPositive',
#   'https://t.co/SaIX1VpFJF'],
#  ['yes', 'i', 'love', ':-)', '#AlDub'],
#  ['@coffeebreak22',
#   '@LauRenArren',
#   '@drparkave',
#   '@JWKanyuira1969',
#   '@dheracing',
#   '@RhoaChri',
#   '@BarbaraBathurst',
#   '@1cryingeye',
#   '@willisteam',
#   ':)',
#   '☕',
#   '☕',
#   '☕',
#   'Thank',
#   'you',
#   'Rita',
#   '!'],
#  ['@mikerobb',
#   'Hi',
#   'there',
#   ',',
#   'could',
#   'you',
#   'please',
#   'DM',
#   'us',
#   'further',
#   'info',
#   'and',
#   "we'd",
#   'be',
#   'happy',
#   'to',
#   'help',
#   '!',
#   ':)'],
#  ['@24gooch', 'on', 'way', 'my', 'boy', '!', ':)'],
#  ['@graphure',
#   'I',
#   'hope',
#   'you',
#   'will',
#   'get',
#   'a',
#   'lot',
#   'of',
#   'nice',
#   'gifts',
#   ':D'],
#  ['Hi',
#   'BAM',
#   '!',
#   '@BarsAndMelody',
#   'Can',
#   'you',
#   'follow',
#   'my',
#   'bestfriend',
#   '@969Horan696',
#   '?',
#   'She',
#   'loves',
#   'you',
#   'a',
#   'lot',
#   ':)',
#   'See',
#   'you',
#   'in',
#   'Warsaw',
#   '<3',
#   'Love',
#   'you',
#   '<3',
#   'x40'],
#  ['#FollowFriday',
#   '@ACBM_SECEM',
#   '@DCarsonCPA_NYC',
#   '@PromosalonsInfo',
#   'for',
#   'being',
#   'top',
#   'supports',
#   'in',
#   'my',
#   'community',
#   'this',
#   'week',
#   ':)'],
#  ['So', 'True', '!', '!', ':)', 'https://t.co/N2ORwrOwhD'],
#  ['I',
#   'added',
#   'a',
#   'video',
#   'to',
#   'a',
#   '@YouTube',
#   'playlist',
#   'http://t.co/09GuSuMrNb',
#   'im',
#   'back',
#   'on',
#   'twitch',
#   'and',
#   'today',
#   'it',
#   'going',
#   'to',
#   'be',
#   'league',
#   ':)',
#   '-',
#   '1',
#   '/',
#   '3'],
#  ['@ZarlashtFaisal',
#   '@Tabinda_Samar',
#   'Sethi',
#   'was',
#   'HIGH',
#   '?',
#   '?',
#   '?',
#   ':)'],
#  ['@IAm_Lennox', 'exe', 'skeem', 'saam', ':)'],
#  ['These',
#   'are',
#   'the',
#   'people',
#   'who',
#   'make',
#   'me',
#   'smile',
#   '.',
#   ':)',
#   '@_pumpchkin_',
#   '@aka_pump',
#   '@LilfrenchMsp',
#   '@_Lishielou908_',
#   'http://t.co/iDdtACkA4K'],
#  ['@CoSchedule', 'Thanks', 'for', 'the', 'invite', '.', ':)'],
#  ['@SyedIHusain',
#   'polite',
#   'izzat',
#   ':)',
#   'wese',
#   'does',
#   'she',
#   'trust',
#   'him',
#   '?',
#   'khawateen',
#   'k',
#   'sath',
#   'selfies',
#   'say',
#   'to',
#   'mana',
#   'kar',
#   'deya',
#   ':)'],
#  ['Thank',
#   'you',
#   '@MovieTubePW',
#   "that's",
#   'my',
#   'Friday',
#   'evening',
#   'sorted',
#   ':-)'],
#  ['@nova_caneeee', 'you', 'smart', ':)', ')', ')'],
#  ['@vaalthepal', ':-)', 'nice', 'hair', 'tbh'],
#  ['5', 'years', ':)', 'https://t.co/hJEhDmxuu9'],
#  ['jacob',
#   'will',
#   'there',
#   'be',
#   'a',
#   'm',
#   '&',
#   'g',
#   'upgrade',
#   '?',
#   '?',
#   ':-)'],
#  ['@heydonworks', 'Nice', 'tee', 'man', ':)'],
#  ['Happy',
#   'family',
#   'vacation',
#   '..',
#   ':D',
#   '[',
#   'pic',
#   ']',
#   '—',
#   'https://t.co/HL0Fw8msf1'],
#  ['some', 'sleep', 'would', 'be', 'nice', ':-)'],
#  ['If',
#   "you're",
#   'reading',
#   'this',
#   ',',
#   "you're",
#   'beautiful',
#   '.',
#   'Like',
#   'this',
#   'if',
#   'you',
#   'just',
#   'read',
#   'this',
#   ':)'],
#  ['Talking',
#   'to',
#   'One',
#   'person',
#   '...',
#   'Having',
#   'Two',
#   'Conversations',
#   ':)',
#   ')',
#   ')'],
#  ['skype', 'was', 'fun', ':-)'],
#  ['@SoggyStones', 'should', 'be', 'online', ':)'],
#  ['...',
#   'because',
#   "it's",
#   'Friday',
#   ':D',
#   '(',
#   'y',
#   ')',
#   'http://t.co/6rA4ZlpjO9'],
#  ['#FollowFriday',
#   '@CCIFCcanada',
#   '@AdamEvnmnt',
#   '@boxcalf1',
#   'for',
#   'being',
#   'top',
#   'engaged',
#   'members',
#   'in',
#   'my',
#   'community',
#   'this',
#   'week',
#   ':)'],
#  ['Something',
#   'to',
#   'get',
#   'your',
#   '#Friday',
#   'off',
#   'to',
#   'a',
#   'great',
#   'start',
#   ':)',
#   'Have',
#   'a',
#   'great',
#   'day',
#   'all',
#   '!',
#   '#Mclaren',
#   '#FridayFeeling',
#   '#TGIF',
#   'http://t.co/LshgwcXsSv'],
#  ['@AvinPera',
#   'follow',
#   '@jnlazts',
#   '&',
#   'http://t.co/RCvcYYO0Iq',
#   'follow',
#   'u',
#   'back',
#   ':)'],
#  ['square', 'enix', 'bissmillah', 'ya', 'Allah', ':)'],
#  ['@SephtonMark',
#   "we're",
#   'training',
#   '#SocEnt',
#   'startups',
#   'at',
#   '@TobaccoDockLon',
#   'this',
#   'week',
#   'w',
#   '/',
#   '@HelpingB',
#   '-',
#   "we'd",
#   'love',
#   'to',
#   'have',
#   'you',
#   'drop',
#   'in',
#   'if',
#   'youre',
#   'arnd',
#   'town',
#   ':)'],
#  ['@HGVWolfie',
#   'Basically',
#   'you',
#   'piss',
#   'in',
#   'a',
#   'cup',
#   'and',
#   'they',
#   'test',
#   'it',
#   ':)',
#   ')',
#   ')'],
#  ['@ellenRstewart', 'where', 'are', 'you', 'off', 'to', 'next', '?', ':)'],
#  ['@IonSwitz',
#   '@notch',
#   'also',
#   ',',
#   'Twitter',
#   'is',
#   'terrible',
#   'for',
#   'complicated',
#   'discussions',
#   ':)'],
#  ['Snapchat',
#   'me',
#   ':',
#   'LynetteLowe',
#   '#snapchat',
#   '#kikmenow',
#   '#snapme',
#   '#hot',
#   '#snapchat',
#   '#amazon',
#   '#kikmeguys',
#   ':)',
#   'http://t.co/kd54m2IAm6'],
#  ['I',
#   'am',
#   'not',
#   'looking',
#   'forward',
#   'to',
#   'a',
#   '12',
#   'hour',
#   'shift',
#   'today',
#   ':)',
#   ')',
#   ')'],
#  ['@ely83_ely',
#   'definately',
#   'agree',
#   'that',
#   "it's",
#   'a',
#   'growing',
#   'sport',
#   '.',
#   'Drop',
#   'me',
#   'an',
#   'email',
#   'with',
#   'details',
#   'and',
#   'we',
#   'can',
#   'see',
#   'what',
#   'we',
#   'can',
#   'do',
#   ':-)'],
#  ['My', 'last', 'rt', 'is', 'me', ':)'],
#  ['...',
#   'and',
#   'the',
#   'Rakyat',
#   'will',
#   'keep',
#   'visiting',
#   'your',
#   'blog',
#   'and',
#   'reading',
#   'your',
#   'writing',
#   ':)',
#   'https://t.co/IMRy2BXuzd'],
#  ['@ryan2390',
#   'ever',
#   'since',
#   'I',
#   'mentioned',
#   'fly',
#   'fishing',
#   'the',
#   'other',
#   'day',
#   "I'm",
#   'getting',
#   'follows',
#   'and',
#   'promoted',
#   'posts',
#   'about',
#   'it',
#   'lol',
#   'cyber',
#   'stalked',
#   '!',
#   ':-)'],
#  ['@Gurmeetramrahim',
#   '#OurDaughtersOurPride',
#   '#mypapamypride',
#   'Proud',
#   'of',
#   'You',
#   'Papa',
#   'Coach',
#   ':)'],
#  ['@imarpita', 'it', 'was', 'great', 'talking', 'to', 'you', ':D'],
#  ['@awaismarwat2011',
#   'never',
#   'see',
#   'positive',
#   'kha',
#   'u',
#   'could',
#   'also',
#   'mention',
#   'atleast',
#   'they',
#   'are',
#   'going',
#   ':)'],
#  ['Hi',
#   'BAM',
#   '!',
#   '@BarsAndMelody',
#   'Can',
#   'you',
#   'follow',
#   'my',
#   'bestfriend',
#   '@969Horan696',
#   '?',
#   'She',
#   'loves',
#   'you',
#   'a',
#   'lot',
#   ':)',
#   'See',
#   'you',
#   'in',
#   'Warsaw',
#   '<3',
#   'Love',
#   'you',
#   '<3',
#   'x39'],
#  ['@_pigglywiggly',
#   '@Omundson',
#   'The',
#   'mango',
#   "lassi's",
#   'from',
#   "Monty's",
#   'are',
#   'marvellous',
#   ':D',
#   '.',
#   'Though',
#   'I',
#   'suspect',
#   "that's",
#   'not',
#   'what',
#   'you',
#   'meant',
#   '...'],
#  ['#FollowFriday',
#   '@StayfanChemin',
#   '@CCI_75',
#   '@aandreup',
#   'for',
#   'being',
#   'top',
#   'influencers',
#   'in',
#   'my',
#   'community',
#   'this',
#   'week',
#   ':)'],
#  ['@Thakurain_',
#   'Haha',
#   '.',
#   'Yes',
#   '.',
#   'I',
#   'have',
#   '24',
#   'hrs',
#   '.',
#   'The',
#   'time',
#   'has',
#   'come',
#   'to',
#   'touch',
#   'the',
#   'Kepler',
#   '452b',
#   '.',
#   'Chalna',
#   'hai',
#   '?',
#   '?',
#   ':D'],
#  ['@iyah_mohamad',
#   'follow',
#   '@jnlazts',
#   '&',
#   'http://t.co/RCvcYYO0Iq',
#   'follow',
#   'u',
#   'back',
#   ':)'],
#  ['@allygrrdo', 'thankyou', 'pretty', '!', ':)'],
#  ['@PinkPeoniesBlog',
#   '@helloprettysa',
#   'definitely',
#   'the',
#   'Hazel',
#   'Food',
#   'Market',
#   'in',
#   'Brooklyn',
#   ',',
#   'Pta',
#   ':)',
#   '>',
#   '>',
#   'http://t.co/ySQkhNDo2B'],
#  ['still', 'awake', ':)', ')', ')'],
#  ['@joiredve', 'okayy', ':D'],
#  ['Awww', 'thank', 'you', ':)', 'https://t.co/9tSQv2DWVm'],
#  ['@AR1961',
#   'ha',
#   '!',
#   'That',
#   'does',
#   'not',
#   'surprise',
#   'me',
#   'in',
#   'the',
#   'least',
#   '!',
#   'Okay',
#   'but',
#   'will',
#   'see',
#   'doc',
#   'this',
#   'afternoon',
#   '.',
#   'Yorkshire',
#   'is',
#   'splendid',
#   'though',
#   '!',
#   ':)',
#   'xx'],
#  ['@JRTurnerPhoto',
#   '@davidqueenan',
#   '@jameslturnbull',
#   'spam',
#   'folder',
#   ':',
#   'WOW',
#   '!',
#   'I',
#   'have',
#   'won',
#   'a',
#   'huge',
#   'amount',
#   'of',
#   '$',
#   'I',
#   'just',
#   'need',
#   'to',
#   'travel',
#   'to',
#   'Nigeria',
#   'to',
#   'claim',
#   'it',
#   ':)'],
#  ['@PERKSOFNIALLJH', 'RTed', '!', 'Good', 'Luck', ':)'],
#  ['My', 'legs', 'hurt', 'so', 'bad', ':)', ')', ')'],
#  ['@johnny_lopez96', 'I', 'get', 'mine', 'Saturday', ':-)', ')', ')'],
#  ['@imafaithreyes', 'thaaanks', '!', 'December', 'puhon', '.', ':)', ')'],
#  ['happinessss', '~', '!', '!', ':)', ')', 'https://t.co/slOn63OUeS'],
#  ['@VaibhavVj78',
#   '@PayUmoney',
#   'True',
#   'that',
#   '.',
#   'Can',
#   'you',
#   'change',
#   'TnC',
#   'without',
#   'prior',
#   'notification',
#   '?',
#   'I',
#   'could',
#   'have',
#   'used',
#   'them',
#   'last',
#   'night',
#   '.',
#   ':-)'],
#  ['https://t.co/gYx34VfmkK',
#   'and',
#   'I',
#   'probably',
#   'only',
#   'find',
#   'this',
#   'funny',
#   'at',
#   '2:22',
#   'am',
#   ':-)'],
#  ['@aliyaskates',
#   '@yoshihikomkm',
#   'Fat',
#   'cos',
#   'he',
#   'probably',
#   'ate',
#   'Yuna',
#   ':D',
#   ':D',
#   ':D'],
#  ['@emmajaneparsons',
#   '@CuriousMindsNW',
#   'Have',
#   'fun',
#   'in',
#   'Tameside',
#   ':)',
#   ')'],
#  ['@hydrcted', 'what', ':-)', 'did', ':-)', 'i', ':-)', 'do', ':', '-', '?'],
#  ['@CharmingJedward', 'you', '´', 're', 'welcome', '!', '!', ':)'],
#  ['My', 'Google', '+', 'account', '.', ':)', 'http://t.co/R8jyDxlQyo'],
#  ['@2SHYMC',
#   'and',
#   'they',
#   'call',
#   'scousers',
#   'for',
#   'everything',
#   '!',
#   'Hope',
#   'you',
#   'and',
#   'Zoe',
#   'are',
#   'well',
#   'mate',
#   ':)'],
#  ['@RachelEvans_28',
#   'RIGHT',
#   '!',
#   '!',
#   '!',
#   'I',
#   'literally',
#   'was',
#   'like',
#   'maybe',
#   'u',
#   'should',
#   'get',
#   'people',
#   'who',
#   'actually',
#   'know',
#   'what',
#   "they're",
#   'doing',
#   ':-)',
#   '@StudentTrip'],
#  ['|', '|', 'Sameee', '~', 'Rest', 'well', ':)', 'https://t.co/T6ZCo4NxDG'],
#  ['@EdgarsLame',
#   'happy',
#   'birthday',
#   'Edgar',
#   '!',
#   'I',
#   'hope',
#   'you',
#   'have',
#   'a',
#   'good',
#   'one',
#   'and',
#   'keep',
#   'updating',
#   'your',
#   'travel',
#   'log',
#   ':)'],
#  ['Hello', ':D', '@VikkFollows', '@Vikkstar123'],
#  ['@MarreyJewAna', 'bring', 'Abes', ':)'],
#  ['Stats',
#   'for',
#   'the',
#   'day',
#   'have',
#   'arrived',
#   '.',
#   '2',
#   'new',
#   'followers',
#   'and',
#   'NO',
#   'unfollowers',
#   ':)',
#   'via',
#   'http://t.co/xxlXs6xYwe',
#   '.'],
#  ['someone', 'talk', 'to', 'me', ':)', ')'],
#  ['i',
#   'will',
#   'never',
#   'be',
#   'the',
#   'same',
#   'if',
#   'we',
#   'ever',
#   'meet',
#   'again',
#   ':D'],
#  ['@BBCSport', 'come', 'on', 'man', ':D', ':D'],
#  ['@prettyden15',
#   'follow',
#   '@jnlazts',
#   '&',
#   'http://t.co/RCvcYYO0Iq',
#   'follow',
#   'u',
#   'back',
#   ':)'],
#  ['Hi',
#   'BAM',
#   '!',
#   '@BarsAndMelody',
#   'Can',
#   'you',
#   'follow',
#   'my',
#   'bestfriend',
#   '@969Horan696',
#   '?',
#   'She',
#   'loves',
#   'you',
#   'a',
#   'lot',
#   ':)',
#   'See',
#   'you',
#   'in',
#   'Warsaw',
#   '<3',
#   'Love',
#   'you',
#   '<3',
#   'x38'],
#  ['@LivelyKaty',
#   '*',
#   'sighs',
#   'dreamily',
#   'at',
#   'that',
#   'pout',
#   'and',
#   'those',
#   "'",
#   'come',
#   'to',
#   'bath',
#   "'",
#   'eyes',
#   '!',
#   '*',
#   ':-)',
#   '#quacketyquack'],
#  ['@_sunshinehoran_', 'happy', 'birthday', 'love', ':)'],
#  ['@Brianscrooks', '@burwellitltd', '@manfrotto_tweet', 'Cheers', ':-)'],
#  ['Funny',
#   'how',
#   'that',
#   'happened',
#   'when',
#   'Phil',
#   'was',
#   'here',
#   'too',
#   ':',
#   ')'],
#  ['@WMFireDogs',
#   "I'd",
#   'call',
#   "'",
#   'em',
#   'Del',
#   '&',
#   'Rodders',
#   ':)',
#   'What',
#   'else',
#   '!'],
#  ['@ForkH',
#   'Hi',
#   ',',
#   'may',
#   'you',
#   'like',
#   'play',
#   'my',
#   'newest',
#   'gamejam',
#   'game',
#   ',',
#   'i',
#   'would',
#   'be',
#   'very',
#   'happy',
#   'about',
#   'it',
#   ':)',
#   'http://t.co/8J5voDDHcs'],
#  ['This',
#   'is',
#   'great',
#   '!',
#   'Irish',
#   'literature',
#   'is',
#   'really',
#   'inaccessible',
#   'to',
#   'most',
#   'of',
#   'us',
#   'without',
#   'Irish',
#   ':)'],
#  ['@BhaktisBanter',
#   '@PallaviRuhail',
#   'yeah',
#   '!',
#   'This',
#   'is',
#   'fun',
#   ':)',
#   '#FlipkartFashionFriday'],
#  ['Nice', 'music', ':)', 'Check', 'it', 'out', '!', 'http://t.co/PEjHsORGrk'],
#  ['@_xRiya',
#   'Strange',
#   "Kareena's",
#   'Fans',
#   'Not',
#   'Knowing',
#   "Kareena's",
#   'Fans',
#   ':)'],
#  ['Hello',
#   ':)',
#   'Get',
#   'Youth',
#   'Job',
#   'Opportunities',
#   'follow',
#   '>',
#   '>',
#   '@tolajobjobs',
#   '@e1d4c8e25ec844c'],
#  ['better', ':)'],
#  ['@ArtForCause',
#   'Cool',
#   '.',
#   'Will',
#   'look',
#   'for',
#   'you',
#   'there',
#   '.',
#   ':)'],
#  [':)', ')', 'beautiful', 'http://t.co/F8V3McI39e'],
#  ["I'm",
#   'playing',
#   'Brain',
#   'Dots',
#   ':',
#   ')',
#   '#BrainDots',
#   'http://t.co/cHl12JvuxN',
#   'http://t.co/GGgU9PYEjI'],
#  ['@ScreamQueenLR',
#   "That's",
#   'fair',
#   'enough',
#   ':)',
#   'I',
#   "wouldn't",
#   'rush',
#   'back',
#   'either',
#   '.'],
#  ['Brandi',
#   '18',
#   'on',
#   'my',
#   'FB',
#   'DROP',
#   'A',
#   'SELFIE',
#   ':)',
#   'was',
#   'fun',
#   'https://t.co/TRoroeS4FK'],
#  ['@kthrnbyln',
#   'follow',
#   '@jnlazts',
#   '&',
#   'http://t.co/RCvcYYO0Iq',
#   'follow',
#   'u',
#   'back',
#   ':)'],
#  ['During',
#   'a',
#   'carnival',
#   'men',
#   'put',
#   'masks',
#   'over',
#   'their',
#   'masks',
#   '.',
#   'Xavier',
#   'Forneret',
#   ':-)'],
#  ['@jennnnifer29',
#   'Jennifer',
#   ',',
#   'Check',
#   'my',
#   'site',
#   'if',
#   'u',
#   'wanna',
#   'get',
#   'FREE',
#   '50.000',
#   '8',
#   'Ball',
#   'Pool',
#   'Coins',
#   '.',
#   'Thank',
#   'you',
#   ':)'],
#  ['@trisha1234',
#   'Beautiful',
#   'edit',
#   ',',
#   'Trish',
#   '!',
#   ':)',
#   'Loved',
#   'it',
#   '!',
#   '♥'],
#  ['Gratefulness',
#   '=',
#   'Happiness',
#   ':)',
#   'Post',
#   'three',
#   'things',
#   "you're",
#   'grateful',
#   'for',
#   'today',
#   'in',
#   'the',
#   'comments'],
#  ['Love',
#   'to',
#   'wakeup',
#   'beside',
#   'her',
#   '&',
#   'have',
#   'some',
#   'real',
#   'dirty',
#   ',',
#   'dirty',
#   'sex',
#   ':-)',
#   'http://t.co/dPLYrlTjil'],
#  ['@literalwt',
#   'LMAOOO',
#   'SAME',
#   'its',
#   'so',
#   'hot',
#   '😤',
#   '😤',
#   'like',
#   'louis',
#   ':)',
#   "he's",
#   'so',
#   'hot',
#   '!',
#   '!',
#   '!'],
#  ['@MariaGM350',
#   'Just',
#   'gonna',
#   'throw',
#   'idea',
#   'at',
#   'you',
#   'cause',
#   'if',
#   "they're",
#   'bad',
#   'it',
#   'will',
#   'inspire',
#   'you',
#   'to',
#   'think',
#   'of',
#   'something',
#   'much',
#   'better',
#   '.',
#   ':-)'],
#  ['#FF',
#   'The',
#   'Best',
#   'Twoofs',
#   'to',
#   'follow',
#   'have',
#   'a',
#   'GR8',
#   'wkend',
#   ':)',
#   '@allpawone',
#   '@Hungry_Hounds',
#   '@DDWalks',
#   '@HealthyHounds4U',
#   '@pawsforawalk',
#   'http://t.co/fIYPR3t2Ai'],
#  ['@cinnamoniboni',
#   'I',
#   'wish',
#   'I',
#   'could',
#   '!',
#   'Maybe',
#   'one',
#   'year',
#   ':)'],
#  ['hey', 'guys', '!', 'how', 'are', 'you', '?', ':)'],
#  ['I',
#   'think',
#   'I',
#   'need',
#   'to',
#   'go',
#   'to',
#   'bed',
#   'kind',
#   'of',
#   'exhausted',
#   'good',
#   'night',
#   'twitter',
#   ':)'],
#  ['@renukaVyavahare',
#   'Thank',
#   'you',
#   'so',
#   'much',
#   '..',
#   'So',
#   'glad',
#   'you',
#   'liked',
#   'it',
#   '..',
#   ':-)'],
#  ['It', 'will', 'all', 'get', 'better', 'in', 'time', '.', ':)'],
#  ['@Chelt52',
#   'Kind',
#   'words',
#   '-',
#   'thank',
#   'you',
#   'very',
#   'much',
#   '!',
#   "It's",
#   '@SueRyderLCH',
#   'that',
#   'does',
#   'so',
#   'much',
#   'good',
#   'in',
#   'the',
#   '#Cheltenham',
#   'area',
#   ':)'],
#  ['Hi',
#   'beautiful',
#   'follow',
#   'me',
#   'please',
#   '?',
#   ':)',
#   '@iggyazalea',
#   '@lanadelrey',
#   '@megannicole',
#   '@madisonellebeer',
#   '@tiffanyalvord',
#   '$',
#   '9'],
#  ['@astro_lass',
#   'They',
#   'weren',
#   '’',
#   't',
#   'kale',
#   'crisps',
#   ':-)',
#   'Why',
#   'ruin',
#   'a',
#   'good',
#   'thing',
#   '?'],
#  ['Hi',
# ...
#   '@inspchin',
#   '@koeitecmoeurope',
#   '@TanikoHorigome',
#   '@GoldxFierce',
#   '@Kronin1',
#   '@Addictrian',
#   '@chako33',
#   '@MatthewRumple',
#   'thx',
#   'Tobi-bro',
#   '!',
#   ':D'],
#  ['@nikimcglynn',
#   'How',
#   'good',
#   'is',
#   'that',
#   '!',
#   'I',
#   'think',
#   'it',
#   'was',
#   'my',
#   'first',
#   'ISP',
#   'too',
#   '!',
#   ':)'],
#  ['@tessasmith4evr',
#   '@BlueBellEMS',
#   "we'll",
#   'steel',
#   'some',
#   'from',
#   'the',
#   '@BlueBellEMS',
#   'next',
#   'Wednesday',
#   'and',
#   'see',
#   'what',
#   "it's",
#   'like',
#   '!',
#   ':)'],
#  ['hey', 'there', ':)'],
#  ['@camerondallas',
#   'definitely',
#   'loves',
#   'making',
#   'people',
#   'smile',
#   'cause',
#   'I',
#   'swear',
#   'since',
#   'I',
#   'met',
#   'him',
#   'earlier',
#   ',',
#   'I',
#   "haven't",
#   'stopped',
#   'smiling',
#   ':)',
#   'i',
#   'love',
#   'you',
#   'cam',
#   '😭',
#   '❤',
#   '️'],
#  ['@SabihaMahmoud',
#   '...',
#   'except',
#   'for',
#   'her',
#   'Lord',
#   ',',
#   "masha'Allah",
#   ':)'],
#  ['@NeilWhoreAnn',
#   'some',
#   'French',
#   'fans',
#   'made',
#   'a',
#   'movie',
#   'about',
#   'the',
#   'WWAT',
#   'in',
#   'France',
#   'last',
#   'year',
#   'with',
#   'our',
#   'videos',
#   'and',
#   'photos',
#   ':)'],
#  ['@max_pen1',
#   'It',
#   'has',
#   'been',
#   'fixed',
#   ',',
#   'thanks',
#   'for',
#   'your',
#   'feedback',
#   ':)'],
#  ['Thanks',
#   'to',
#   'everyone',
#   'who',
#   'came',
#   'to',
#   'the',
#   'stream',
#   ':D',
#   'Hope',
#   'you',
#   'guys',
#   'enjoyed',
#   '.',
#   'Night',
#   'all',
#   '!'],
#  ['@siddichan', '@Twitch', 'YAAAAAAAAY', 'thx', ':)'],
#  ['Looking',
#   'forward',
#   'to',
#   'reviewing',
#   'ours',
#   ':-)',
#   'https://t.co/y8SUBXjqXk'],
#  ['Thank', 'you', 'Beiruting', ':)'],
#  ['@coolkidsftnjh', 'fback', '?', ':)'],
#  ['Thanks',
#   'for',
#   'updating',
#   'your',
#   'profile',
#   'page',
#   '@AlexaPoppe',
#   ':-)',
#   'http://t.co/JK3NSXIRMe'],
#  ['Lovely', 'coffee', ':)', '@CoffeesToGo1'],
#  ["Here's",
#   'a',
#   'cute',
#   'panda',
#   'to',
#   'make',
#   'your',
#   'day',
#   '!',
#   ':)',
#   'http://t.co/zCaWqrjSvr',
#   'http://t.co/FuZNhjGWD7'],
#  ['@x0lovestephi', 'thank', 'you', 'eonnie', ':)', ')'],
#  ['@stokebrisbane',
#   'Hi',
#   '!',
#   'Saw',
#   'who',
#   'u',
#   'follow',
#   'and',
#   'thought',
#   'u',
#   'might',
#   'like',
#   '"',
#   'Dark',
#   '"',
#   'https://t.co/CFl0s5hwWw',
#   '.',
#   'Plz',
#   'let',
#   'us',
#   'know',
#   'what',
#   'u',
#   'think',
#   ':)'],
#  ['@Polished_teeth',
#   'my',
#   'favourite',
#   'too',
#   '!',
#   ':)',
#   '@ciatelondon',
#   'Cream',
#   'Soda',
#   ':)'],
#  ['I',
#   'love',
#   'my',
#   'body',
#   ',',
#   'when',
#   "it's",
#   'fuller',
#   ',',
#   'and',
#   'shit',
#   ',',
#   'even',
#   'when',
#   "it's",
#   'not',
#   'lol',
#   '.',
#   "I'm",
#   'just',
#   'happy',
#   'to',
#   'be',
#   'healthy',
#   ':)',
#   'happy',
#   'to',
#   'be',
#   'happy',
#   '..',
#   '💓'],
#  ['Rettweet', ':-)', 'http://t.co/l6T0rx7bEf'],
#  ['@DianaaOrtizz',
#   'the',
#   'real',
#   'MVG',
#   '(',
#   'MOST',
#   'VALUABLE',
#   'GIRLFRIEND',
#   ')',
#   'for',
#   'staying',
#   'up',
#   'with',
#   'me',
#   'till',
#   'the',
#   'Madrid',
#   'game',
#   'starts',
#   ':-)'],
#  ['@OLX_OHayoung96', 'sore', 'ya', ':)'],
#  ['@tmhcuddly',
#   "I'm",
#   'so',
#   'excited',
#   ',',
#   'we',
#   'should',
#   'definitely',
#   'meet',
#   'up',
#   ':)'],
#  ['@morriskid',
#   'are',
#   'you',
#   'coming',
#   'to',
#   'Bergerac',
#   '?',
#   'Have',
#   'the',
#   'first',
#   'team',
#   'left',
#   'any',
#   'u21',
#   "'",
#   's',
#   "I'd",
#   'know',
#   'of',
#   '?',
#   '#checking',
#   'for',
#   'chants',
#   ':-)'],
#  ['@rizwanism',
#   ':)',
#   'just',
#   'a',
#   'choice',
#   'of',
#   'food',
#   '.',
#   'Left',
#   'to',
#   'the',
#   'individuals',
#   '.'],
#  ['@VickiCartagena',
#   'The',
#   'episode',
#   'is',
#   'excellent',
#   'so',
#   'far',
#   '.',
#   ':-)',
#   'I',
#   'love',
#   'Adam',
#   "Beach's",
#   'movies',
#   '&',
#   'shows',
#   '.',
#   "I'm",
#   'looking',
#   'forward',
#   'to',
#   'seeing',
#   'Suicide',
#   'Squad',
#   'next',
#   'year'],
#  ['Growing',
#   'very',
#   'fond',
#   'of',
#   'Christopher',
#   ',',
#   "didn't",
#   'like',
#   'him',
#   'initially',
#   'because',
#   'he',
#   'was',
#   'cocky',
#   'and',
#   "didn't",
#   'really',
#   'prove',
#   'it',
#   'but',
#   'his',
#   "attitude's",
#   'improving',
#   ':D'],
#  ['@GlenOcsko',
#   'sounds',
#   'good',
#   '!',
#   'Can',
#   'you',
#   'DM',
#   'me',
#   'your',
#   'email',
#   'address',
#   '?',
#   'Will',
#   'suggest',
#   'some',
#   'dates',
#   'for',
#   'a',
#   'coffee',
#   '!',
#   ':)'],
#  ['@forlodge1', 'It', 'is', 'indeed', '-', 'many', 'thanks', ':-)'],
#  ['Just',
#   'smile',
#   'even',
#   'your',
#   'in',
#   'Pain',
#   ':)',
#   'http://t.co/AxTiqf0xek'],
#  ['Hi', 'happys', '!', '!', ':)', 'http://t.co/AGiLlxJdbi'],
#  ['Funny',
#   '.',
#   'Intelligent',
#   ',',
#   'strong',
#   'and',
#   'funny',
#   '.',
#   'Just',
#   'funny',
#   '...',
#   ':-)',
#   'https://t.co/IqJwYRF52C'],
#  ['Hello',
#   ':)',
#   'Get',
#   'Youth',
#   'Job',
#   'Opportunities',
#   'follow',
#   '>',
#   '>',
#   '@tolajobjobs',
#   '@me1campbell'],
#  ['@mokwepa', 'no', ',', 'other', 'than', 'it', 'using', 'Cs', ':)'],
#  ['you',
#   'ever',
#   'watch',
#   'certain',
#   "people's",
#   'snapchat',
#   'over',
#   'and',
#   'over',
#   'again',
#   ',',
#   'bc',
#   'i',
#   'know',
#   'i',
#   'do',
#   ':-)',
#   ')',
#   ')'],
#  ['@IbnNabih1', "that's", 'all', 'ok', 'I', 'know', 'your', 'busy', ':)'],
#  ['Last', '2', 'exams', ':)'],
#  ['forgot', 'u', 'were', 'up', '.', ':)', ')', ')', 'https://t.co/Or6eATWDjm'],
#  ['Fun', 'fact', ':', 'I', 'love', 'meeting', 'new', 'people', ':)'],
#  ['@jaseygalore',
#   'I',
#   'know',
#   'the',
#   'home-based',
#   'office',
#   'busy',
#   'feeling',
#   ':-)',
#   'Pity',
#   'about',
#   'your',
#   'knee',
#   '-',
#   'what',
#   'happened',
#   '?'],
#  ['SALE',
#   'FLEUR',
#   'DRESS',
#   'CREAM',
#   '#Readystock_hijabmart',
#   'IDR',
#   '325.000',
#   '=',
#   '=',
#   '=',
#   '>',
#   'IDR',
#   '200.000',
#   ':)',
#   'http://t.co/AGp51NQMbS'],
#  ['@pprabha014', 'Thankyou', ':)'],
#  ['@fernandeznoemi4',
#   'follow',
#   '@jnlazts',
#   '&',
#   'http://t.co/RCvcYYO0Iq',
#   'follow',
#   'u',
#   'back',
#   ':)'],
#  ['Is',
#   'Tompolo',
#   'meeting',
#   'aimed',
#   'at',
#   'stopping',
#   'the',
#   'sale',
#   'of',
#   'the',
#   'oil',
#   'that',
#   'we',
#   'cannot',
#   'find',
#   'buyers',
#   'for',
#   '?',
#   ':D'],
#  ['@Centerfxld',
#   "that's",
#   'true',
#   ',',
#   '@johngreen',
#   "doesn't",
#   'disappoint',
#   '!',
#   'Looking',
#   'forward',
#   'to',
#   'Paper',
#   'Towns',
#   '?',
#   ':)'],
#  ["That's",
#   'all',
#   'I',
#   'need',
#   'to',
#   'know',
#   ',',
#   'is',
#   'that',
#   'everything',
#   'is',
#   'going',
#   'to',
#   'be',
#   'okay',
#   ':-)'],
#  ['@LTBeautyBlog',
#   '@FDNCoffee',
#   'I',
#   'say',
#   'less',
#   'slacking',
#   '&',
#   'getting',
#   'cracking',
#   ':)'],
#  ['@JulieWestern',
#   'I',
#   "don't",
#   'know',
#   'the',
#   'name',
#   'but',
#   'it',
#   'is',
#   'particularly',
#   'striking',
#   '.',
#   'Happy',
#   'days',
#   ':)'],
#  ['@misshollylou',
#   'Hey',
#   ',',
#   "here's",
#   'your',
#   'invite',
#   'to',
#   'join',
#   'Scope',
#   'as',
#   'an',
#   'influencer',
#   ':)',
#   'http://t.co/ipJ2yOiGet'],
#  ['@DeewaniVeronica', '31', '*', 'My', 'Bad', 'Mam', ':p'],
#  ['@FrancesBeeton',
#   'Lovely',
#   'looking',
#   'cake',
#   ',',
#   'bet',
#   'it',
#   'tastes',
#   'good',
#   'too',
#   ':-)'],
#  ['FeyTyaz', 'Follback', 'ya', ':)'],
#  ['@dalenaha1',
#   'so',
#   'I',
#   'found',
#   'this',
#   'last',
#   'night',
#   ',',
#   'lets',
#   'just',
#   'say',
#   'there',
#   'was',
#   'an',
#   'instant',
#   'stiffening',
#   'of',
#   'my',
#   'interest',
#   ':)',
#   'https://t.co/sw5O1Bz4y9'],
#  ['Rettweet', ':-)', 'http://t.co/zBOvLw0y5S'],
#  ['@CHUBANHES', 'fback', '?', ':)'],
#  ['Rettweet', ':-)', 'http://t.co/CGTjR664Kj'],
#  ['ricky_febs', 'Follback', 'ya', ':)'],
#  ['Got',
#   'Secrets',
#   'of',
#   'Grindea',
#   ',',
#   'Courier',
#   'of',
#   'the',
#   'Crypts',
#   'and',
#   'possibly',
#   'some',
#   'Arma',
#   '3',
#   'to',
#   'record',
#   'today',
#   '...',
#   'Gosh',
#   '!',
#   'And',
#   'a',
#   'new',
#   'game',
#   'that',
#   'looks',
#   'like',
#   'Limbo',
#   ':)'],
#  ['@siaramelatienza',
#   'follow',
#   '@jnlazts',
#   '&',
#   'http://t.co/RCvcYYO0Iq',
#   'follow',
#   'u',
#   'back',
#   ':)'],
#  ['@MyriadPhoto',
#   'thanks',
#   'for',
#   'retweeting',
#   '@madsenjewellery',
#   'orchard',
#   'art',
#   'show',
#   ',',
#   'have',
#   'a',
#   'super',
#   'weekend',
#   ':)'],
#  ['Karachi',
#   'ka',
#   'Venice',
#   'after',
#   'rains',
#   ':)',
#   '@rizz_javaid',
#   '“',
#   '@JaagAlerts',
#   ':',
#   'Several',
#   'parts',
#   'of',
#   'Karachi',
#   'witness',
#   'accumulated',
#   'rain',
#   'water',
#   ',',
#   'http://t.co/Wionr1evBo',
#   '”'],
#  ['maroon',
#   'cocktail',
#   'dresses',
#   'http://t.co/Ioj5YzNRwu',
#   '#MidiDresses',
#   'for',
#   '@filipinaniah',
#   ':)',
#   'http://t.co/Vj1U5fIzBw'],
#  ['@IamPatmae_', 'fback', 'po', '?', ':)'],
#  ['0-100', 'real', 'quick', ':)'],
#  ['@Iron_Vein',
#   'Morning',
#   '!',
#   ':',
#   ')',
#   'Mine',
#   'is',
#   '1100D',
#   '.',
#   'Usually',
#   'auto-focus',
#   '.',
#   'I',
#   'only',
#   'use',
#   'manual',
#   'for',
#   'really',
#   'close',
#   'up',
#   'like',
#   'shooting',
#   'veins',
#   'on',
#   'crackle',
#   'glaze',
#   '.',
#   ':)'],
#  ['the', 'new', 'layout', 'looks', 'bomb', '!', ':-)', '-', 'g'],
#  ['Thanks',
#   'for',
#   'connecting',
#   '@garrowlscq',
#   'Hope',
#   "you're",
#   'having',
#   'an',
#   'Great',
#   'Day',
#   '!',
#   'Have',
#   'a',
#   'social',
#   '/',
#   'website',
#   'question',
#   '?',
#   'Just',
#   'ask',
#   ':-)'],
#  ['@Tweetnesian', 'pake', ':)'],
#  ['@gabrielaliuw',
#   'hi',
#   'we',
#   'made',
#   'some',
#   'changes',
#   'in',
#   'our',
#   'design',
#   ',',
#   'hope',
#   'you',
#   'like',
#   'it',
#   ':)',
#   'https://t.co/EXt098Yq1b'],
#  ['joim',
#   'me',
#   'while',
#   'I',
#   'feed',
#   'the',
#   'troops',
#   '.',
#   ':)',
#   'https://t.co/ZlcsRuUpPY',
#   'via',
#   '@audioBoom'],
#  ['Any',
#   'brands',
#   'wanting',
#   'me',
#   'to',
#   'review',
#   'BEAUTY',
#   'products',
#   'on',
#   'my',
#   'blog',
#   '?',
#   'mail',
#   'me',
#   'at',
#   ':',
#   'ladolcevitainluxembourg@hotmail.com',
#   '#prrequest',
#   '#journorequest',
#   ':)'],
#  ['The_MadStork', 'Follback', 'ya', ':)'],
#  ['@SSalchli', 'Good', 'luck', ',', 'Shaun', '!', ':)'],
#  ['@madziucha_5', 'yes', 'he', 'is', ':)'],
#  ['Anyone',
#   'who',
#   'wants',
#   'to',
#   'be',
#   'added',
#   'to',
#   'the',
#   'bot',
#   'just',
#   'DM',
#   'me',
#   '!',
#   '!',
#   ':)',
#   '#bot'],
#  ['@ChloeGMoretz',
#   'Chloe',
#   'I',
#   'watched',
#   '"',
#   'Let',
#   'me',
#   'in',
#   '"',
#   'yesterday',
#   'and',
#   'you',
#   'were',
#   'really',
#   'awesome',
#   '!',
#   'Really',
#   'talented',
#   'and',
#   'intelligent',
#   'actress',
#   ',',
#   'beautiful',
#   'too',
#   '!',
#   ':)'],
#  ['@hesfallenangel',
#   'could',
#   'i',
#   'get',
#   'some',
#   'free',
#   'solo',
#   'dms',
#   '?',
#   'Any',
#   'to',
#   'give',
#   'away',
#   '?',
#   ':)',
#   'xoxo'],
#  ['@TripVerse',
#   '@outboundapp',
#   'thanks',
#   'for',
#   'sharing',
#   '!',
#   'Wishing',
#   'you',
#   'a',
#   'wicked',
#   'weekend',
#   ':)'],
#  ['Hola',
#   'juan',
#   '..',
#   'sending',
#   'you',
#   'a',
#   'big',
#   'Hi',
#   'from',
#   'Houston',
#   'tx',
#   '!',
#   ':)',
#   "I've",
#   'been',
#   'a',
#   'fan',
#   'of',
#   'jenni',
#   'and',
#   'the',
#   'family',
#   'for',
#   "year's",
#   '.',
#   'I',
#   'stumble',
#   'upon',
#   'a',
#   'video',
#   'of',
#   'you'],
#  ['@padaleckbye', '.', 'No', 'prob.nice', 'choker', 'btw', ':)'],
#  ['@seoulsjin', '@seouljins', 'seouljins', ':)', 'both', 'are', 'fine', 'tbh'],
#  ['Photoset',
#   ':',
#   'sadomasochistsparadise',
#   ':',
#   'Wynter',
#   'bottoms',
#   '-',
#   'and',
#   'an',
#   'outtake',
#   ':)',
#   'Sadomasochist',
#   '’',
#   's',
#   'Paradise',
#   'Cuties',
#   'http://t.co/GNW1lwjFK1'],
#  ['You', 'make', 'my', 'day', 'by', 'just', 'smiling', ':)'],
#  ['@ghostkidluke', 'fback', '?', ':)'],
#  ['@itsRebeccaRayne', ':D', 'ty', 'bby', '!'],
#  ['Please',
#   'enjoy',
#   'this',
#   'clip',
#   'of',
#   'me',
#   'losing',
#   'my',
#   'shit',
#   'during',
#   'cypher',
#   ':)',
#   'http://t.co/8FIyPQ6kkn'],
#  ['@athrawestokio',
#   '@AdeccoWaytoWork',
#   '@AdeccoJapan',
#   'next',
#   'week',
#   ',',
#   'i',
#   'will',
#   'be',
#   'at',
#   'my',
#   'office',
#   '!',
#   'so',
#   'lets',
#   'go',
#   ':)'],
#  ['@DanielCWest', 'thank', 'you', 'for', 'following', 'me', ':D'],
#  ['Stats',
#   'for',
#   'the',
#   'day',
#   'have',
#   'arrived',
#   '.',
#   '2',
#   'new',
#   'followers',
#   'and',
#   'NO',
#   'unfollowers',
#   ':)',
#   'via',
#   'http://t.co/e644DJI0zw',
#   '.'],
#  ['@purehaire', 'Amen', '.', 'Thanks', ':)'],
#  ['Hi',
#   'BAM',
#   '!',
#   '@BarsAndMelody',
#   'Can',
#   'you',
#   'follow',
#   'my',
#   'bestfriend',
#   '@969Horan696',
#   '?',
#   'She',
#   'loves',
#   'you',
#   'a',
#   'lot',
#   ':)',
#   'See',
#   'you',
#   'in',
#   'Warsaw',
#   '<3',
#   'Love',
#   'you',
#   '<3',
#   'x32'],
#  ['@shyayen',
#   'follow',
#   '@jnlazts',
#   '&',
#   'http://t.co/RCvcYYO0Iq',
#   'follow',
#   'u',
#   'back',
#   ':)'],
#  ['@DrenchinWine', '@2fai', '@Chompu_Kusuma', 'paper', 'girl', ':D'],
#  ['@gculloty87',
#   'I',
#   'know',
#   'would',
#   'of',
#   'been',
#   'lovely',
#   'to',
#   'have',
#   'her',
#   'in',
#   'that',
#   'pic',
#   ':)',
#   ')',
#   'x'],
#  ['@adnanCad',
#   'Planted',
#   'people',
#   'are',
#   'allowed',
#   'to',
#   'do',
#   'any',
#   'thing',
#   'and',
#   'every',
#   'thing',
#   ':p'],
#  ['@mRpOrTeR7',
#   '"',
#   'This',
#   'Corner',
#   '"',
#   'is',
#   'so',
#   'fucking',
#   'Dope',
#   '!',
#   '!',
#   'Getting',
#   'addicted',
#   'to',
#   'it',
#   '..',
#   'Great',
#   'Job',
#   ':D'],
#  ['My', 'bby', 'gurl', ':)', 'http://t.co/S0IiU35MWw'],
#  ['Hey', 'hey', ':D'],
#  ['@NickTheBullsFan',
#   '@CashNastyGaming',
#   'still',
#   'suck',
#   'at',
#   'editing',
#   'but',
#   'if',
#   'this',
#   'turns',
#   'into',
#   'something',
#   'special',
#   'I',
#   'owe',
#   'it',
#   'to',
#   'you',
#   'guys',
#   ':)'],
#  ['@ayokejkt',
#   'Visit',
#   'my',
#   'blog',
#   'http://t.co/UzOAqroWKx',
#   'thanks',
#   ':D'],
#  ['@daannymoncada',
#   '@breannelaflare',
#   "YOU'RE",
#   'UGLY',
#   'DANIEL',
#   ',',
#   'is',
#   'it',
#   'good',
#   'ape',
#   '?',
#   ':)'],
#  ['Happy',
#   'bday',
#   '@Cinemainmygenes',
#   'Saar',
#   '...',
#   'Have',
#   'a',
#   'great',
#   'year',
#   'ahead',
#   '...',
#   ':)'],
#  ['@LucyLu_xx',
#   'Thought',
#   'you',
#   'might',
#   '!',
#   'I',
#   'saw',
#   'it',
#   'and',
#   'I',
#   'loved',
#   'the',
#   'verse',
#   '.',
#   'The',
#   'butterfly',
#   'part',
#   'was',
#   'just',
#   'a',
#   'bonus',
#   ':)',
#   '.'],
#  ['Thank',
#   'you',
#   ':-)',
#   ')',
#   ')',
#   'OK',
#   'Have',
#   'fun',
#   '!',
#   '!',
#   '@anvy2446',
#   '@4HUMANITEEs',
#   '@SexyAF12',
#   '@kikbella',
#   '@adasamper',
#   '@RachelLFilsoof',
#   'Enjoy',
#   'day',
#   'u',
#   'all',
#   'http://t.co/5Y5OAESAzv'],
#  ['well', '.', 'good', 'morning', '.', ':D'],
#  ['@palakspatel', 'would', 'you', 'follow', 'me', '?', ':)'],
#  ['Busy',
#   ',',
#   'productive',
#   'day',
#   'filled',
#   'with',
#   'a',
#   'few',
#   'tears',
#   ',',
#   'but',
#   'hours',
#   'and',
#   'hours',
#   'of',
#   'laughter',
#   '.',
#   'Today',
#   'was',
#   'a',
#   'good',
#   'day',
#   '.',
#   ':)'],
#  ['@17bljpk',
#   'hi',
#   '.',
#   'You',
#   'have',
#   '5sos',
#   'tickets',
#   '?',
#   '?',
#   'Dm',
#   'me',
#   ':)'],
#  ['Yummmyyy', '...', ':-)', '—', 'eating', 'dosa'],
#  ['@bbcdoctorwho', 'so', 'do', 'I', ':D'],
#  ['@MegLovesGames',
#   'its',
#   'probably',
#   'easier',
#   'to',
#   'meet',
#   'at',
#   'the',
#   'station',
#   '?',
#   'Unless',
#   'you',
#   'particularly',
#   'want',
#   'to',
#   'show',
#   'me',
#   'your',
#   'house',
#   '?',
#   ':)'],
#  ['A', 'Huge', '&', 'Warm', 'Welcome', 'to', '@VodkaBlond', ':-)', ')'],
#  ['ACHI',
#   '!',
#   '!',
#   '!',
#   'Im',
#   'busy',
#   'next',
#   'week',
#   'because',
#   'of',
#   'our',
#   'exams',
#   '.',
#   'Hope',
#   'you',
#   'understand',
#   'that',
#   'I',
#   'cant',
#   'tweet',
#   'youuu',
#   ',',
#   'Bawi',
#   'ako',
#   'queenesther',
#   '!',
#   ':)',
#   '@esthercarodan'],
#  ['@LeeMcKenzieTV', 'Looking', 'sharp', ':-)'],
#  ['@xWinnerMino',
#   'yess',
#   'im',
#   '1',
#   'year',
#   'younger',
#   'than',
#   'u',
#   ':-)',
#   'no',
#   'wonder',
#   'youre',
#   'huge',
#   'boy'],
#  ["I'm",
#   'playing',
#   'Brain',
#   'Dots',
#   ':',
#   ')',
#   '#BrainDots',
#   'http://t.co/ilDzDRHf9d',
#   'http://t.co/VTXNFCPFuI'],
#  ['Ha', '!', 'All', 'in', 'one', 'picture', ':-)', 'http://t.co/IgLPwLvSfz'],
#  ['@Galatasaray', '@Podolski10', 'is', 'ready', ':)', '#Poldi', '#Cimbom'],
#  ['@LuvSocial_Media', 'Thanks', 'for', 'the', 'share', ':)'],
#  ['@LOSTCHILLHORAN', 'fback', '?', ':)'],
#  ['@24f567234e3c410',
#   'follow',
#   '@jnlazts',
#   '&',
#   'http://t.co/RCvcYYO0Iq',
#   'follow',
#   'u',
#   'back',
#   ':)'],
#  ['@graphure', 'Happy', 'birthday', 'buddy', '!', ':D'],
#  ['@waterrat77', 'Thank', 'you', ':-)'],
#  ['*',
#   'sigh',
#   '*',
#   '"',
#   '@Whykaysbeauty',
#   ':',
#   'Bruhhh',
#   '“',
#   '@Dopjones',
#   ':',
#   'Call',
#   'me',
#   'daddy',
#   'one',
#   'more',
#   'time',
#   ':)',
#   '”',
#   '"'],
#  ...]

# %%
tweet_tokens = twitter_samples.tokenized('positive_tweets.json')
print(pos_tag(tweet_tokens[0]))
# Out:
# [('#FollowFriday', 'JJ'), ('@France_Inte', 'NNP'), ('@PKuchly57', 'NNP'), ('@Milipol_Paris', 'NNP'), ('for', 'IN'), ('being', 'VBG'), ('top', 'JJ'), ('engaged', 'VBN'), ('members', 'NNS'), ('in', 'IN'), ('my', 'PRP$'), ('community', 'NN'), ('this', 'DT'), ('week', 'NN'), (':)', 'NN')]

# %%
def lemmatize_sentence(tokens):
    lemmatizer = WordNetLemmatizer()
    lemmatized_sentence = []
    for word, tag in pos_tag(tokens):
        if tag.startswith('NN'):
            pos = 'n'
        elif tag.startswith('VB'):
            pos = 'v'
        else:
            pos = 'a'
        lemmatized_sentence.append(lemmatizer.lemmatize(word, pos))
    return lemmatized_sentence

print(lemmatize_sentence(tweet_tokens[0]))
# Out:
# ['#FollowFriday', '@France_Inte', '@PKuchly57', '@Milipol_Paris', 'for', 'be', 'top', 'engage', 'member', 'in', 'my', 'community', 'this', 'week', ':)']

# %%
import re, string

def remove_noise(tweet_tokens, stop_words = ()):

    cleaned_tokens = []

    for token, tag in pos_tag(tweet_tokens):
        token = re.sub('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+#]|[!*\(\),]|'\
                       '(?:%[0-9a-fA-F][0-9a-fA-F]))+','', token)
        token = re.sub("(@[A-Za-z0-9_]+)","", token)

        if tag.startswith("NN"):
            pos = 'n'
        elif tag.startswith('VB'):
            pos = 'v'
        else:
            pos = 'a'

        lemmatizer = WordNetLemmatizer()
        token = lemmatizer.lemmatize(token, pos)

        if len(token) > 0 and token not in string.punctuation and token.lower() not in stop_words:
            cleaned_tokens.append(token.lower())
    return cleaned_tokens

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')

print(remove_noise(tweet_tokens[0], stop_words))
# Out:
# ['#followfriday', 'top', 'engage', 'member', 'community', 'week', ':)']

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')

#print(remove_noise(tweet_tokens[0], stop_words))

positive_tweet_tokens = twitter_samples.tokenized('positive_tweets.json')
negative_tweet_tokens = twitter_samples.tokenized('negative_tweets.json')

positive_cleaned_tokens_list = []
negative_cleaned_tokens_list = []

for tokens in positive_tweet_tokens:
    positive_cleaned_tokens_list.append(remove_noise(tokens, stop_words))

for tokens in negative_tweet_tokens:
    negative_cleaned_tokens_list.append(remove_noise(tokens, stop_words))

# %%
def get_all_words(cleaned_tokens_list):
    for tokens in cleaned_tokens_list:
        for token in tokens:
            yield token

all_pos_words = get_all_words(positive_cleaned_tokens_list)

# %%
from nltk import FreqDist

freq_dist_pos = FreqDist(all_pos_words)
print(freq_dist_pos.most_common(10))
# Out:
# [(':)', 3691), (':-)', 701), (':d', 658), ('thanks', 388), ('follow', 357), ('love', 333), ('...', 290), ('good', 283), ('get', 263), ('thank', 253)]

# %%
def get_tweets_for_model(cleaned_tokens_list):
    for tweet_tokens in cleaned_tokens_list:
        yield dict([token, True] for token in tweet_tokens)

positive_tokens_for_model = get_tweets_for_model(positive_cleaned_tokens_list)
negative_tokens_for_model = get_tweets_for_model(negative_cleaned_tokens_list)

# %%
import random

positive_dataset = [(tweet_dict, "Positive")
                     for tweet_dict in positive_tokens_for_model]

negative_dataset = [(tweet_dict, "Negative")
                     for tweet_dict in negative_tokens_for_model]

dataset = positive_dataset + negative_dataset

random.shuffle(dataset)

train_data = dataset[:7000]
test_data = dataset[7000:]

# %%
dataset
# Out:
# [({'rain': True, 'today': True, 'boo': True, ':(': True}, 'Negative'),
#  ({'think': True, 'mess': True, 'ankle': True, ':(': True}, 'Negative'),
#  ({'oo': True,
#    'pre': True,
#    "i'm": True,
#    'sick': True,
#    ':(': True,
#    'huhu': True,
#    'sad': True,
#    'hahaha': True},
#   'Negative'),
#  ({'miss': True, 'tweet': True, 'spree': True, 'oh': True, ':(': True},
#   'Negative'),
#  ({':(': True, 'least': True, 'freeze': True, 'outside': True, 'right': True},
#   'Negative'),
#  ({'case': True,
#    'cat': True,
#    'video': True,
#    'mood': True,
#    'swear': True,
#    ':d': True},
#   'Positive'),
#  ({':(': True, 'okay': True, 'bad': True}, 'Negative'),
#  ({'phantasy': True,
#    'star': True,
#    'online': True,
#    '2': True,
#    'ip': True,
#    'issue': True,
#    'happy': True,
#    'could': True,
#    'finally': True,
#    'play': True,
#    'game': True,
#    '...': True,
#    'sad': True,
#    ':(': True},
#   'Negative'),
#  ({'idea': True, 'phone': True, 'arrange': True, ':)': True}, 'Positive'),
#  ({'fun': True,
#    'osaka': True,
#    'super': True,
#    'junior': True,
#    ':(': True,
#    'would': True,
#    'lovely': True,
#    'watch': True,
#    'comeback': True,
#    'stage': True,
#    'though': True},
#   'Negative'),
#  ({'upset': True,
#    'promise': True,
#    'us': True,
#    'free': True,
#    'ice': True,
#    'cream': True,
#    'mention': True,
#    'city': True,
#    'centre': True,
#    '#thatscold': True,
#    '#ubericecream': True,
#    ':(': True},
#   'Negative'),
#  ({"i'll": True,
#    'get': True,
#    'cement': True,
#    'cast': True,
#    'tomorrow': True,
#    ':(': True},
#   'Negative'),
#  ({':)': True}, 'Positive'),
#  ({'guys': True,
#    'add': True,
#    'kik': True,
#    'rhisfor': True,
#    '500': True,
#    '#kik': True,
#    '#hornykik': True,
#    '#bestoftheday': True,
#    '#chat': True,
#    '#snapme': True,
#    '#summer': True,
#    '#camsex': True,
#    ':(': True},
#   'Negative'),
#  ({'know': True,
#    'long': True,
#    'play': True,
#    '15': True,
#    'hour': True,
#    ':(': True},
#   'Negative'),
#  ({'happy': True,
#    'birthday': True,
#    'sunday': True,
#    ':)': True,
#    'hope': True,
#    'great': True,
#    'day': True,
#    'lot': True,
#    'pamper': True,
#    'love': True},
#   'Positive'),
#  ({'check': True,
#    'email': True,
#    'marketing': True,
#    '24/7': True,
#    'regret': True,
#    'buy': True,
#    ':)': True},
#   'Positive'),
#  ({'thanks': True,
#    'share': True,
#    'enjoy': True,
#    'app': True,
#    'wishing': True,
#    'wicked': True,
#    'weekend': True,
#    ':)': True},
#   'Positive'),
#  ({'great': True, 'work': True, 'matt': True, ':)': True}, 'Positive'),
#  ({'picture': True,
#    "i'd": True,
#    'like': True,
#    'see': True,
#    'obituary': True,
#    'advert': True,
#    ':)': True,
#    '#goofingaround': True,
#    '#madness': True,
#    '#mad': True,
#    '#bollywood': True,
#    '…': True},
#   'Positive'),
#  ({'omg': True, ':(': True, 'wish': True, 'come': True, 'spain': True},
#   'Negative'),
#  ({'ghost': True,
#    '#bae': True,
#    ':d': True,
#    '#love': True,
#    '#tagsforlikesapp': True,
#    '#instagood': True,
#    '#me': True,
#    '#smile': True,
#    '#follow': True,
#    '#cute': True,
#    '#photooftheday': True,
#    '#tbt': True,
#    '…': True},
#   'Positive'),
#  ({'yesss': True, 'sonaaaaaaa': True, 'beautifull': True, ':)': True},
#   'Positive'),
#  ({'thanks': True,
#    'recommendation': True,
#    'shiva': True,
#    ':)': True,
#    'happy': True,
#    'music': True,
#    'mp3': True,
#    'mobile': True,
#    'apps': True},
#   'Positive'),
#  ({'well': True,
#    'good': True,
#    'get': True,
#    'thing': True,
#    'way': True,
#    ':-)': True},
#   'Positive'),
#  ({'thank': True, ':)': True}, 'Positive'),
#  ({'another': True,
#    'gem': True,
#    'today': True,
#    'falcos': True,
#    'cool': True,
#    ':)': True,
#    '#supersmash': True},
#   'Positive'),
#  ({"we've": True,
#    'receive': True,
#    'payment': True,
#    'order': True,
#    'process': True,
#    ':)': True,
#    'thanks': True,
#    'shop': True,
#    'spree': True},
#   'Positive'),
#  ({'stomach': True, 'kill': True, ':(': True}, 'Negative'),
#  ({'word': True,
#    'big': True,
#    'site': True,
#    'get': True,
#    'changes': True,
#    'a-foot': True,
#    ':)': True,
#    '#website': True,
#    '#development': True,
#    '#revamp': True},
#   'Positive'),
#  ({'wish': True,
#    'go': True,
#    'ed': True,
#    'croke': True,
#    'park': True,
#    'today': True,
#    ':(': True},
#   'Negative'),
#  ({'kind': True, ':)': True}, 'Positive'),
#  ({"i'm": True,
#    'serious': True,
#    'one': True,
#    'amazing': True,
#    'submission': True,
#    'well': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({'want': True, 'white': True, 'french': True, 'bulldog': True, ':(': True},
#   'Negative'),
#  ({'frou': True,
#    'bad': True,
#    'thing': True,
#    'neither': True,
#    'vaccine': True,
#    'good': True,
#    '..': True,
#    ':(': True,
#    'learn': True,
#    'get': True,
#    'much': True,
#    'information': True},
#   'Negative'),
#  ({'look': True, 'like': True, ':(': True}, 'Negative'),
#  ({'one': True,
#    "japan's": True,
#    'pop': True,
#    'artist': True,
#    'become': True,
#    'follower': True,
#    'ig': True,
#    '...': True,
#    'nice': True,
#    ':)': True},
#   'Positive'),
#  ({'mess': True, 'big': True, 'time': True, ':(': True}, 'Negative'),
#  ({'nothing': True, 'bad': True, ':(': True}, 'Negative'),
#  ({'ahh': True, 'thank': True, 'much': True, ':)': True, 'xxx': True},
#   'Positive'),
#  ({'followed': True, 'thanks': True, 'please': True, ':(': True}, 'Negative'),
#  ({'tfw': True,
#    'boyfriend': True,
#    ':(': True,
#    'lol': True,
#    'jest': True,
#    'cooking': True,
#    'relaxes': True,
#    "i'm": True,
#    'sure': True,
#    "i'll": True,
#    'eat': True,
#    'lunch': True,
#    'tomorrow': True},
#   'Negative'),
#  ({"here's": True,
#    'selfie': True,
#    'tara': True,
#    'thanks': True,
#    'another': True,
#    'great': True,
#    'event': True,
#    '. . .': True,
#    '#happyfriday': True,
#    '#ff': True,
#    ':)': True},
#   'Positive'),
#  ({'download': True,
#    'uber': True,
#    'mobile': True,
#    'application': True,
#    'place': True,
#    'order': True,
#    ':)': True,
#    '#enjoy': True},
#   'Positive'),
#  ({'supreme': True,
#    'court': True,
#    'even': True,
#    'give': True,
#    'decision': True,
#    'sunny': True,
#    'leon': True,
#    'virgin': True,
#    ':p': True},
#   'Positive'),
#  ({'yasss': True,
#    'still': True,
#    'dont': True,
#    'get': True,
#    'pay': True,
#    'til': True,
#    'august': True,
#    '6th': True,
#    ':(': True,
#    'lol': True,
#    'hella': True,
#    'clothes': True,
#    'though': True},
#   'Negative'),
#  ({'hey': True,
#    'thanks': True,
#    'following': True,
#    ':)': True,
#    '#autofollow': True,
#    '#teamfollowback': True,
#    'via': True},
#   'Positive'),
#  ({'sorry': True, 'delay': True, 'naomi': True, ':(': True}, 'Negative'),
#  ({'yes': True,
#    'thats': True,
#    'good': True,
#    ':)': True,
#    'hope': True,
#    'news': True,
#    'dayz': True,
#    'game': True,
#    'preview': True},
#   'Positive'),
#  ({'message': True, '...': True, 'feed': True, 'catspjs': True, ':)': True},
#   'Positive'),
#  ({'yeah': True,
#    'really': True,
#    'shoulda': True,
#    'hippo': True,
#    'one': True,
#    ':)': True},
#   'Positive'),
#  ({'awwwww': True,
#    "i'm": True,
#    'sorry': True,
#    ':(': True,
#    'bet': True,
#    'look': True,
#    '<3': True,
#    '3': True},
#   'Negative'),
#  ({'aww': True,
#    "i've": True,
#    'already': True,
#    'leave': True,
#    'would': True,
#    'come': True,
#    'say': True,
#    'hey': True,
#    'see': True,
#    'sooner': True,
#    ':(': True,
#    'good': True,
#    'night': True,
#    'x': True},
#   'Negative'),
#  ({'💓': True,
#    '🚮': True,
#    '👯': True,
#    'definition': True,
#    'perfection': True,
#    'would': True,
#    'picture': True,
#    'next': True,
#    ':)': True},
#   'Positive'),
#  ({':(': True,
#    "we're": True,
#    'gonna': True,
#    'run': True,
#    'cali': True,
#    'w': True,
#    'woe': True,
#    ':/': True},
#   'Negative'),
#  ({'happy': True,
#    'friday': True,
#    'lovelies': True,
#    'great': True,
#    'day': True,
#    'lovely': True,
#    'weekend': True,
#    ':)': True,
#    '#friday': True,
#    '#smile': True,
#    '#weekend': True,
#    '#fridayfeeling': True},
#   'Positive'),
#  ({'aw': True, 'bb': True, ':(': True}, 'Negative'),
#  ({'thank': True,
#    'much': True,
#    'know': True,
#    'great': True,
#    'magical': True,
#    'detective': True,
#    '#jonathancreek': True,
#    'back': True,
#    'tv': True,
#    'set': True,
#    'dvr': True,
#    ':)': True},
#   'Positive'),
#  ({'true': True, ':)': True}, 'Positive'),
#  ({'haha': True,
#    'thanks': True,
#    'man': True,
#    ':-)': True,
#    'fingers-crossed': True,
#    'win': True,
#    '’': True,
#    'delve': True,
#    'deep': True,
#    'htaccess': True,
#    'file': True},
#   'Positive'),
#  ({'lonely': True, ':(': True}, 'Negative'),
#  ({'oh': True,
#    ':(': True,
#    'hate': True,
#    'happen': True,
#    'get': True,
#    'sad': True},
#   'Negative'),
#  ({'stats': True,
#    'week': True,
#    'arrive': True,
#    '2': True,
#    'new': True,
#    'follower': True,
#    'unfollowers': True,
#    ':)': True,
#    'via': True},
#   'Positive'),
#  ({"i'm": True,
#    'go': True,
#    ':(': True,
#    'kailan': True,
#    'ba': True,
#    'may': True,
#    'tix': True,
#    'ka': True},
#   'Negative'),
#  ({'spend': True, 'friday': True, 'night': True, 'without': True, ':(': True},
#   'Negative'),
#  ({'morning': True,
#    'friend': True,
#    ':)': True,
#    'yesss': True,
#    'thats': True,
#    'way': True,
#    'roll': True,
#    ';)': True,
#    '#cam4': True},
#   'Positive'),
#  ({'#ff': True,
#    'wooftastic': True,
#    'twoofs': True,
#    'hope': True,
#    'supa': True,
#    'dupa': True,
#    'weekend': True,
#    ':)': True},
#   'Positive'),
#  ({'baby': True, 'boy': True, ':(': True}, 'Negative'),
#  ({'love': True,
#    ':)': True,
#    '#teenchoice': True,
#    '#choiceinternationalartist': True,
#    '#superjunior': True},
#   'Positive'),
#  ({"we're": True,
#    'go': True,
#    'moment': True,
#    ':(': True,
#    'percentage': True,
#    'ohh': True,
#    'please': True},
#   'Negative'),
#  ({'gorgeous': True, 'fun': True, "y'all": True, ':)': True}, 'Positive'),
#  ({'#ff': True,
#    'nyc': True,
#    'girl': True,
#    'must': True,
#    'follow': True,
#    ':-)': True},
#   'Positive'),
#  ({'live': True,
#    'northern': True,
#    'ireland': True,
#    ':)': True,
#    'sight': True,
#    'see': True},
#   'Positive'),
#  ({'big': True,
#    'hello': True,
#    "we've": True,
#    'send': True,
#    'email': True,
#    ':)': True},
#   'Positive'),
#  ({'great': True,
#    'reserve': True,
#    'windows': True,
#    '10': True,
#    ':)': True,
#    'mm': True},
#   'Positive'),
#  ({'vote': True,
#    '#brainchild': True,
#    '3': True,
#    'time': True,
#    'please': True,
#    'may': True,
#    'poem': True,
#    ':d': True},
#   'Positive'),
#  ({':(': True,
#    'like': True,
#    'fersuree': True,
#    'thing': True,
#    'yet': True,
#    'though': True},
#   'Negative'),
#  ({'penis': True, 'small': True, ':(': True}, 'Negative'),
#  ({'dare': True, 'run': True, 'corridor': True, ':-)': True}, 'Positive'),
#  ({'ahaha': True,
#    "i'm": True,
#    'lay': True,
#    'bed': True,
#    'like': True,
#    'whyyyyyy': True,
#    'pretty': True,
#    'wine': True,
#    'glass': True,
#    'suck': True,
#    ':(': True},
#   'Negative'),
#  ({'damn': True,
#    ':(': True,
#    'hope': True,
#    'u': True,
#    'feel': True,
#    'good': True,
#    'soon': True},
#   'Negative'),
#  ({'cry': True, 'watch': True, 'bigbang': True, 'tl': True, ':(': True},
#   'Negative'),
#  ({'awwww': True, 'thanks': True, ':-)': True}, 'Positive'),
#  ({'lovely': True,
#    'time': True,
#    'go': True,
#    'flow': True,
#    '#workinprogress': True,
#    'love': True,
#    'choose': True,
#    'colour': True,
#    ':)': True,
#    '…': True},
#   'Positive'),
#  ({'birthday': True, 'week': True, 'today': True, ':d': True}, 'Positive'),
#  ({'hi': True,
#    'hope': True,
#    'great': True,
#    'time': True,
#    'full': True,
#    'happiness': True,
#    ':)': True,
#    'love': True,
#    '...': True,
#    '79x': True},
#   'Positive'),
#  ({'walk': True,
#    'barely': True,
#    'accord': True,
#    ':)': True,
#    'good': True,
#    'hope': True,
#    'get': True,
#    'home': True,
#    'ok': True},
#   'Positive'),
#  ({'esnho': True,
#    'node': True,
#    '15': True,
#    'advanced': True,
#    'directx': True,
#    '11': True,
#    'shading': True,
#    'workshop': True,
#    'p2': True,
#    'uploaded': True,
#    'remove': True,
#    ':(': True},
#   'Negative'),
#  ({"i'm": True, 'sad': True, ':(': True}, 'Negative'),
#  ({"panic's": True,
#    'new': True,
#    'album': True,
#    'come': True,
#    '22nd': True,
#    ':(': True},
#   'Negative'),
#  ({'airport': True,
#    'picture': True,
#    'jongdae': True,
#    'hardly': True,
#    'see': True,
#    'tlists': True,
#    ':(': True},
#   'Negative'),
#  ({"i'm": True, 'manteca': True, ':(': True, 'visit': True, 'dad': True},
#   'Negative'),
#  ({'oh': True,
#    'bed': True,
#    'haha': True,
#    "can't": True,
#    'sleep': True,
#    'though': True,
#    'day': True,
#    'exciting': True,
#    ':)': True},
#   'Positive'),
#  ({'want': True,
#    'go': True,
#    'grandma': True,
#    "grandpa's": True,
#    'farm': True,
#    "there's": True,
#    'lot': True,
#    'cow': True,
#    'chicken': True,
#    'sheeps': True,
#    'horse': True,
#    'fruit': True,
#    'vegetable': True,
#    ':(': True,
#    'aww': True,
#    'help': True},
#   'Negative'),
#  ({'break': True,
#    'heart': True,
#    'cause': True,
#    "i'm": True,
#    'hard': True,
#    ':(': True},
#   'Negative'),
#  ({'thanks': True,
#    'working': True,
#    'way': True,
#    'overdue': True,
#    'literally': True,
#    'update': True,
#    'right': True,
#    'mice': True,
#    ':d': True},
#   'Positive'),
#  ({'hi': True, 'happys': True, ':)': True}, 'Positive'),
#  ({'happy': True, 'friday': True, ':-)': True}, 'Positive'),
#  ({'think': True, 'could': True, 'get': True, 'sponsor': True, ':)': True},
#   'Positive'),
#  ({'would': True,
#    'ever': True,
#    'consider': True,
#    'create': True,
#    'crash': True,
#    'course': True,
#    'video': True,
#    'computer': True,
#    'science': True,
#    'many': True,
#    'resource': True,
#    'school': True,
#    ':(': True},
#   'Negative'),
#  ({'wanna': True,
#    'go': True,
#    'favorite': True,
#    'spot': True,
#    'watch': True,
#    'sun': True,
#    'rise': True,
#    "that's": True,
#    'way': True,
#    'across': True,
#    'town': True,
#    ':(': True},
#   'Negative'),
#  ({'bring': True, 'key': True, ':(': True}, 'Negative'),
#  ({'look': True, 'gorgeous': True, ':)': True}, 'Positive'),
#  ({'everything': True, 'much': True, 'easy': True, 'back': True, ':(': True},
#   'Negative'),
#  ({'♛': True,
#    '》': True,
#    'love': True,
#    'much': True,
#    'beli̇eve': True,
#    'wi̇ll': True,
#    'follow': True,
#    'please': True,
#    'justi̇n': True,
#    ':(': True,
#    'x15': True,
#    '332': True,
#    'ｓｅｅ': True,
#    'ｍｅ': True},
#   'Negative'),
#  ({'hi': True,
#    'bam': True,
#    'follow': True,
#    'bestfriend': True,
#    'love': True,
#    'lot': True,
#    ':)': True,
#    'see': True,
#    'warsaw': True,
#    '<3': True,
#    'x31': True},
#   'Positive'),
#  ({'know': True,
#    'live': True,
#    'australia': True,
#    'talk': True,
#    'friend': True,
#    'cuz': True,
#    'like': True,
#    '4am': True,
#    'thanks': True,
#    'anyway': True,
#    ':)': True},
#   'Positive'),
#  ({'follow': True, ':)': True}, 'Positive'),
#  ({"i'm": True,
#    'look': True,
#    'influencers': True,
#    'app': True,
#    ':)': True,
#    'interested': True,
#    "here's": True,
#    'invite': True},
#   'Positive'),
#  ({'tiring': True, 'week': True, ':(': True, '#nathanielhinanakit': True},
#   'Negative'),
#  ({"i'm": True,
#    'sorry': True,
#    'people': True,
#    'shit': True,
#    'respect': True,
#    'personal': True,
#    'space': True,
#    ':(': True},
#   'Negative'),
#  ({'bring': True,
#    '#together': True,
#    '#friends': True,
#    '#family': True,
#    '#loveforfood': True,
#    '#foodforthought': True,
#    '#thoughtfortheday': True,
#    ':)': True},
#   'Positive'),
#  ({'hashtag': True, 'say': True, '...': True, ':)': True}, 'Positive'),
#  ({'first': True,
#    'leg': True,
#    'tour': True,
#    'go': True,
#    'well': True,
#    ':d': True,
#    '#music': True,
#    '#band': True,
#    '#rock': True,
#    '#magictrik': True,
#    '#tour': True},
#   'Positive'),
#  ({'sleep': True, 'good': True, "i'm": True, 'kaylas': True, ':(': True},
#   'Negative'),
#  ({'cry': True, ':(': True}, 'Negative'),
#  ({':(': True, 'could': True, 'snap': True, 'head': True}, 'Negative'),
#  ({'weh': True,
#    'think': True,
#    'sa': True,
#    'may': True,
#    'bank': True,
#    ':-(': True},
#   'Negative'),
#  ({'appreciate': True,
#    'follow': True,
#    'like': True,
#    'tweet': True,
#    ':)': True,
#    'dorset': True,
#    'beautiful': True,
#    'place': True},
#   'Positive'),
#  ({'thank': True,
#    'wonderful': True,
#    'feedback': True,
#    'sir': True,
#    'hope': True,
#    'see': True,
#    'soon': True,
#    ':)': True},
#   'Positive'),
#  ({'earth': True,
#    '2.0': True,
#    '...': True,
#    'yuppiieee': True,
#    ':)': True,
#    '#alienthought': True,
#    '#happyalien': True},
#   'Positive'),
#  ({'cheers': True, 'alice': True, ':)': True}, 'Positive'),
#  ({'hate': True,
#    'hot': True,
#    'weather': True,
#    ':(': True,
#    'graduation': True,
#    'ceremony': True,
#    'late': True,
#    'boy': True,
#    'gonna': True,
#    'wear': True,
#    'suit': True,
#    'everyones': True,
#    'go': True,
#    'die': True},
#   'Negative'),
#  ({'disk': True,
#    'management': True,
#    'since': True,
#    'nt4': True,
#    'iirc': True,
#    ':d': True,
#    'also': True,
#    'ux': True,
#    'refinement': True,
#    'zdps': True},
#   'Positive'),
#  ({'love': True, ':)': True}, 'Positive'),
#  ({'wew': True, 'ramos': True, 'ground': True, ':(': True}, 'Negative'),
#  ({'best': True, 'night': True, 'life': True, ':)': True}, 'Positive'),
#  ({'back': True,
#    'thnx': True,
#    'god': True,
#    "i'm": True,
#    'happy': True,
#    ':)': True},
#   'Positive'),
#  ({'guess': True,
#    "they'll": True,
#    'show': True,
#    'german': True,
#    'also': True,
#    'subtitle': True,
#    ':)': True},
#   'Positive'),
#  ({"ain't": True, 'gonna': True, 'follow': True, ':(': True}, 'Negative'),
#  ({'#followfriday': True,
#    'top': True,
#    'influencers': True,
#    'community': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({'trip': True,
#    'philly': True,
#    'december': True,
#    ':)': True,
#    "i'd": True,
#    'love': True,
#    'come': True,
#    'dude': True},
#   'Positive'),
#  ({'woohoo': True,
#    'welcome': True,
#    'aboard': True,
#    'lani': True,
#    'great': True,
#    'graze': True,
#    'us': True,
#    ':)': True},
#   'Positive'),
#  ({'stile': True, ':(': True}, 'Negative'),
#  ({'oh': True,
#    'plan': True,
#    'stream': True,
#    'halo': True,
#    'xbox': True,
#    'one': True,
#    'today': True,
#    ':(': True},
#   'Negative'),
#  ({'ill': True, 'soon': True, 'promise': True, ':(': True, 'waaah': True},
#   'Negative'),
#  ({'tv': True, 'game': True, 'kid': True, ':)': True, '#birthdaymonth': True},
#   'Positive'),
#  ({'♛': True,
#    '》': True,
#    'love': True,
#    'much': True,
#    'beli̇eve': True,
#    'wi̇ll': True,
#    'follow': True,
#    'please': True,
#    'justi̇n': True,
#    ':(': True,
#    'x15': True,
#    '330': True,
#    'ｓｅｅ': True,
#    'ｍｅ': True},
#   'Negative'),
#  ({'knowwwww': True, ':(': True}, 'Negative'),
#  ({':(': True}, 'Negative'),
#  ({'hi': True,
#    'emma': True,
#    ':-)': True,
#    'ask': True,
#    '#bellybutton': True,
#    '#innie': True,
#    '#outie': True},
#   'Positive'),
#  ({'yeey': True, ':d': True}, 'Positive'),
#  ({'im': True, 'hungry': True, ':(': True}, 'Negative'),
#  ({'hey': True, 'buddy': True, 'thinking': True, 'anything': True, ':)': True},
#   'Positive'),
#  ({'want': True,
#    'follow': True,
#    "that's": True,
#    'crazy': True,
#    ':(': True,
#    'please': True,
#    'love': True,
#    '(:': True,
#    '♡': True},
#   'Negative'),
#  ({'thanks': True, 'retweet': True, ':)': True}, 'Positive'),
#  ({'sorry': True,
#    'busy': True,
#    'arini': True,
#    'je': True,
#    'tak': True,
#    ':(': True},
#   'Negative'),
#  ({'ta': True, ':)': True}, 'Positive'),
#  ({'nice': True, ':-)': True}, 'Positive'),
#  ({'miss': True, ':-(': True}, 'Negative'),
#  ({'oh': True, 'okay': True, ':d': True, 'thanks': True}, 'Positive'),
#  ({'get': True, 'fuck': True, 'outta': True, ':d': True}, 'Positive'),
#  ({'think': True,
#    'need': True,
#    'go': True,
#    'bed': True,
#    'kind': True,
#    'exhausted': True,
#    'good': True,
#    'night': True,
#    'twitter': True,
#    ':)': True},
#   'Positive'),
#  ({'get': True, 'misunderstood': True, ':(': True}, 'Negative'),
#  ({'guess': True,
#    'block': True,
#    'number': True,
#    'phone': True,
#    'spam': True,
#    'sms': True,
#    'feature': True,
#    'wont': True,
#    'work': True,
#    'use': True,
#    'specific': True,
#    'word': True,
#    'since': True,
#    'guy': True,
#    'write': True,
#    'sinhala': True,
#    'english': True,
#    ':(': True},
#   'Negative'),
#  ({'hope': True,
#    'okay': True,
#    'super': True,
#    'big': True,
#    'smile': True,
#    'hug': True,
#    ':)': True},
#   'Positive'),
#  ({'yep': True, '3:03': True, "can't": True, 'sleep': True, ':(': True},
#   'Negative'),
#  ({':)': True, '430': True, 'smh': True}, 'Positive'),
#  ({'never': True, 'love': True, 'life': True, 'success': True, ':)': True},
#   'Positive'),
#  ({'sad': True,
#    'bc': True,
#    'dream': True,
#    'boy': True,
#    'rtd': True,
#    'louis': True,
#    'harry': True,
#    'follow': True,
#    'wake': True,
#    'true': True,
#    ':(': True},
#   'Negative'),
#  ({'ice': True,
#    'cream': True,
#    'van': True,
#    'busy': True,
#    'bristol': True,
#    ':(': True},
#   'Negative'),
#  ({'thanks': True,
#    'going': True,
#    'take': True,
#    'time': True,
#    'create': True,
#    'shortlist': True,
#    ':)': True,
#    'much': True,
#    'appreciate': True},
#   'Positive'),
#  ({'nobody': True, 'go': True, ':(': True}, 'Negative'),
#  ({'unnieeee': True, ':)': True}, 'Positive'),
#  ({'yepp': True, 'course': True, 'mo': True, ':)': True}, 'Positive'),
#  ({'thank': True,
#    'much': True,
#    'mean': True,
#    'everything': True,
#    'even': True,
#    'know': True,
#    'never': True,
#    'follow': True,
#    'back': True,
#    ':)': True},
#   'Positive'),
#  ({'good': True,
#    'morning': True,
#    'happy': True,
#    'birthday': True,
#    ':)': True,
#    'one': True},
#   'Positive'),
#  ({'thesis': True,
#    'sherep': True,
#    'nemen': True,
#    'ng': True,
#    'behey': True,
#    'ke': True,
#    ':(': True},
#   'Negative'),
#  ({'fab': True, 'hope': True, ':)': True}, 'Positive'),
#  ({':(': True,
#    'know': True,
#    'happen': True,
#    'internet': True,
#    'light': True,
#    'connection': True,
#    'drop': True,
#    'thanks': True,
#    'kei': True},
#   'Negative'),
#  ({'want': True, 'ft': True, 'arianna': True, ':-)': True}, 'Positive'),
#  ({'really': True,
#    'happy': True,
#    'today': True,
#    '...': True,
#    'wat': True,
#    'u': True,
#    'done': True,
#    'us': True,
#    'muahhh': True,
#    ':)': True,
#    'may': True,
#    'god': True,
#    'bless': True},
#   'Positive'),
#  ({':(': True,
#    'mosque': True,
#    'w': True,
#    'sit': True,
#    'outside': True,
#    'whole': True,
#    'time': True,
#    'smelly': True,
#    "i'm": True,
#    'annoy': True},
#   'Negative'),
#  ({'wish': True,
#    'money': True,
#    'fly': True,
#    'see': True,
#    'concert': True,
#    ':(': True},
#   'Negative'),
#  ({'thanks': True, 'much': True, ':-)': True}, 'Positive'),
#  ({'fell': True,
#    'asleep': True,
#    'like': True,
#    '6:30': True,
#    "can't": True,
#    'fall': True,
#    'two': True,
#    'hour': True,
#    ':-)': True},
#   'Positive'),
#  ({'thanks': True, ':)': True}, 'Positive'),
#  ({"i'm": True,
#    'sorry': True,
#    ':(': True,
#    'hypercholesteloremia': True,
#    'ok': True},
#   'Negative'),
#  ({'char': True,
#    'im': True,
#    'really': True,
#    'sick': True,
#    ':(': True,
#    'one': True,
#    'font': True,
#    'size': True,
#    '8': True,
#    'minion': True,
#    'float': True,
#    '12': True,
#    'kid': True,
#    'pls': True},
#   'Negative'),
#  ({'stats': True,
#    'day': True,
#    'arrive': True,
#    '1': True,
#    'new': True,
#    'follower': True,
#    'unfollowers': True,
#    ':)': True,
#    'via': True},
#   'Positive'),
#  ({'watching': True,
#    'abusive': True,
#    'relationship': True,
#    'video': True,
#    'fucking': True,
#    'hard': True,
#    "i'm": True,
#    'try': True,
#    'cry': True,
#    'like': True,
#    '...': True,
#    ':(': True},
#   'Negative'),
#  ({'hull': True,
#    'supporter': True,
#    'expect': True,
#    'misserable': True,
#    'week': True,
#    ':-(': True},
#   'Negative'),
#  ({'keep': True,
#    'change': True,
#    'fe14': True,
#    'icon': True,
#    'dont': True,
#    'know': True,
#    'one': True,
#    'pick': True,
#    '>:(': True},
#   'Negative'),
#  ({'yeah': True,
#    'play': True,
#    'pretty': True,
#    'girl': True,
#    'bus': True,
#    'stop': True,
#    ':)': True,
#    'x': True},
#   'Positive'),
#  ({'hi': True,
#    'thanks': True,
#    'connect': True,
#    'specialise': True,
#    'thermal': True,
#    'image': True,
#    'survey': True,
#    '–': True,
#    'need': True,
#    'us': True,
#    ':)': True},
#   'Positive'),
#  ({'numbero': True, 'lolz': True, 'hope': True, 'well': True, ':)': True},
#   'Positive'),
#  ({'leaving': True,
#    'airport': True,
#    'soon': True,
#    ':(': True,
#    'wanna': True,
#    'go': True,
#    'home': True},
#   'Negative'),
#  ({'reynoldsgrl': True,
#    'either': True,
#    'deactivate': True,
#    'get': True,
#    'suspend': True,
#    'want': True,
#    'shade': True,
#    ':(': True},
#   'Negative'),
#  ({'reading': True, 'beautiful': True, 'like': True, 'read': True, ':)': True},
#   'Positive'),
#  ({'bae': True, ':)': True, '<3': True}, 'Positive'),
#  ({'itong': True,
#    'shirt': True,
#    'oh': True,
#    ':(': True,
#    'want': True,
#    'thaaaat': True,
#    'ctto': True},
#   'Negative'),
#  ({'neobytes': True,
#    ':)': True,
#    'universal': True,
#    'pictures': True,
#    'seed': True,
#    'pirate': True,
#    'movie': True,
#    'copy': True,
#    'file': True,
#    'takedown': True,
#    'notice': True},
#   'Positive'),
#  ({'haha': True,
#    'almost': True,
#    'certainly': True,
#    'true': True,
#    'name': True,
#    ':)': True},
#   'Positive'),
#  ({'need': True, 'stop': True, 'hardheaded': True, ':-(': True}, 'Negative'),
#  ({'leave': True, 'alone': True, ':(': True}, 'Negative'),
#  ({'miss': True, 'baao': True, ':(': True}, 'Negative'),
#  ({"i'm": True, 'thirstyyyy': True, ':(': True}, 'Negative'),
#  ({'seeing': True,
#    'delph': True,
#    'another': True,
#    'kit': True,
#    'upset': True,
#    ':(': True},
#   'Negative'),
#  ({'like': True,
#    'see': True,
#    'sad': True,
#    ':(': True,
#    'smile': True,
#    'stay': True,
#    'strong': True,
#    'alright': True,
#    '😊': True,
#    '💞': True},
#   'Negative'),
#  ({'ticket': True, 'da': True, 'expire': True, ':(': True}, 'Negative'),
#  ({'wish': True, 'blooper': True, ':(': True}, 'Negative'),
#  ({'follow': True, 'u': True, 'back': True, ':)': True}, 'Positive'),
#  ({'try': True, 'turn': True, ':)': True}, 'Positive'),
#  ({'please': True, ':(': True}, 'Negative'),
#  ({"i'm": True, 'still': True, 'finish': True, 'work': True, 'dad': True},
#   'Negative'),
#  ({'contact': True, 'whatsoever': True, 'anybody': True, ':(': True},
#   'Negative'),
#  ({'fav': True, 'cheese': True, 'give': True, 'migrines': True, ':(': True},
#   'Negative'),
#  ({'gimme': True,
#    ':(': True,
#    'enjoy': True,
#    'meal': True,
#    'baby': True,
#    '♡': True},
#   'Negative'),
#  ({'yeahhh': True, ':(': True, '..': True, 'mean': True, 'hacharatt': True},
#   'Negative'),
#  ({'anytime': True, ':)': True}, 'Positive'),
#  ({'come': True, 'singapore': True, ':(': True}, 'Negative'),
#  ({'already': True, ':)': True}, 'Positive'),
#  ({'payback': True,
#    'like': True,
#    'video': True,
#    'try': True,
#    'help': True,
#    'get': True,
#    'kit': True,
#    'kat': True,
#    ':(': True},
#   'Negative'),
#  ({'hey': True,
#    'like': True,
#    'fnaf': True,
#    'check': True,
#    'youtube': True,
#    'channel': True,
#    ':)': True,
#    'via': True},
#   'Positive'),
#  ({'morning': True,
#    '...': True,
#    'friday': True,
#    'happy': True,
#    'beautiful': True,
#    'people': True,
#    ':)': True,
#    '#smile': True},
#   'Positive'),
#  ({'nice': True, 'see': True, 'emulation': True, 'bring': True, ':)': True},
#   'Positive'),
#  ({'spring': True,
#    'fiesta': True,
#    '2015': True,
#    'make': True,
#    'noise': True,
#    'awuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuu': True,
#    'aich': True,
#    ':)': True},
#   'Positive'),
#  ({'dear': True,
#    'last': True,
#    'night': True,
#    'wait': True,
#    '2hrs': True,
#    '13m': True,
#    'pizza': True,
#    'time': True,
#    'arrive': True,
#    'cold': True,
#    'late': True,
#    'eat': True,
#    'disappointed': True,
#    ':(': True},
#   'Negative'),
#  ({'jummah': True,
#    'mubarik': True,
#    'recite': True,
#    'durood': True,
#    'e': True,
#    'pak': True,
#    'much': True,
#    'thank': True,
#    ':)': True},
#   'Positive'),
#  ({'“': True,
#    'treat': True,
#    'two': True,
#    'different': True,
#    'thing': True,
#    'equal': True,
#    'form': True,
#    'injustice': True,
#    '”': True,
#    '#feminism': True,
#    '#ineedfeminismbecause': True,
#    '..': True,
#    'actually': True,
#    ':p': True},
#   'Positive'),
#  ({"i'm": True, 'inactive': True, ':(': True}, 'Negative'),
#  ({'congrats': True, 'launch': True, ':d': True}, 'Positive'),
#  ({'kinda': True,
#    'wish': True,
#    'tip': True,
#    'smoke': True,
#    '...': True,
#    'good': True,
#    'morning': True,
#    ':-)': True},
#   'Positive'),
#  ({'ur': True, 'la': True, ':(': True}, 'Negative'),
#  ({'check': True,
#    'new': True,
#    'article': True,
#    'blog': True,
#    ':)': True,
#    'app': True,
#    'terrific': True},
#   'Positive'),
#  ({'im': True,
#    '24': True,
#    'hour': True,
#    'sleep': True,
#    'sunday': True,
#    ':(': True,
#    'xx': True},
#   'Negative'),
#  ({'stand': True, 'cool': True, ':)': True}, 'Positive'),
#  ({'first': True,
#    'attempt': True,
#    'size': True,
#    '6g': True,
#    'unsuccessful': True,
#    'lil': True,
#    'earlobes': True,
#    'hurt': True,
#    ':(': True},
#   'Negative'),
#  ({'uh': True,
#    'huh': True,
#    ':(': True,
#    'two': True,
#    'time': True,
#    "i'm": True,
#    'super': True,
#    'clever': True,
#    'like': True},
#   'Negative'),
#  ({'bakit': True, 'facebook': True, ':(': True}, 'Negative'),
#  ({'awww': True,
#    'stealth': True,
#    'bastard': True,
#    '2': True,
#    'name': True,
#    'inc': True,
#    'steam': True,
#    ':(': True},
#   'Negative'),
#  ({'little': True,
#    'doodle': True,
#    'star': True,
#    'comic': True,
#    'summoner': True,
#    'back': True,
#    'soon': True,
#    ':)': True,
#    '#art': True,
#    '#doodle': True},
#   'Positive'),
#  ({'good': True,
#    'luck': True,
#    '...': True,
#    'another': True,
#    'potential': True,
#    'favourite': True,
#    'water': True,
#    'hole': True,
#    ':-)': True},
#   'Positive'),
#  ({'r': True, 'u': True, ':-)': True}, 'Positive'),
#  ({'good': True, 'night': True, 'everyone': True}, 'Positive'),
#  ({'leeds': True, 'wanna': True, 'see': True, 'live': True, ':(': True},
#   'Negative'),
#  ({'honest': True,
#    'miss': True,
#    'dubai': True,
#    'want': True,
#    'come': True,
#    'back': True,
#    ':(': True},
#   'Negative'),
#  ({'full': True,
#    'really': True,
#    'great': True,
#    'job': True,
#    'congrats': True,
#    ':)': True},
#   'Positive'),
#  ({'first': True,
#    'person': True,
#    'make': True,
#    'twinx': True,
#    'cry': True,
#    '16': True,
#    'year': True,
#    'old': True,
#    ':)': True},
#   'Positive'),
#  ({'u': True,
#    'knw': True,
#    'wht': True,
#    "i'm": True,
#    'big': True,
#    'fan': True,
#    'n': True,
#    'go': True,
#    'set': True,
#    'bt': True,
#    'get': True,
#    'chance': True,
#    'meet': True,
#    '...': True,
#    ':(': True},
#   'Negative'),
#  ({'almost': True, '12': True, "i'm": True, 'tired': True, ':(': True},
#   'Negative'),
#  ({'hi': True,
#    'bam': True,
#    'follow': True,
#    'bestfriend': True,
#    'love': True,
#    'lot': True,
#    ':)': True,
#    'see': True,
#    'warsaw': True,
#    '<3': True,
#    'x15': True},
#   'Positive'),
#  ({'sadkaay': True, 'tharkness': True, 'peak': True, ':)': True}, 'Positive'),
#  ({'chicsirific': True, 'heart': True, ':(': True}, 'Negative'),
#  ({'love': True, 'u': True, ':(': True}, 'Negative'),
#  ({'goddess': True, ':d': True}, 'Positive'),
#  ({'thank': True, 'much': True, 'mention': True, 'awesome': True, ':)': True},
#   'Positive'),
#  ({'thanks': True, 'follow': True, ':)': True}, 'Positive'),
#  ({'nice': True, 'music': True, ':)': True, 'check': True}, 'Positive'),
#  ({'party': True, 'promotion': True, ':(': True}, 'Negative'),
#  ({'hi': True,
#    'unfortunately': True,
#    "we're": True,
#    'unable': True,
#    'locate': True,
#    'original': True,
#    'complaint': True,
#    ':(': True,
#    'pls': True,
#    'dm': True,
#    'us': True,
#    'product': True,
#    'detail': True,
#    "we'll": True,
#    'get': True,
#    'back': True},
#   'Negative'),
#  ({'fback': True, ':)': True}, 'Positive'),
#  ({'reject': True,
#    'section': True,
#    'uk': True,
#    'govt': True,
#    'e-petitions': True,
#    'site': True,
#    'die': True,
#    ':(': True},
#   'Negative'),
#  ({'great': True,
#    'view': True,
#    'shame': True,
#    'weather': True,
#    'though': True,
#    ':-(': True},
#   'Negative'),
#  ({'#jummamubarak': True,
#    'every': True,
#    'one': True,
#    ':)': True,
#    'take': True,
#    'shower': True,
#    'wear': True,
#    'good': True,
#    '#shalwarkameez': True,
#    '#itter': True,
#    'offer': True,
#    '#jummaprayer': True,
#    '...': True},
#   'Positive'),
#  ({'#welcometweet': True,
#    'thanks': True,
#    'follow': True,
#    '..': True,
#    ':-)': True,
#    'via': True},
#   'Positive'),
#  ({'hi': True,
#    'great': True,
#    'connect': True,
#    'specialise': True,
#    'thermal': True,
#    'image': True,
#    'survey': True,
#    '–': True,
#    'need': True,
#    'us': True,
#    ':)': True},
#   'Positive'),
#  ({'hello': True,
#    'need': True,
#    '2.5': True,
#    'g2a': True,
#    'code': True,
#    'pls': True,
#    ':(': True},
#   'Negative'),
#  ({'another': True,
#    '#thankyou': True,
#    'debbie': True,
#    'carol': True,
#    ':)': True,
#    '“': True,
#    'thanks': True,
#    'see': True,
#    'record': True,
#    'number': True,
#    'patient': True,
#    'discharge': True,
#    'lounge': True,
#    'yesterday': True,
#    'great': True,
#    '”': True},
#   'Positive'),
#  ({'think': True,
#    'want': True,
#    'take': True,
#    'slow': True,
#    '..': True,
#    ':d': True,
#    'glad': True,
#    'though': True},
#   'Positive'),
#  ({"i've": True,
#    'support': True,
#    'since': True,
#    'start': True,
#    'always': True,
#    'ignore': True,
#    ':(': True,
#    'please': True,
#    'let': True,
#    'today': True,
#    'day': True,
#    'finally': True,
#    'follow': True,
#    '�': True,
#    '♥': True},
#   'Negative'),
#  ({'ask': True, 'make': True, 'year': True, ':)': True}, 'Positive'),
#  ({'weltum': True,
#    'teh': True,
#    'dety': True,
#    ':p': True,
#    'huh': True,
#    '=d': True},
#   'Positive'),
#  ({'amaze': True,
#    'set': True,
#    'question': True,
#    'bhai': True,
#    'keep': True,
#    ':(': True,
#    'miss': True,
#    'e': True,
#    'ramzan': True,
#    'u': True},
#   'Negative'),
#  ({'time': True, 'fly': True, ':d': True}, 'Positive'),
#  ({'want': True, 'jack': True, 'box': True, ':(': True}, 'Negative'),
#  ({'state': True, 'hair': True, ':(': True}, 'Negative'),
#  ({'notice': True, ':(': True, 'work': True}, 'Negative'),
#  ({'please': True, 'follow': True, 'liam': True, ':)': True}, 'Positive'),
#  ({'justin': True, ':(': True}, 'Negative'),
#  ({'rain': True, ':-(': True}, 'Negative'),
#  ({'want': True,
#    'make': True,
#    'someone': True,
#    'happy': True,
#    'thats': True,
#    'def': True,
#    'happiness': True,
#    ':)': True,
#    '#kunoriforceo': True,
#    '#ceo1month': True},
#   'Positive'),
#  ({'reason': True,
#    "i'm": True,
#    'always': True,
#    'overweight': True,
#    '...': True,
#    'sigeg': True,
#    'habhab': True,
#    ':(': True,
#    'masud': True,
#    'pa': True,
#    'kaha': True,
#    'ko': True,
#    'akong': True,
#    'un': True,
#    '…': True},
#   'Negative'),
#  ({'rain': True, ':(': True}, 'Negative'),
#  ({'remember': True,
#    'oh': True,
#    'god': True,
#    'frank': True,
#    'iero': True,
#    'phase': True,
#    ':d': True},
#   'Positive'),
#  ({'noone': True,
#    'live': True,
#    'drag': True,
#    'draw': True,
#    'ok': True,
#    ':(': True},
#   'Negative'),
#  ({'wanna': True, 'feel': True, 'love': True, ':(': True}, 'Negative'),
#  ({'go': True, ':(': True}, 'Negative'),
#  ({'getting': True,
#    'ready': True,
#    '...': True,
#    '#ubericecream': True,
#    '#messengerforaday': True,
#    ':)': True},
#   'Positive'),
#  ({'welcome': True, ':)': True}, 'Positive'),
#  ({"that's": True,
#    'u': True,
#    'get': True,
#    'pour': True,
#    'milk': True,
#    'first': True,
#    ':-)': True},
#   'Positive'),
#  ({'cute': True, 'look': True, 'fabulous': True, ':)': True}, 'Positive'),
#  ({'sorry': True, ':-(': True, 'hope': True, 'get': True, 'good': True},
#   'Negative'),
#  ({'yo': True,
#    'stop': True,
#    'bragging': True,
#    'everybody': True,
#    'get': True,
#    'skrillah': True,
#    'travel': True,
#    ':(': True},
#   'Negative'),
#  ({'u': True, 'hiding': True, 'baby': True, ':(': True}, 'Negative'),
#  ({'place': True, '..': True, 'close': True, ':(': True}, 'Negative'),
#  ({'lucky': True, 'spike': True, ':-(': True}, 'Negative'),
#  ({'stats': True,
#    'day': True,
#    'arrive': True,
#    '2': True,
#    'new': True,
#    'follower': True,
#    'unfollowers': True,
#    ':)': True,
#    'via': True},
#   'Positive'),
#  ({'good': True, 'night': True, ':)': True}, 'Positive'),
#  ({'life': True,
#    'remember': True,
#    'one': True,
#    'time': True,
#    'year': True,
#    'ago': True,
#    'change': True,
#    'avi': True,
#    'lose': True,
#    '72': True,
#    'follower': True,
#    'looooool': True,
#    ':(': True},
#   'Negative'),
#  ({'s2': True,
#    'air': True,
#    'spain': True,
#    'delay': True,
#    'kill': True,
#    'us': True,
#    '...': True,
#    ':(': True},
#   'Negative'),
#  ({'thanks': True, 'admin': True, ':)': True}, 'Positive'),
#  ({'course': True,
#    'always': True,
#    'miss': True,
#    'tweeting': True,
#    'spree': True,
#    ':(': True},
#   'Negative'),
#  ({'would': True,
#    "i'm": True,
#    'still': True,
#    'wait': True,
#    'email': True,
#    ':(': True,
#    'check': True,
#    'photo': True},
#   'Negative'),
#  ({'finish': True,
#    'download': True,
#    '10': True,
#    'movie': True,
#    'one': True,
#    'complete': True,
#    'tv': True,
#    'series': True,
#    'last': True,
#    'night': True,
#    '…': True,
#    'where.do.i.start': True,
#    ':)': True,
#    '#moviemarathon': True},
#   'Positive'),
#  ({'everything': True, 'okay': True, ':(': True, 'x': True}, 'Negative'),
#  ({'“': True,
#    'bet': True,
#    'wonder': True,
#    'happen': True,
#    ':(': True,
#    '”': True,
#    'try': True,
#    'calm': True,
#    'start': True,
#    '🙏🏻': True,
#    '🎂': True},
#   'Negative'),
#  ({'dinner': True,
#    'date': True,
#    'tonight': True,
#    'pony': True,
#    'bf': True,
#    ':d': True},
#   'Positive'),
#  ({'ok': True,
#    'good': True,
#    'stay': True,
#    'otherwise': True,
#    'miss': True,
#    'much': True,
#    ':(': True},
#   'Negative'),
#  ({'wish': True,
#    'could': True,
#    'drive': True,
#    "i'm": True,
#    'good': True,
#    'stupid': True,
#    'vertigo': True,
#    'panic': True,
#    'attack': True,
#    'make': True,
#    'dual': True,
#    'carriageway': True,
#    'impossible': True,
#    'tho': True,
#    ':(': True},
#   'Negative'),
#  ({'would': True,
#    'like': True,
#    'able': True,
#    'work': True,
#    'full': True,
#    'time': True,
#    'stuff': True,
#    'move': True,
#    "i'm": True,
#    'consider': True,
#    'take': True,
#    'fulltime': True,
#    'job': True,
#    ':(': True},
#   'Negative'),
#  ({'snap': True, ':)': True}, 'Positive'),
#  ({'miss': True, 'mom': True, ':(': True}, 'Negative'),
#  ({'v': True,
#    'nice': True,
#    'day': True,
#    'happen': True,
#    'surreal': True,
#    ':)': True},
#   'Positive'),
#  ({'abby': True, ':(': True}, 'Negative'),
#  ({'good': True,
#    'idea': True,
#    'share': True,
#    'excellent': True,
#    'book': True,
#    'title': True,
#    'would': True,
#    'without': True,
#    'keep': True,
#    'work': True,
#    ':)': True},
#   'Positive'),
#  ({'worry': True,
#    'thanks': True,
#    'follow': True,
#    'hope': True,
#    'great': True,
#    'day': True,
#    'long': True,
#    'till': True,
#    'weekend': True,
#    ':)': True},
#   'Positive'),
#  ({'probably': True, 'gonna': True, 'though': True, ':d': True}, 'Positive'),
#  ({'ah': True, 'find': True, 'thanks': True, ':)': True}, 'Positive'),
#  ({'haw': True,
#    'phela': True,
#    'look': True,
#    'like': True,
#    'mom': True,
#    'obviously': True,
#    ':)': True},
#   'Positive'),
#  ({'even': True, 'notice': True, ':(': True}, 'Negative'),
#  ({'truly': True,
#    'miss': True,
#    'play': True,
#    'piano': True,
#    'much': True,
#    'never': True,
#    'stop': True,
#    ':(': True},
#   'Negative'),
#  ({'good': True, 'go': True, 'peter': True, 'keep': True, ':)': True},
#   'Positive'),
#  ({'twitter': True,
#    'meni': True,
#    'tebrik': True,
#    'etdi': True,
#    ':)': True,
#    'congratulations': True,
#    '700': True,
#    'follower': True},
#   'Positive'),
#  ({'need': True,
#    ':)': True,
#    '#teenchoice': True,
#    '#choiceinternationalartist': True,
#    '#superjunior': True},
#   'Positive'),
#  ({'welcome': True, ':)': True}, 'Positive'),
#  ({'follback': True, ':)': True}, 'Positive'),
#  ({'flat': True, 'love': True, 'make': True, 'puke': True, ':(': True},
#   'Negative'),
#  ({'wait': True,
#    '2nd': True,
#    'year': True,
#    'soon': True,
#    ':)': True,
#    'get': True,
#    'go': True,
#    'trip': True,
#    'like': True,
#    'hschool': True},
#   'Positive'),
#  ({':(': True}, 'Negative'),
#  ({'breaking': True,
#    'habit': True,
#    'lifetime': True,
#    '...': True,
#    "i'm": True,
#    'play': True,
#    'call': True,
#    'duty': True,
#    'game': True,
#    '..': True,
#    ':(': True},
#   'Negative'),
#  ({'enjoy': True,
#    'short': True,
#    'hilly': True,
#    'cycle': True,
#    'last': True,
#    'day': True,
#    'england': True,
#    'trip': True,
#    '#scotlandismassive': True,
#    ':)': True},
#   'Positive'),
#  ({'lovely': True, ':)': True}, 'Positive'),
#  ({'maybe': True,
#    'young': True,
#    'woman': True,
#    'stamen': True,
#    'tom': True,
#    ':)': True},
#   'Positive'),
#  ({'feelings': True, 'sir': True, ':(': True}, 'Negative'),
#  ({'app': True,
#    'look': True,
#    'influencers': True,
#    ':)': True,
#    'interested': True,
#    "here's": True,
#    'invite': True},
#   'Positive'),
#  ({'second': True, 'wednesday': True, 'already': True, ':(': True},
#   'Negative'),
#  ({'newly': True,
#    'list': True,
#    'ebay': True,
#    'store': True,
#    ':-)': True,
#    '...': True},
#   'Positive'),
#  ({'great': True, 'weekend': True, 'friend': True, ':)': True}, 'Positive'),
#  ({'fun': True, 'boy': True, ':d': True}, 'Positive'),
#  ({'officially': True,
#    'patron': True,
#    'love': True,
#    'work': True,
#    "i'm": True,
#    'look': True,
#    'forward': True,
#    'see': True,
#    'extra': True,
#    'content': True,
#    ':)': True},
#   'Positive'),
#  ({'best': True,
#    'burger': True,
#    'far': True,
#    'agree': True,
#    ':)': True,
#    '#retweet': True,
#    '#food': True,
#    '#burger': True},
#   'Positive'),
#  ({'know': True, 'find': True, 'balance': True, ':(': True}, 'Negative'),
#  ({'persona': True,
#    '4': True,
#    'normal': True,
#    'one': True,
#    '...': True,
#    'prefer': True,
#    'golden': True,
#    'though': True,
#    'lot': True,
#    'new': True,
#    'scene': True,
#    ':(': True},
#   'Negative'),
#  ({'name': True,
#    'couple': True,
#    'yet': True,
#    '#tomhiddleston': True,
#    '#elizabetholsen': True,
#    '#yaytheylookgreat': True,
#    ':)': True},
#   'Positive'),
#  ({'hey': True,
#    'thanks': True,
#    'following': True,
#    ':)': True,
#    '#autofollow': True,
#    '#teamfollowback': True,
#    'via': True},
#   'Positive'),
#  ({'know': True, ':(': True, 'saklap': True}, 'Negative'),
#  ({'please': True,
#    'keep': True,
#    'prayer': True,
#    "he's": True,
#    'fragile': True,
#    "can't": True,
#    'even': True,
#    'cry': True,
#    'feel': True,
#    'like': True,
#    "i've": True,
#    'much': True,
#    'week': True,
#    'already': True,
#    ':(': True},
#   'Negative'),
#  ({'adults': True,
#    'take': True,
#    'thing': True,
#    'serious': True,
#    'really': True,
#    'miss': True,
#    'kid': True,
#    ':(': True},
#   'Negative'),
#  ({'early': True, 'day': True, 'boner': True, 'mercy': True, ':-(': True},
#   'Negative'),
#  ({'liam': True, 'sophia': True, 'chicago': True, ':)': True, '♥': True},
#   'Positive'),
#  ({'probably': True, 'yes': True, ':p': True}, 'Positive'),
#  ({'thanks': True, 'support': True, ':)': True}, 'Positive'),
#  ({'school': True,
#    'end': True,
#    'early': True,
#    'could': True,
#    'ngee': True,
#    'ann': True,
#    'acoustic': True,
#    'gig': True,
#    ':(': True},
#   'Negative'),
#  ({'hard': True,
#    'save': True,
#    'live': True,
#    '...': True,
#    ':(': True,
#    '</3': True,
#    '#stexpert': True,
#    '#ripstegi': True},
#   'Negative'),
#  ({'hahaha': True,
#    'u': True,
#    'serious': True,
#    'himmat': True,
#    'karain': True,
#    'aur': True,
#    'moo': True,
#    'pay': True,
#    'baat': True,
#    ':)': True,
#    'believe': True,
#    'meri': True,
#    'debate': True,
#    'abu': True,
#    'k': True,
#    'cousin': True,
#    'sath': True,
#    'hotee-my': True,
#    'uncle': True,
#    '😂': True},
#   'Positive'),
#  ({':(': True, 'nope': True, 'haha': True, 'fly': True, 'dallas': True},
#   'Negative'),
#  ({'someone': True,
#    'talk': True,
#    'cant': True,
#    'sleep': True,
#    ':/': True,
#    'ill': True,
#    'anything': True,
#    'want': True,
#    ':)': True},
#   'Positive'),
#  ({'yep': True,
#    'would': True,
#    'vote': True,
#    'could': True,
#    ';-)': True,
#    'imagine': True,
#    'hillary': True,
#    'clinton': True,
#    'first': True,
#    'female': True,
#    'us': True,
#    'president': True,
#    ':-)': True},
#   'Positive'),
#  ({'hey': True,
#    "here's": True,
#    'invite': True,
#    'join': True,
#    'scope': True,
#    'influencer': True,
#    ':)': True},
#   'Positive'),
#  ({'lol': True, 'one': True, 'word': True, 'david': True, ':)': True},
#   'Positive'),
#  ({'visit': True, 'blog': True, 'thanks': True, ':d': True}, 'Positive'),
#  ({'tomorrow': True, 'lmao': True, 'hehe': True, ':d': True}, 'Positive'),
#  ({'nice': True,
#    'enji': True,
#    '...': True,
#    'good': True,
#    'job': True,
#    ':-)': True},
#   'Positive'),
#  ({'en': True,
#    'mis': True,
#    'manos': True,
#    'hold': True,
#    'hand': True,
#    ':)': True},
#   'Positive'),
#  ({'terrible': True, ':(': True}, 'Negative'),
#  ({'hey': True,
#    'cam': True,
#    'come': True,
#    'peace': True,
#    ':)': True,
#    'help': True,
#    'c': True},
#   'Positive'),
#  ({'happy': True,
#    '30th': True,
#    'wed': True,
#    'anniversary': True,
#    'folk': True,
#    ':)': True},
#   'Positive'),
#  ({'guess': True,
#    'never': True,
#    'really': True,
#    'identify': True,
#    'pharmacy': True,
#    ':)': True,
#    '#verylaterealisation': True,
#    '#iwishiknewbetter': True},
#   'Positive'),
#  ({'#followfriday': True,
#    'top': True,
#    'influencers': True,
#    'community': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({'please': True,
#    'james': True,
#    'think': True,
#    'beautiful': True,
#    'girls': True,
#    'loneliest': True,
#    'tattoo': True,
#    'change': True,
#    'life': True,
#    ':)': True},
#   'Positive'),
#  ({'kik': True,
#    'abligaverins': True,
#    '7': True,
#    '#kik': True,
#    '#hornykik': True,
#    '#photooftheday': True,
#    '#kikchat': True,
#    '#likeforlike': True,
#    '#indiemusic': True,
#    '#sexygirlbypreciouslemmy': True,
#    ':(': True},
#   'Negative'),
#  ({"i'm": True, 'omw': True, '😍': True, 'lol': True, 'wish': True, ':(': True},
#   'Negative'),
#  ({'must': True, 'tired': True, ':(': True}, 'Negative'),
#  ({'niall': True, 'niwll': True, ':(': True}, 'Negative'),
#  ({'favorite': True, 'tea': True, ':)': True}, 'Positive'),
#  ({'hay': True, ':(': True}, 'Negative'),
#  ({'guys': True,
#    'add': True,
#    'kik': True,
#    'abouty': True,
#    '797': True,
#    '#kik': True,
#    '#kiksex': True,
#    '#interracial': True,
#    '#tagsforlikes': True,
#    '#kikme': True,
#    '#travel': True,
#    '#kikmenow': True,
#    ':(': True},
#   'Negative'),
#  ({'feel': True,
#    'like': True,
#    'cry': True,
#    'reason': True,
#    'right': True,
#    ':(': True},
#   'Negative'),
#  ({'lucky': True,
#    'u': True,
#    'dont': True,
#    'ramadhan': True,
#    'holiday': True,
#    'eid': True,
#    "that's": True,
#    'week': True,
#    ':(': True,
#    'need': True},
#   'Negative'),
#  ({'good': True, 'morning': True}, 'Positive'),
#  ({'hello': True,
#    ':)': True,
#    'get': True,
#    'youth': True,
#    'job': True,
#    'opportunities': True,
#    'follow': True},
#   'Positive'),
#  ({'fuck': True, 'day': True, '\U000fe196': True, ':(': True}, 'Negative'),
#  ({'want': True, 'kylie': True, 'jenner': True, 'clothes': True, ':(': True},
#   'Negative'),
#  ({'headack': True,
#    'badly': True,
#    'tension': True,
#    'eritation': True,
#    ':(': True},
#   'Negative'),
#  ({'first': True,
#    'love': True,
#    'wanna': True,
#    'fuck': True,
#    'late': True,
#    'night': True,
#    'thinking': True,
#    'get': True,
#    'nut': True,
#    ':-)': True,
#    'v': True,
#    'look': True,
#    '...': True},
#   'Positive'),
#  ({'nice': True, 'one': True, ':)': True}, 'Positive'),
#  ({'last': True,
#    '9': True,
# ...
#   'Negative'),
#  ({'ugh': True,
#    'cant': True,
#    'stream': True,
#    'tmr': True,
#    'duty': True,
#    ':(': True},
#   'Negative'),
#  ({'sunggyu': True,
#    'injure': True,
#    'hand': True,
#    'yesterday': True,
#    "there's": True,
#    'plaster': True,
#    ':(': True},
#   'Negative'),
#  ({'want': True,
#    'bandana': True,
#    'bottle': True,
#    'set': True,
#    'huhuh': True,
#    ':(': True},
#   'Negative'),
#  ({'controversy': True, ':(': True}, 'Negative'),
#  ({'great': True,
#    'news': True,
#    'thanks': True,
#    'let': True,
#    'us': True,
#    'know': True,
#    ':(': True,
#    'hope': True,
#    'good': True,
#    'weekend': True},
#   'Negative'),
#  ({'come': True,
#    'online': True,
#    'follow': True,
#    'people': True,
#    ':/': True,
#    'z': True,
#    'wrong': True,
#    'u': True,
#    'ignore': True,
#    'sidharth': True,
#    ':(': True},
#   'Negative'),
#  ({'11:11': True,
#    'meet': True,
#    'michael': True,
#    'hug': True,
#    'tight': True,
#    'talk': True,
#    'tell': True,
#    "he's": True,
#    'important': True,
#    'love': True,
#    'much': True,
#    'make': True,
#    'smile': True,
#    ':d': True},
#   'Positive'),
#  ({'wish': True,
#    'could': True,
#    'come': True,
#    'see': True,
#    'disability': True,
#    'pension': True,
#    'ptsd': True,
#    'make': True,
#    'impossible': True,
#    'physically': True,
#    'financially': True,
#    ':(': True},
#   'Negative'),
#  ({'nstp': True, 'class': True, 'tomorrow': True, ':(': True}, 'Negative'),
#  ({'today': True, 'happy': True, 'day': True, ':)': True}, 'Positive'),
#  ({'know': True,
#    'hell': True,
#    'play': True,
#    'next': True,
#    'one': True,
#    'find': True,
#    'way': True,
#    'turn': True,
#    ':(': True},
#   'Negative'),
#  ({'love': True,
#    'multiracial': True,
#    'couple': True,
#    "they're": True,
#    'like': True,
#    'royal': True,
#    'fk': True,
#    'narrow': True,
#    'mind': True,
#    'asshole': True,
#    'walk': True,
#    'planet': True,
#    ':)': True},
#   'Positive'),
#  ({'literally': True,
#    'tear': True,
#    'room': True,
#    'apart': True,
#    'look': True,
#    'retainer': True,
#    ':(': True},
#   'Negative'),
#  ({"i've": True,
#    'run': True,
#    'bread': True,
#    'feel': True,
#    'well': True,
#    'enough': True,
#    'make': True,
#    ':(': True},
#   'Negative'),
#  ({'livid': True, 'still': True, 'work': True, ':(': True}, 'Negative'),
#  ({'still': True,
#    'decide': True,
#    'want': True,
#    'name': True,
#    'planner': True,
#    ':(': True,
#    'please': True,
#    'helpppp': True},
#   'Negative'),
#  ({':-)': True, 'nice': True, 'hair': True, 'tbh': True}, 'Positive'),
#  ({'perfect': True,
#    'time': True,
#    'see': True,
#    'tweet': True,
#    'send': True,
#    'email': True,
#    'info': True,
#    'recently': True,
#    'engage': True,
#    ':d': True},
#   'Positive'),
#  ({'early': True,
#    'bird': True,
#    'go': True,
#    'already': True,
#    'das': True,
#    'nice': True,
#    ':)': True},
#   'Positive'),
#  ({"i've": True,
#    'gotta': True,
#    'go': True,
#    'home': True,
#    'put': True,
#    'sweatpants': True,
#    'hold': True,
#    'breath': True,
#    'die': True,
#    ':)': True},
#   'Positive'),
#  ({'love': True, ':(': True}, 'Negative'),
#  ({'tomorrow': True, 'morning': True, 'mate': True, ':)': True}, 'Positive'),
#  ({'make': True,
#    'alive': True,
#    'suffer': True,
#    'feel': True,
#    '..': True,
#    'addictive': True,
#    'song': True,
#    'always': True,
#    'sing': True,
#    'karaoke': True,
#    ':-)': True},
#   'Positive'),
#  ({'remember': True,
#    '2': True,
#    'gaon': True,
#    'bad': True,
#    '6': True,
#    'infnt': True,
#    'eligible': True,
#    'apink': True,
#    ':(': True,
#    'acube': True,
#    "why'd": True,
#    'u': True},
#   'Negative'),
#  ({'yeeeeyyy': True,
#    'congrats': True,
#    '..': True,
#    ':-)': True,
#    '#gohf2015': True,
#    '#barsostay': True},
#   'Positive'),
#  ({'feel': True,
#    'pain': True,
#    'like': True,
#    'welsh': True,
#    'pod': True,
#    ':(': True},
#   'Negative'),
#  ({'mistake': True,
#    'happen': True,
#    'man': True,
#    'long': True,
#    'get': True,
#    'play': True,
#    'game': True,
#    "we'll": True,
#    'happy': True,
#    ':)': True},
#   'Positive'),
#  ({'good': True, 'morning': True, ':-)': True}, 'Positive'),
#  ({':-)': True}, 'Positive'),
#  ({'hello': True,
#    ':)': True,
#    'get': True,
#    'youth': True,
#    'job': True,
#    'opportunities': True,
#    'follow': True},
#   'Positive'),
#  ({'___': True, 'mad': True, 'us': True, 'think': True, ':(': True},
#   'Negative'),
#  ({'yeah': True,
#    '...': True,
#    'get': True,
#    'shit': True,
#    'bag': True,
#    'laughing': True,
#    'face': True,
#    'anxiety': True,
#    'har': True,
#    'think': True,
#    ':(': True,
#    "how's": True,
#    'go': True,
#    'chum': True,
#    'weekend': True},
#   'Negative'),
#  ({'ice': True, 'cream': True, 'vehicle': True, 'busy': True, ':(': True},
#   'Negative'),
#  ({'things': True,
#    'regret': True,
#    '...': True,
#    'loose': True,
#    '..': True,
#    ":'(": True,
#    ':(': True,
#    'miss': True,
#    'everyday': True,
#    'life': True,
#    '#kapatidkongpogi': True},
#   'Negative'),
#  ({'ruin': True,
#    'game': True,
#    'notice': True,
#    'many': True,
#    'stop': True,
#    'play': True,
#    'regens': True,
#    'look': True,
#    'realistic': True,
#    ':(': True,
#    'shame': True},
#   'Negative'),
#  ({'...': True, 'cup': True, 'empty': True, ':d': True}, 'Positive'),
#  ({'surreal': True, ':)': True}, 'Positive'),
#  ({"can't": True, 'feel': True, 'tomorrow': True, ':(': True}, 'Negative'),
#  ({'nfinite': True,
#    'new': True,
#    'update': True,
#    'hoya': True,
#    '#admin_myung': True,
#    'slp': True,
#    ':(': True},
#   'Negative'),
#  ({'exactly': True,
#    '6': True,
#    'min': True,
#    'get': True,
#    'work': True,
#    'still': True,
#    'luas': True,
#    'right': True,
#    ':)': True},
#   'Positive'),
#  ({'popped': True, 'confetti': True, 'though': True}, 'Negative'),
#  ({'common': True,
#    'celebrate': True,
#    'never': True,
#    'fail': True,
#    'get': True,
#    'good': True,
#    'mood': True,
#    ':)': True},
#   'Positive'),
#  ({'okayy': True, ':d': True}, 'Positive'),
#  ({'appreciate': True,
#    'work': True,
#    'lot': True,
#    'go': True,
#    'italian': True,
#    'fan': True,
#    ':d': True},
#   'Positive'),
#  ({"i'll": True,
#    'hawaii': True,
#    'december': True,
#    "we'll": True,
#    'kick': True,
#    'back': True,
#    'miss': True,
#    ':)': True},
#   'Positive'),
#  ({'happy': True,
#    'birthday': True,
#    '...': True,
#    '#pricelessantique': True,
#    '#takesonetoknowone': True,
#    ':-)': True},
#   'Positive'),
#  ({'suppose': True, 'sleep': True, ':-)': True}, 'Positive'),
#  ({'go': True, 'po': True, 'ice': True, 'cream': True, ':)': True},
#   'Positive'),
#  ({'mtaani': True,
#    'tunaita': True,
#    'pussy': True,
#    'viazi': True,
#    'choma': True,
#    'still': True,
#    'get': True,
#    'laid': True,
#    ':-(': True},
#   'Negative'),
#  ({'yippeee': True,
#    'hope': True,
#    'little': True,
#    'one': True,
#    'enjoy': True,
#    'scrummy': True,
#    'recipe': True,
#    ':)': True},
#   'Positive'),
#  ({'ahh': True, 'hope': True, ':(': True}, 'Negative'),
#  ({'miss': True,
#    ':)': True,
#    '#teenchoice': True,
#    '#choiceinternationalartist': True,
#    '#superjunior': True},
#   'Positive'),
#  ({'join': True,
#    'hug': True,
#    "i'm": True,
#    'sorry': True,
#    'hear': True,
#    'sodders': True,
#    ':(': True},
#   'Negative'),
#  ({'love': True, ':d': True}, 'Positive'),
#  ({'happy': True, 'birthday': True, 'love': True, ':)': True}, 'Positive'),
#  ({'know': True, ':)': True, 'hot': True, 'always': True}, 'Positive'),
#  ({'u': True, 'never': True, 'call': True, ':(': True}, 'Negative'),
#  ({"we're": True,
#    'sorry': True,
#    'feel': True,
#    'way': True,
#    'shell': True,
#    ':(': True,
#    'regularly': True,
#    'review': True,
#    'pricing': True,
#    'offer': True,
#    'best': True},
#   'Negative'),
#  ({'goodnight': True,
#    'guy': True,
#    ':-)': True,
#    'remember': True,
#    'tomorrow': True,
#    'brand': True,
#    'new': True,
#    'day': True,
#    'fresh': True,
#    'start': True,
#    'another': True,
#    'chance': True},
#   'Positive'),
#  ({'hi': True,
#    'would': True,
#    'like': True,
#    'concert': True,
#    'let': True,
#    'know': True,
#    'city': True,
#    'country': True,
#    "i'll": True,
#    'start': True,
#    'work': True,
#    'thanks': True,
#    ':)': True},
#   'Positive'),
#  ({"i'm": True,
#    'keep': True,
#    'bug': True,
#    'spray': True,
#    'industry': True,
#    'business': True,
#    'something': True,
#    'bit': True,
#    'foot': True,
#    'swell': True,
#    'half': True,
#    'way': True,
#    'leg': True,
#    ':(': True},
#   'Negative'),
#  ({':(': True,
#    'disgust': True,
#    'piece': True,
#    'shit': True,
#    '..': True,
#    'amazing': True,
#    'mother': True,
#    'mateo': True,
#    'brooklyn': True,
#    'lucky': True,
#    '💗': True,
#    'deserve': True},
#   'Negative'),
#  ({'eat': True,
#    'rest': True,
#    'well': True,
#    ':(': True,
#    'tire': True,
#    '..': True},
#   'Negative'),
#  ({'forget': True,
#    'earth': True,
#    'delight': True,
#    'feel': True,
#    'bare': True,
#    'foot': True,
#    'wind': True,
#    'long': True,
#    'play': True,
#    'hair': True,
#    'kahlil': True,
#    'gibran': True,
#    ':)': True},
#   'Positive'),
#  ({'dont': True,
#    'really': True,
#    'know': True,
#    'sorry': True,
#    ':(': True,
#    'try': True,
#    'opening': True,
#    'paint': True,
#    'save': True},
#   'Negative'),
#  ({'bigbang': True,
#    'need': True,
#    'rest': True,
#    ':(': True,
#    'travel': True,
#    'one': True,
#    'place': True,
#    'another': True,
#    'must': True,
#    'really': True,
#    'tire': True},
#   'Negative'),
#  ({'heart': True, 'slide': True, 'waste': True, 'basket': True, ':(': True},
#   'Negative'),
#  ({'stats': True,
#    'day': True,
#    'arrive': True,
#    '1': True,
#    'new': True,
#    'follower': True,
#    'unfollowers': True,
#    ':)': True,
#    'via': True},
#   'Positive'),
#  ({'head': True, 'kill': True, ':(': True}, 'Negative'),
#  ({'drew': True, ':)': True, 'pls': True}, 'Positive'),
#  ({'follow': True, 'u': True, 'back': True, ':)': True}, 'Positive'),
#  ({'scheme': True, 'plan': True, 'yet': True, ':(': True}, 'Negative'),
#  ({'snapchat': True,
#    'jaclintiler': True,
#    '#snapchat': True,
#    '#teens': True,
#    '#models': True,
#    '#likeforlike': True,
#    '#mpoints': True,
#    '#hotfmnoaidilforariana': True,
#    ':(': True},
#   'Negative'),
#  ({'u': True,
#    'beautiful': True,
#    'man': True,
#    ':d': True,
#    'yeah': True,
#    'sometimes': True},
#   'Positive'),
#  ({'6248108': True,
#    '80khan': True,
#    'confidence': True,
#    'confined': True,
#    'u': True,
#    'ur': True,
#    'limits': True,
#    '...': True,
#    ':)': True},
#   'Positive'),
#  ({'thanks': True, ':(': True}, 'Negative'),
#  ({'take': True,
#    'ice': True,
#    'creamist': True,
#    'pleaseeeee': True,
#    ':(': True},
#   'Negative'),
#  ({'thank': True,
#    'come': True,
#    'last': True,
#    'night': True,
#    'great': True,
#    'see': True,
#    ':)': True},
#   'Positive'),
#  ({'yes': True,
#    'youre': True,
#    'right': True,
#    '..': True,
#    'sad': True,
#    'many': True,
#    'intolerant': True,
#    'scar': True,
#    'xenophobes': True,
#    ':-(': True},
#   'Negative'),
#  ({'p': True,
#    '£': True,
#    'heiya': True,
#    'visit': True,
#    'site': True,
#    'u': True,
#    'wanna': True,
#    'grab': True,
#    'free': True,
#    '30.000': True,
#    '8': True,
#    'ball': True,
#    'pool': True,
#    'coins': True,
#    'thank': True,
#    ':)': True},
#   'Positive'),
#  ({'sleep': True, "i'm": True}, 'Negative'),
#  ({'full': True,
#    'time': True,
#    'job': True,
#    'mean': True,
#    'gonna': True,
#    'part': True,
#    'fun': True,
#    ':(': True},
#   'Negative'),
#  ({'finally': True,
#    'get': True,
#    'bed': True,
#    ':)': True,
#    'good': True,
#    'night': True,
#    'tweeties': True},
#   'Positive'),
#  ({'feel': True,
#    'like': True,
#    "i'm": True,
#    'weird': True,
#    'person': True,
#    'ship': True,
#    'bellamy': True,
#    'raven': True,
#    'everyone': True,
#    'clarke': True,
#    'heart': True,
#    'want': True,
#    ':(': True},
#   'Negative'),
#  ({'aww': True,
#    "i've": True,
#    'get': True,
#    'fever': True,
#    ':(': True,
#    '#bad4thwin': True,
#    '<3': True},
#   'Negative'),
#  ({"i'm": True,
#    'look': True,
#    'forward': True,
#    'mine': True,
#    'go': True,
#    'next': True,
#    'year': True,
#    '3': True,
#    ':(': True},
#   'Negative'),
#  ({'😞': True, ':(': True}, 'Negative'),
#  ({'wait': True,
#    "we're": True,
#    'youtube': True,
#    'comment': True,
#    'section': True,
#    'video': True,
#    'slightly': True,
#    'mention': True,
#    'science': True,
#    ':)': True},
#   'Positive'),
#  ({'visit': True,
#    'greek': True,
#    'ruin': True,
#    'petra': True,
#    'back': True,
#    ':)': True},
#   'Positive'),
#  ({'fback': True, 'po': True, ':)': True}, 'Positive'),
#  ({'every': True,
#    'night': True,
#    'take': True,
#    'hella': True,
#    'melatonin': True,
#    'like': True,
#    '2-4': True,
#    'hour': True,
#    'nap': True,
#    "i'm": True,
#    'wide': True,
#    'awake': True,
#    'next': True,
#    'day': True,
#    ':(': True},
#   'Negative'),
#  ({'aw': True, 'fuck': True, 'suck': True, ':(': True}, 'Negative'),
#  ({"i'm": True, 'mean': True, ':(': True, 'sazballs': True, '❤': True},
#   'Negative'),
#  ({'fback': True, ':)': True}, 'Positive'),
#  ({"i'll": True,
#    'sit': True,
#    'android': True,
#    'phone': True,
#    'like': True,
#    ':)': True},
#   'Positive'),
#  ({'feeling': True, 'let': True, ':(': True, 'think': True, 'favourite': True},
#   'Negative'),
#  ({'people': True, 'change': True, 'always': True, 'good': True, ':(': True},
#   'Negative'),
#  ({'oh': True,
#    ':(': True,
#    'someone': True,
#    "i'm": True,
#    'close': True,
#    'maybe': True,
#    'help': True,
#    'sort': True,
#    'tell': True,
#    'though': True,
#    'xd': True,
#    'offer': True},
#   'Negative'),
#  ({'grepe': True, 'grepein': True, ':(': True}, 'Negative'),
#  ({'pains': True,
#    'propa': True,
#    'knockin': True,
#    'sick': True,
#    ':(': True,
#    'owwww': True},
#   'Negative'),
#  ({'bird': True,
#    'come': True,
#    'join': True,
#    'us': True,
#    'little': True,
#    'fun': True,
#    ':)': True,
#    '#teamadmicro': True},
#   'Positive'),
#  ({'thanks': True, 'bro': True, ':d': True, 'x': True}, 'Positive'),
#  ({'know': True,
#    ':(': True,
#    'askies': True,
#    'hai': True,
#    "that's": True,
#    'u': True,
#    'say': True,
#    'last': True,
#    'time': True},
#   'Negative'),
#  ({'trend': True,
#    '..': True,
#    'follow': True,
#    'bobble': True,
#    'link': True,
#    ':)': True},
#   'Positive'),
#  ({'yeah': True, 'sad': True, 'life': True, ':(': True}, 'Negative'),
#  ({'thank': True, ':)': True}, 'Positive'),
#  ({'sad': True,
#    'hear': True,
#    'thank': True,
#    'much': True,
#    'overwhelmingly': True,
#    'beautiful': True,
#    'game': True,
#    'hard': True,
#    'work': True,
#    ':)': True},
#   'Positive'),
#  ({'ended': True,
#    'soon': True,
#    't_t': True,
#    'hurt': True,
#    'one': True,
#    'eliminate': True,
#    "they're": True,
#    'good': True,
#    ':(': True,
#    '#teamzipal': True,
#    'smtm': True,
#    '4': True},
#   'Negative'),
#  ({'<3': True, 'guy': True, ':)': True}, 'Positive'),
#  ({'apartment': True,
#    'makeover': True,
#    'great': True,
#    'idea': True,
#    'factory': True,
#    'living': True,
#    ':)': True},
#   'Positive'),
#  ({'first': True,
#    'two': True,
#    'day': True,
#    'katies': True,
#    'summer': True,
#    'back': True,
#    'forth': True,
#    'doctor': True,
#    'suspect': True,
#    'meningitis': True,
#    'viral': True,
#    'tonsillitis': True,
#    ':(': True,
#    'poorly': True,
#    'girl': True,
#    '😷': True},
#   'Negative'),
#  ({'hello': True,
#    'info': True,
#    'possible': True,
#    'interest': True,
#    'jonathas': True,
#    'close': True,
#    'join': True,
#    'betis': True,
#    ':(': True,
#    'greatings': True},
#   'Negative'),
#  ({'go': True, ':(': True}, 'Negative'),
#  ({'write': True, 'english': True, ':)': True}, 'Positive'),
#  ({'indian': True,
#    'fan': True,
#    'really': True,
#    'miss': True,
#    'uu': True,
#    'dear': True,
#    'us': True,
#    ':(': True},
#   'Negative'),
#  ({'yeah': True,
#    'everyone': True,
#    'wake': True,
#    'morning': True,
#    "they'll": True,
#    'see': True,
#    'big': True,
#    'pile': True,
#    'dump': True,
#    ':)': True,
#    'cool': True},
#   'Positive'),
#  ({'friend': True,
#    'whatsoever': True,
#    'lol': True,
#    ':(': True,
#    'oh': True,
#    'well': True},
#   'Negative'),
#  ...]

# %%
from nltk import classify
from nltk import NaiveBayesClassifier
classifier = NaiveBayesClassifier.train(train_data)

print("Accuracy is:", classify.accuracy(classifier, test_data))

print(classifier.show_most_informative_features(10))
# Out:
# Accuracy is: 0.9946666666666667
# Most Informative Features
#                       :( = True           Negati : Positi =   2080.5 : 1.0
#                       :) = True           Positi : Negati =   1639.6 : 1.0
#                 followed = True           Negati : Positi =     26.8 : 1.0
#                      sad = True           Negati : Positi =     26.3 : 1.0
#                 follower = True           Positi : Negati =     23.0 : 1.0
#                      x15 = True           Negati : Positi =     18.6 : 1.0
#                community = True           Positi : Negati =     14.8 : 1.0
#                   arrive = True           Positi : Negati =     13.6 : 1.0
#                      bro = True           Positi : Negati =     13.4 : 1.0
#            unfortunately = True           Negati : Positi =     13.2 : 1.0
# None

# %%
from nltk.tokenize import word_tokenize

custom_tweet = "I ordered just once from TerribleCo, they screwed up, never used the app again."

custom_tokens = remove_noise(word_tokenize(custom_tweet))

print(classifier.classify(dict([token, True] for token in custom_tokens)))
# Out:
# Negative

# %%
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import twitter_samples, stopwords
from nltk.tag import pos_tag
from nltk.tokenize import word_tokenize
from nltk import FreqDist, classify, NaiveBayesClassifier

import re, string, random

def remove_noise(tweet_tokens, stop_words = ()):

    cleaned_tokens = []

    for token, tag in pos_tag(tweet_tokens):
        token = re.sub('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+#]|[!*\(\),]|'\
                       '(?:%[0-9a-fA-F][0-9a-fA-F]))+','', token)
        token = re.sub("(@[A-Za-z0-9_]+)","", token)

        if tag.startswith("NN"):
            pos = 'n'
        elif tag.startswith('VB'):
            pos = 'v'
        else:
            pos = 'a'

        lemmatizer = WordNetLemmatizer()
        token = lemmatizer.lemmatize(token, pos)

        if len(token) > 0 and token not in string.punctuation and token.lower() not in stop_words:
            cleaned_tokens.append(token.lower())
    return cleaned_tokens

def get_all_words(cleaned_tokens_list):
    for tokens in cleaned_tokens_list:
        for token in tokens:
            yield token

def get_tweets_for_model(cleaned_tokens_list):
    for tweet_tokens in cleaned_tokens_list:
        yield dict([token, True] for token in tweet_tokens)

if __name__ == "__main__":

    positive_tweets = twitter_samples.strings('positive_tweets.json')
    negative_tweets = twitter_samples.strings('negative_tweets.json')
    text = twitter_samples.strings('tweets.20150430-223406.json')
    tweet_tokens = twitter_samples.tokenized('positive_tweets.json')[0]

    stop_words = stopwords.words('english')

    positive_tweet_tokens = twitter_samples.tokenized('positive_tweets.json')
    negative_tweet_tokens = twitter_samples.tokenized('negative_tweets.json')

    positive_cleaned_tokens_list = []
    negative_cleaned_tokens_list = []

    for tokens in positive_tweet_tokens:
        positive_cleaned_tokens_list.append(remove_noise(tokens, stop_words))

    for tokens in negative_tweet_tokens:
        negative_cleaned_tokens_list.append(remove_noise(tokens, stop_words))

    all_pos_words = get_all_words(positive_cleaned_tokens_list)

    freq_dist_pos = FreqDist(all_pos_words)
    print(freq_dist_pos.most_common(10))

    positive_tokens_for_model = get_tweets_for_model(positive_cleaned_tokens_list)
    negative_tokens_for_model = get_tweets_for_model(negative_cleaned_tokens_list)

    positive_dataset = [(tweet_dict, "Positive")
                         for tweet_dict in positive_tokens_for_model]

    negative_dataset = [(tweet_dict, "Negative")
                         for tweet_dict in negative_tokens_for_model]

    dataset = positive_dataset + negative_dataset

    random.shuffle(dataset)

    train_data = dataset[:7000]
    test_data = dataset[7000:]

    classifier = NaiveBayesClassifier.train(train_data)

    print("Accuracy is:", classify.accuracy(classifier, test_data))

    print(classifier.show_most_informative_features(10))

    custom_tweet = "I ordered just once from TerribleCo, they screwed up, never used the app again."

    custom_tokens = remove_noise(word_tokenize(custom_tweet))

    print(custom_tweet, classifier.classify(dict([token, True] for token in custom_tokens)))
# Out:
# [(':)', 3691), (':-)', 701), (':d', 658), ('thanks', 388), ('follow', 357), ('love', 333), ('...', 290), ('good', 283), ('get', 263), ('thank', 253)]
# Accuracy is: 0.9936666666666667
# Most Informative Features
#                       :) = True           Positi : Negati =    999.4 : 1.0
#                      bam = True           Positi : Negati =     23.3 : 1.0
#                      sad = True           Negati : Positi =     22.2 : 1.0
#                 follower = True           Positi : Negati =     20.7 : 1.0
#                      x15 = True           Negati : Positi =     17.9 : 1.0
#                     poor = True           Negati : Positi =     16.6 : 1.0
#                 followed = True           Negati : Positi =     15.2 : 1.0
#                     luck = True           Positi : Negati =     14.1 : 1.0
#                      ugh = True           Negati : Positi =     13.9 : 1.0
#               appreciate = True           Positi : Negati =     12.8 : 1.0
# None
# I ordered just once from TerribleCo, they screwed up, never used the app again. Negative
