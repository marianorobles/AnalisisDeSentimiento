# %%
import pandas as pd
import re

# %%
with open('Chat de WhatsApp con Mi RucA.txt') as f:
    lines = f.readlines()

# %%
df=pd.DataFrame(lines)
df
# Out:
#                                                        0
# 0        17/05/22 2:19 p. m. - Mariano Robles: Gracias\n
# 1      17/05/22 2:20 p. m. - Mariano Robles: Pues ya ...
# 2      17/05/22 2:20 p. m. - Mariano Robles: Y ya aca...
# 3      17/05/22 2:20 p. m. - Mariano Robles: Ya solo ...
# 4      17/05/22 2:20 p. m. - Mariano Robles: Pero ya ...
# ...                                                  ...
# 42308  18/11/22 6:19 a. m. - Mariano Robles: Ven jaja...
# 42309  18/11/22 6:19 a. m. - Mi RucA: Es que voy a ll...
# 42310  18/11/22 6:20 a. m. - Mi RucA: Y sí me da peni...
# 42311  18/11/22 6:20 a. m. - Mi RucA: Aunque sí avanc...
# 42312          18/11/22 7:30 a. m. - Mariano Robles: 🙁\n
#
# [42313 rows x 1 columns]

# %%
df=df[0].str.replace('^[\s\S]+:','',regex=True)
#df=df[0].replace('\n','',regex=True)

# %%
df.to_csv('platica.csv',index=False)

# %%
df=pd.read_csv('platica.csv')

# %%
df.head()
# Out:
#                                                    0
# 0                                          Gracias\n
# 1             Pues ya solo le voy a poner el error\n
# 2         Y ya acabamos de menos la parte práctica\n
# 3              Ya solo faltaría redactar más cosas\n
# 4   Pero ya quiero sentir que un proyecto ya quedó\n

# %%
inicio=137+25+72+94
inicio
# Out:
# 328

# %%
lista=[]
for indice,fila in df.iloc[inicio:].iterrows():
    print(fila[0])
    sentimiento=int(input())
    lista.append(sentimiento)
# Out:
#  Te iba a pedir que te pusieras a cantar
#
# 1
#  Jajajajajaja
#
# 1
#  La de los países, no? Jajajajajsj
#
# 0
#  Qué crees? El lunes me pidieron revisar un tablero porque no salían unos datos y conmigo tampoco salían jaja
#
# -1
# Pero ya quedó hace rato👍
#
# 1
#  Wuuuuu
#
# 1
#  Jajaja pero estuvo chistoso porque fue de esas veces donde ya intentaste todo
#
# 0
#  Y no sale jajaja
#
# -1
#  Y ya lo haces de nuevo como para ver qué sale pero igual ya probaste todo todo jajaja
#
# 0
#  Y salió jaua
#
# 0
#  Abiiiiiii
#
# 0
#  Acabo de recordar que me dijiste que hicieramos algo hoy
#
# 0
#  Y... no se si aún quieras
#
# 0
#  O puedas
#
# 0
#  No recuerdo cuándo dije eso
#
# 0
#  Pero es algo que 100% diría
#
# 0
#  Jajajaja
#
# 1
#  Ayer jajajaja
#
# 0
#  Jalas?
#
# 1
#  Para festejar jajaja
#
# 1
#  Neta???
#
# 0
#  No?
#
# 0
#  Omggg Mariano no me acuerdo jajajajaja
#
# 0
#  Qué horror
#
# -1
#  Pero obvio
#
# 1
#  Que si adelantaba lo de visualización
#
# 0
#  Y hacíamos algo hoy
#
# 0
#  No?
#
# 0
#  Ah creo que sí sisisi
#
# 0
#  Más o menos
#
# 0
#  Pero sí, neta
#
# 0
#  Si tú quieres
#
# 0
#  Porque ps también hay tareas y eso y si dices que no, no tengo problema
#
# 0
#  Pero yo sí súper jalo
#
# 1
#  Marianoooooo
#
# 0
#  Jajajajajajaja
#
# 1
#  Estoy en una llamada con la otra becaria
#
# 0
#  Y dije "pene"
#
# 0
#  En vez de "pone"
#
# 0
#  Jajajajajajajaj
#
# 1
#  Pensé en que sería algo de lo que te burlarías
#
# -1
#  Sí, pero mañana les dedicaré mucho tiempo ya que no tengo estadística
#
# 0
#  Jajajaajajajajajajajaajaja
#
# 1
#  No ma, Sigmund Freud tiene teorías al respecto
#
# 0
#  Pero tú me avisas a que hora te veo
#
# 0
#  Mi mamá diría "El que en pan piensa..."
#
# 0
#  Jajajajajajajajaja okno
#
# 1
#  Jajaja mañana sí es presencial con Pablo, no?
#
# 0
#  Qué onda con que sí todo el semestre estuvo super desincronizado
#
# 0
#  Está cool así
#
# 1
#  Solo ir a una
#
# 0
#  <Multimedia omitido>
#
# -2
#  Jajajajajaja está buenazo
#
# 1
#  <Multimedia omitido>
#
# -2
#  No me he bañado
#
# -1
#  Estás en clase ahorita, no?
#
# 0
#  Aún no
#
# 0
#  Y tenemos Mahil de 1 a 3
#
# 0
#  Ey
#
# 0
#  La vas a tomar en fesss?
#
# 0
#  O en el heraldo jajaja
#
# 0
#  Jajajajajaja
#
# 1
#  Mariano, no puedes llegar tan rápido
#
# 0
# 30
#
# 0
#  Vamos a ir ahí?
#
# 0
#  O qué plannnn?
#
# 0
#  No sé jajaja
#
# 0
#  Uy, podríamos ir a probar el otro que te dije
#
# 0
#  No tengo plan
#
# -1
#  O al cinema
#
# 1
#  Va
#
# 1
#  Algo más decente
#
# 0
#  Va
#
# 1
#  Jajajajajajaja
#
# 1
#  Si quieres
#
# 0
#  Hay algo?
#
# 0
#  Uy, en Buenavista está Jurassic Park
#
# 1
#  Va
#
# 1
#  A las 4
#
# 0
#  Creo que queda bien, no?
#
# 1
#  Jajajaja en otro está rocky IV
#
# 1
#  Guau, hace cuánto no hacemos algo no seggsual como pareja?
#
# 0
#  Cuál es esa?
#
# 0
#  La del ruso?
#
# 0
#  Doctor strange?
#
# 0
#  O esa es la3?
#
# 0
#  Ah no, luego fuimos
#
# 0
#  Esa
#
# 0
#  Pero después pasaron cosas nalas
#
# -1
#  Uyyyyyy
#
# 1
#  Mariano
#
# 0
#  Ambas me gustan mucho
#
# 1
#  Jajaja
#
# 1
#  Me gusta mas jurassic
#
# 1
#  La verdad
#
# 0
#  Sonic jajaja ya vi la 1
#
# 1
#  Cuando dices cosas así, me enamoro
#
# 1
#  Jajajajajajajaja
#
# 1
#  Qué tal está?
#
# 0
#  La 1 está chistosa la neta
#
# 1
#  O sea no es la gran cosa
#
# -1
#  Pero pues para niños está cool
#
# 1
#  Sonic me cayó muuuuy bien
#
# 1
#  Mauricio Wenceslao y Winston Estanislao la podrán ver?
#
# 1
#  100% es para niños
#
# 1
#  Abi...
#
# 0
#  Voy a ser honesto
#
# -1
#  Tengo ganas de otro plan
#
# 0
#  Pero... vamos a tener el sábado para eso
#
# 0
#  De qué?
#
# 0
#  Ohhhh
#
# 0
#  Uhhhh
#
# 1
# 50
#
# 0
#  Y como es cerca del estado, es mucho más barato un boleto 3D que uno normal en la cdmx jajajajajajaj
#
# 1
#  Y empieza 15-20 minutos después
#
# 0
# 30, tenemos tres horas
#
# 0
#  Y si Mahil acaba antes y nos vemos a las 3
#
# 0
#  Son tres horas y media
#
# 0
#  <Multimedia omitido>
#
# -2
#  Jajajajajaja la película no era a las 4?
#
# 0
#  No, abi, está bien jajajaja
#
# 1
#  El sábado vamos a tener un buen de tiempo
#
# 1
#  <Multimedia omitido>
#
# -2
#  <Multimedia omitido>
#
# -2
#  <Multimedia omitido>
#
# -2
#  Jajajaajaja
#
# 1
#  O sea pero no pasa nada
#
# 0
#  Podemos esperarnos
#
# 1
#  A este ritmo me vas a decir "No, esperemos al matrimonio"
#
# 1
#  Pero está bien
#
# 1
#  Me conoces bien
#
# 1
#  Ya es la segunda vez que me rechazas
#
# -1
#  <Multimedia omitido>
#
# -2
#  Cuándo más?
#
# 0
#  Abi, yo soy el que te dijo que tiene ganas
#
# 1
#  Jajajjaa no me acuerdo pero sé que fue apenas
#
# 0
#  Tal vez el lunes?
#
# 0
#  El martes?
#
# 0
#  Neta noooo
#
# -1
#  Sé que tuvimos la misma conversación
#
# 0
#  Para nada
#
# -1
#  Fue al revés justo
#
# 0
#  Jajajajaja no abuses de mi mala memoria
#
# -1
#  No, sí?
#
# 0
#  Ahhhhhh noooo
#
# -1
#  Ya me acordé
#
# 1
#  Jajajajajajajajaja
#
# 1
#  El lunes te dije que el martes 😏😏
#
# 1
#  Y tú me dijiste que no
#
# 0
#  Y el martes me dijiste 😏😏
#
# 1
#  Y yo te dije que no porque el lunes me habías dicho que no
#
# -1
#  Jajajajaajajaj que fea eres
#
# -1
#  Jajajajajaja
#
# 1
#  Ahorita me dijiste 😏😏
#
# 1
#  Y yo te dije 😏😏
#
# 1
#  Y luego me dijiste que no
#
# -1
#  Y yo soy la fea?
#
# -1
#  En fin, la hipotenusa
#
# 1
#  No mandes mensaje, voy a ver YouTube en mi celular con mi papá akajajajajaj
#
# 1
#  Jajajaajajajaajajaja
#
# 1
#  😈😈😈😈😈
#
# 1
#  Entonces no hablo de como te emborrachaste el otro día y golpeaste a mi hermana?
#
# -1
#  Jajajajajajaja qué te pasa?
#
# -1
#  Qué bueno que no salieron
#
# 1
#  Pero sí estaba en YouTube
#
# 0
#  Ese sí salió
#
# 0
#  Pero lo quité jaja
#
# 0
#  Si hiciera eso, terminarías conmigo?
#
# -1
#  Probablemente
#
# 0
#  Depende de porque se pelean
#
# -1
#  Jajajaja no se lo hubiera creido
#
# -1
#  Qué razón sería lo suficientemente buena para que no lo hicieras?
#
# 0
#  Te faltó al respeto de forma muuuuy cañona
#
# -1
#  O sea así neta te insultó muy feo
#
# -1
#  Jajajajajaja
#
# 1
#  Es que verga jajaja sí se pone muy agresiva peda
#
# -1
#  Así que neta sí lo considero una posibilidad
#
# 0
#  No, ni siquiera estando sobria yo tendría oportunidad con tu hermana jajajaja
#
# 0
#  Siento que ella sí pelearía feo jajajajajaja
#
# -1
#  Y yo solo querría salir corriendo
#
# -1
#  Jajajajajajajajaja
#
# 1
#  Jajajajaja sí, sería ñera jajajaajajaja
#
# -1
#  Yo tengo recuerdos de nuestras peleas jajajaaja
#
# -1
#  De niños obviamente jajajaaj
#
# 0
#  Peleaban en serio?
#
# -1
#  O solo de juego?
#
# 0
#  Lo llegamos a hacer
#
# 0
#  No, nunca jajajaja
#
# 0
#  Jajajajajajajaja ????
#
# 0
#  Esas respuestas eran al revés
#
# 0
#  Jajajajajaja
#
# 1
#  Con mi papá peleaba de juego
#
# 1
#  Era bien divertido
#
# 1
#  Ay, yo también
#
# 0
#  Es bien cool no?
#
# 1
#  Jajajajaj justo le estaba enseñando las peleas del tal John Wick
#
# 0
#  Siiiii
#
# 1
#  Mucho mucho
#
# 1
#  Jajajaajajajajaja cuál?
#
# 0
#  Sí es de mis recuerdos favoritos
#
# 1
#  Las dos
#
# 0
#  Jajajajajajaj
#
# 1
#  Y le gustaron bastante
#
# 1
#  Jajajajaaj noooo, la del ojo?
#
# 0
#  Jajaajajaj
#
# 1
#  Y le dije que para cuándo los lanzamientos con cuchillo
#
# 0
#  Esa fue la que más le gustó
#
# 1
#  Nanabababa
#
# 0
#  Hacha*
#
# 0
#  Jajajaja ke
#
# 0
#  No se me antoja tanto pero también me gustaría
#
# 0
#  😞
#
# -1
#  Jajajajajajaja no sé
#
# 0
#  Era un jajajajaja
#
# 0
#  Noe dijo que también hay de cuchillos
#
# 0
#  Per bajé mucho el pulgar al parecer
#
# 0
#  Las peleas callejeras en la esquina no valen
#
# 0
#  Sí estaría cool ir a lanzar cuchillos
#
# 0
#  Hay que tener una date así
#
# 1
#  Supongo que en la marquesa o algún lugar de ese tipo debe tener
#
# 0
#  Ah pues tú dijiste que conoces gente que ha ido
#
# 0
#  Diles que rolen ubi
#
# 1
#  Marianooooo
#
# 0
#  No sé qué ponerme
#
# 0
#  😮‍💨😮‍💨😮‍💨
#
# -1
#  Qué vamos a hacer?
#
# 0
#  <Multimedia omitido>
#
# -2
#  Jajajajajajajajajajajaja
#
# 1
#  Un momento, es acaso una ss tuya?
#
# 0
#  No manches abi, obvio no jajajajaajaj
#
# -1
#  <Multimedia omitido>
#
# -2
#  Rip
#
# -1
#  Jajajajaajajajajajajajaajaj sería la peor mierda del mundo si lo fuera
#
# -1
#  Tenía un buen meme de respuesta
#
# 1
#  👀
#
# 1
#  Ese jajajajajajaj
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_32358/3396488222.py in <module>
#       2 for indice,fila in df.iloc[inicio:].iterrows():
#       3     print(fila[0])
# ----> 4     sentimiento=int(input())
#       5     lista.append(sentimiento)
#
# ValueError: invalid literal for int() with base 10: ''

# %%
# 616
final=len(lista)
final
# Out:
# 235

# %%
df2=df.iloc[inicio:inicio+final].copy()

# %%
df2=df2.reset_index()

# %%
df2['sentimiento']=pd.Series(lista)

# %%
df2=df2.drop('index',axis=1)
df2
# Out:
#                                                      0  sentimiento
# 0            Te iba a pedir que te pusieras a cantar\n            1
# 1                                       Jajajajajaja\n            1
# 2                  La de los países, no? Jajajajajsj\n            0
# 3     Qué crees? El lunes me pidieron revisar un ta...           -1
# 4                           Pero ya quedó hace rato👍\n            1
# ..                                                 ...          ...
# 230                             <Multimedia omitido>\n           -2
# 231                                              Rip\n           -1
# 232   Jajajajaajajajajajajajaajaj sería la peor mie...           -1
# 233                  Tenía un buen meme de respuesta\n            1
# 234                                                👀\n            1
#
# [235 rows x 2 columns]

# %%
df2.to_csv('final(3).csv',index=False,mode='a',index_label=False)
