# %%
import pandas as pd
import re

# %%
with open('Chat de WhatsApp con Ciencia de datos Acatlán.txt') as f:
    lines = f.readlines()

# %%
df=pd.DataFrame(lines)
df
# Out:
#                                                       0
# 0     09/08/21 2:15 p. m. - Los mensajes y las llama...
# 1     09/08/21 2:14 p. m. - ‎Gabo CD creó el grupo "...
# 2     09/08/21 2:15 p. m. - Te uniste mediante el en...
# 3     09/08/21 2:15 p. m. - ‎Gustavo Alvarez se unió...
# 4     09/08/21 2:25 p. m. - ‎Francisco CD se unió us...
# ...                                                 ...
# 8052  04/11/22 7:59 p. m. - Mi RucA: <Multimedia omi...
# 8053  05/11/22 6:49 a. m. - Francisco CD: Buenos día...
# 8054  05/11/22 6:50 a. m. - Mi RucA: Quién sabe, por...
# 8055  05/11/22 6:51 a. m. - Francisco CD: Vaaa le pr...
# 8056  05/11/22 6:51 a. m. - Francisco CD: Gracias Ab...
#
# [8057 rows x 1 columns]

# %%
df=df[0].str.replace('^[\s\S]+:','',regex=True)

# %%
df.to_csv('platica.csv',index=False)

# %%
df=pd.read_csv('platica.csv')

# %%
df.head()
# Out:
#                                                    0
# 0  15 p. m. - Los mensajes y las llamadas están c...
# 1  14 p. m. - ‎Gabo CD creó el grupo "Ciencia de ...
# 2  15 p. m. - Te uniste mediante el enlace de inv...
# 3  15 p. m. - ‎Gustavo Alvarez se unió usando el ...
# 4  25 p. m. - ‎Francisco CD se unió usando el enl...

# %%
inicio=616+556+304+81+217+318+82+494+495+209+152+192+142+333+317+120+440+145+48+587+583
inicio
# Out:
# 5848

# %%
lista=[]
for indice,fila in df.iloc[inicio:].iterrows():
    print(fila[0])
    sentimiento=int(input())
    lista.append(sentimiento)
# Out:
#  Mandan el link
#
# 0
#  <Multimedia omitido>
#
# -2
#  Si se conecto?
#
# 0
#  Sí
#
# 0
#  <Multimedia omitido>
#
# -2
#  <Multimedia omitido>
#
# -2
# //us02web.zoom.us/j/88139655239?pwd=S1c5VzVhZUZlUWJpVzRnR2k1bk5DUT09
#
# -2
#  <Multimedia omitido>
#
# -2
#  Ahorita me uno jaja
#
# 0
#  <Multimedia omitido>
#
# -2
#  Que mañana no hay clase @5215586893177
#
# 0
#  ya sellaron todos su credencial?
#
# 0
#  No
#
# 0
#  Tu ya?
#
# 0
#  <Multimedia omitido>
#
# -2
#  X2
#
# 0
#  Me da un vergo de hueca ir
#
# -1
#  <Multimedia omitido>
#
# -2
#  Hazlo por las bicis we
#
# 1
#  Wey se me hace una mamada tener que ir hasta allá por esa mamada
#
# -1
#  <Multimedia omitido>
#
# -2
#  De huevos deberíamos poder hacerlo en la fes
#
# -1
#  <Multimedia omitido>
#
# -2
#  <Multimedia omitido>
#
# -2
#  yo le caigo hoy
#
# 0
#  justo por esto jajajaajajajajja
#
# 1
#  Y de ahi un sambucazo
#
# 1
#  voy a sellarla y me voy a dar un paseo
#
# 1
#  Puta que rico
#
# 1
#  Ve a sambuca we
#
# 1
#  Omgggg yo tambiénnnn
#
# 1
#  Vayan a sambuca
#
# 1
#  no puedo tengo el fokin servicio
#
# -1
#  Nooo weee
#
# -1
#  Bueno chance no estaba tan cool porque un buen de facs estan en paro
#
# -1
#  si we ya se media unam jajaja
#
# 0
#  a que hora le caes abiato
#
# 0
# 00
#
# -2
#  Oigan pero el sello solo sirve para lo que queda del año no?
#
# -1
#  <Multimedia omitido>
#
# -2
#  Según yo, es para octavo también
#
# 0
#  O te referías al año escolar? Jajaja
#
# 0
#  Porque si sí, sí
#
# 1
#  <Multimedia omitido>
#
# -2
#  Aaaa
#
# 0
#  Ni pedo voy a tener que ir
#
# -1
#  te paso el horario
#
# 0
#  Porfa
#
# 0
#  aue me dio mi estimada Erika
#
# 1
#  Jajajajajaja
#
# 1
#  <Multimedia omitido>
#
# -1
#  pero voy a ir hoy porque ya amenazaron en el grupo que hoy es el ultimo dia
#
# -1
#  Mmm bueno ni pedo
#
# -1
#  Un baño y a ir
#
# 0
#  <Multimedia omitido>
#
# -2
#  Tu a qué hora vas a ir?
#
# 0
#  en una horita jaja
#
# 0
#  llego
#
# 0
#  espero 🛐
#
# 1
#  Jajaja
#
# 1
#  Ripppp
#
# -1
#
#
# -2
#  JAJAJAJAJAJAJAJAJA
#
# 1
#  Ya por dios que se resbale esa señora y no se levante
#
# -1
#  <Multimedia omitido>
#
# -2
#  Jajajajaj groserote
#
# -1
#  Pero sí
#
# 0
#  #Incómodo
#
# -1
#  <Multimedia omitido>
#
# -2
#  Eso no le quita lo cierto
#
# 0
#  <Multimedia omitido>
#
# -2
#  Ya me dijo porqué jajaja
#
# 0
# Solo porque el sello dice iimas
#
# 0
#  Y por la sede y eso
#
# 0
#  Oh
#
# 0
#  Dónde era ?
#
# 0
#  Tercer piso
#
# 0
#  Como a la mitad
#
# 0
#  Vale gracias
#
# 1
#  <Multimedia omitido>
#
# -2
#  niña, niño o Francisco?🤨
#
# 0
#  Los 3
#
# 0
#  <Multimedia omitido>
#
# -2
#  <Multimedia omitido>
#
# -2
#  Abi todos lo estábamos evitando
#
# -1
#  Por salud mental
#
# 0
#  <Multimedia omitido>
#
# -2
#  <Multimedia omitido>
#
# -2
#  me avisan cuando empiece? por fa
#
# 0
#  va
#
# 1
#  Ya lo volví a amar, lo siento gus
#
# 1
#  Wey lo amas
#
# 1
#  Porque ya dijo que lo vas a ver menos
#
# 0
#  Eso es amar?
#
# 0
#  Ojo ahí @5215538430946
#
# -1
#  <Multimedia omitido>
#
# -2
#  Igual ya habló de examen, ya no lo amo de nuevo
#
# -1
#  JAJAJAJAJAJAJAJA
#
# 1
#  Pero va a dar guía
#
# 0
#  Miden lo de una biblia
#
# 0
#  Pero pues si es un parote
#
# 1
#  <Multimedia omitido>
#
# -2
#  Nah mames como que ya se va a acabar el semestre
#
# -1
#  <Multimedia omitido>
#
# -2
#  Desde que ví cómo Leonardo lo veía, entendí cómo sería este trip
#
# 1
#  JAJAJAJAJAJAJAJA
#
# 1
#  Es que Abi, yo también me iría si me vieran con esos ojos de amor
#
# 1
#  <Multimedia omitido>
#
# -2
#  Fuck, son dos pendientes jajaja
#
# -1
#  ya empezo la practica?
#
# 0
#  o eso lo vimos la clase pasada
#
# 0
#  Pasada
#
# 0
#  Ei
#
# 0
#  Clase pasada
#
# 0
#  gracias
#
# 1
#  llevamos 3 practicas?
#
# 0
#  porque neta si son 4
#
# 0
#  no me acuerdo de la pasada
#
# -1
#  4
#
# -2
#  Es que fue cuando faltamos
#
# -1
#  Jajaja
#
# 1
#  Y luego fue el paro
#
# 0
#  Ah cierto no fueron ese día
#
# 0
#  <Multimedia omitido>
#
# -2
#  Si slguien sube la 4 en lugar de la 3 va a ser una mamada jajajaja
#
# -1
#  Jajajajajaja
#
# 1
#  Dijo que las presentaciones las sube?
#
# 0
#  Según esto
#
# 0
#  sí pero dile para que no se le olvide jajajaj
#
# 0
#  porque yo se las pedí hace un mes jajaja
#
# 0
#  alaaaa
#
# -1
#  donde las sube?
#
# 0
#  en el onedrive?
#
# 0
#  En el sea no?
#
# 0
#  <Multimedia omitido>
#
# -2
#  omggggg
#
# 1
#  es verdad
#
# 1
#  Ahí
#
# 0
#  ahí están todas
#
# 0
#  perdóname eloy por dudar de ti
#
# -1
#  Oh
#
# 0
#  Y si está la de hoy?
#
# 0
#  en el sea no sube nada jajaj
#
# 0
#  Ya las subió
#
# 0
#  Porque no tome captura de nada
#
# 0
#  ?
#
# 0
#  <Multimedia omitido>
#
# -2
#  Yo tampoco jajajajajajaja
#
# 0
#  Fui a hacer cafecito
#
# 0
#  Creí que se iría con calma
#
# 0
#  yo si pero en cachos jajajajaj
#
# 0
#  Pan
#
# 0
#  si no?
#
# 0
#  parecia speedrun
#
# 0
#  Y dije ya ahora sí se viene lo rico
#
# 0
#  Y pum
#
# 0
#  Nos vemos el miércoles chicos
#
# 0
#  <Multimedia omitido>
#
# -2
#  ni modo
#
# -1
#  Jajajaja
#
# 0
#  yo tomé algunas
#
# 0
#  me hundo en quehaceres
#
# -1
#  pero creo que sí está la de hoy
#
# 0
#  es la 17
#
# 0
#  igual les mando lo que tomé
#
# 0
#  Va
#
# 0
#  <Multimedia omitido>
#
# -2
#  <Multimedia omitido>
#
# -2
#  <Multimedia omitido>
#
# -2
#  <Multimedia omitido>
#
# -2
#  <Multimedia omitido>
#
# -2
#  <Multimedia omitido>
#
# -2
#  Gracias abi
#
# -2
#  cuál gracias pasen la práctica 4 pls
#
# 1
#  wuuuu gracias
#
# 1
#  cual es la 3?
#
# 0
#  por favor
#
# 0
#  te la paso
#
# 1
#  Pero bueno, con las diapositivas
#
# 1
#  ya están todas
#
# 0
#  no?
#
# 0
#  o sea, las prácticas vienen en las diapositivas
#
# 0
#  El Notebook?
#
# 0
#  z pues si
#
# 0
#  oigan, que si quieren clase de jacobo jeje
#
# 1
#  Pues todas las clases se van a dar no?
#
# 0
#  Jajaja no, no es cierto gvs, era bromaska, ya con las diapos estoy bien, thxxx
#
# 1
#  pero el pues creo qeu no
#
# 0
#  verguerabi
#
# -1
#  Segurolas?
#
# 1
#  <Multimedia omitido>
#
# -2
#  Andaba buscando cuál era jaja
#
# 0
#  Ah
#
# 0
#  Pues yo sí la puedo tomar
#
# 1
#  Para ya decirle que tenga sus chingaderas
#
# -1
#  <Multimedia omitido>
#
# -2
#  qeu chingaderas?
#
# -1
#  Está muy larga?
#
# 0
#  Y que pase tutorial de como hizo su página con NFT's
#
# 0
#  yo si necesito su presencia
#
# 1
#  Amm pues las prácticas
#
# 0
#  Oigan, sí le van a decir lo del hackaton?
#
# 0
#  Y a ver si ya nos deja exponer el culero para saber que investigaron ustedes jaja
#
# -1
#  Pues no se si directamente que se rife con el equipo
#
# 0
#  Pero yo al menos si lo voy atosigar
#
# -1
#  <Multimedia omitido>
#
# -2
#  Porque dudas hay muchas
#
# -1
#  <Multimedia omitido>
#
# -2
#  Es que son varios Notebooks
#
# 0
#  Pero pues ya sabes que luego son puro copypaste
#
# 0
#  De la anterior
#
# 0
#  Pero bueno tons si clase con Jacob?
#
# 0
#  Sí, sin problema👍
#
# 1
#  Me da un poquito de flojera, no mentiré
#
# -1
#  Pero también me cae muy bien
#
# 1
#  Y como dijo Mariano, él fue el primero en ofrecerse jaja
#
# 1
#  No vamos a tener clase jajaja seguro solo nos va a hablar de sus nfts
#
# 0
#  Pero ahora sí sirve
#
# 1
#  solo hay que hacer la pregunta correcta
#
# 1
#  <Multimedia omitido>
#
# -2
#  Ey
#
# 0
#  Que por cierto, creen que la llamada se pueda en la noche? Tengo que llevar a mi hermana a hacerse unos estudios
#
# 0
#  A mí me queda chido en la noche 👌
#
# 1
#  Sip
#
# 0
#  Si a todos también les parece hay que proponer hora y decirle al profe
#
# 1
#  También si no puedes, no pasa nada
#
# 0
#  <Multimedia omitido>
#
# -2
#  No, sí puedo, solo me dio miedo que fuera a ser como de 1 a 4
#
# 0
#  Ah ya
#
# 0
#  Tons a qué hora le acomoda a todos?
#
# 1
#  Mmmm por qué no de 9 a 11?
#
# 0
#  Ahhhh esperen
#
# -1
#  Mañana es de tres horas jaja
#
# 0
#  No, estamos hablando de una con jl
#
# 0
#  Lo decía para tenerla en vez de finanzas
#
# 0
#  Qué?
#
# 0
#  Jajajaja
#
# 1
#  <Multimedia omitido>
#
# -2
#  No era de Jacobo?
#
# 0
#  Nop
#
# 0
#  O sea cada quien sería en su hora
#
# 0
#  Es del reto jajaja
#
# 0
#  Ahhhh jajajajajajajaja
#
# 1
#  Mañana a la hora que digan
#
# 1
#  Si es lo de bancomer no?
#
# 0
#  Es hoy jajaja
#
# 1
#  9 de la noche?
#
# 0
#  Esque dijeron de 9-11
#
# 0
#  No jajaja aún no tenemos hora
#
# 0
#  Va
#
# 0
#  A la hora que digan aún así
#
# 0
#  Cuántas horas de diferencia son contigo wey?
#
# 0
#  <Multimedia omitido>
#
# -2
#  Solo no se mamen
#
# -1
#  6
#
# -2
#  Pero mañana no tengo escuela
#
# 0
#  <Multimedia omitido>
#
# -2
#  Pero no quiero dormirme a las 3 am jaja
#
# -1
#  No te apures
#
# 1
#  Te levantamos a las 4am
#
# 0
#  <Multimedia omitido>
#
# -2
#  Jjaja
#
# 1
#  Tu duérmete a la hora que quieras
#
# 0
#  A las 17-18 esta aceptable
#
# 0
#  entonces le digo que si?
#
# 0
#  le voy a decir que si al jacob
#
# 1
#  Mañana él
#
# 0
#  a bueno de que hora a que hora
#
# 0
#  hoy yo
#
# 0
#  ayer nosotros
#
# 0
#  Pues en su clase jajaja
#
# 0
#  listogro
#
# 1
#  Por donde le hablan a ese wei?
#
# 0
#  Wa
#
# 0
#  por tumblr
#
# 0
#  A que hora quedo entonces?
#
# 0
#  No se
#
# 0
#  Ya viste los videos?
#
# 0
#  Unos
#
# 0
#  Esque mandaron un buen
#
# -1
#  Fueron 2 no?
#
# 0
#  <Multimedia omitido>
#
# -2
#  De cosas
#
# 0
#  Bueno
#
# 0
#  Esque uno dura 2 horas
#
# 0
#  Les queda a las 5-6 para que gabo asista?
#
# 0
#  <Multimedia omitido>
#
# -2
#  Ese es el poderoso
#
# 1
#  <Multimedia omitido>
#
# -2
#  <Multimedia omitido>
#
# -2
#  En el que dices
#
# 0
#  Sacate alv
#
# -1
#  Ya pa que vamos
#
# 0
#  <Multimedia omitido>
#
# -2
#  Y ves que si Jacobo lo explicará así no estarías diciendo
#
# 0
#  Ya va a empezar con sus mamadas este wey
# -1
#  <Multimedia omitido>
#
# -2
#  <Multimedia omitido>
#
# -2
#  Si pueden?
#
# 0
#  O abrimos a gabo y la hacemos a las 9, ustedes digan
#
# 0
#  <Multimedia omitido>
#
# -2
#  <Multimedia omitido>
#
# -2
#  A ls 7 y es un trato
#
# 0
#  Verga no
#
# -1
#  Si a las 18
#
# 0
#  <Multimedia omitido>
#
# -2
#  Está perro
#
# 1
#  Yo de ese llevo como 1 hora nada más
#
# -1
#  js, css
#
# 0
#  Cosas que neta no usamos normalmente
#
# 0
#  Eso es lo relax
#
# 1
#  <Multimedia omitido>
#
# -2
#  Jajajaja sí se mamaron un poco metiéndonos a un reto que no jajaja
#
# -1
#  Le apuesto todo a jacobo
#
# 0
#  Jajajajajaja
#
# 1
#  Pero creo que se arma si empezamos desde ahorita
#
# 1
#  Por eso quería que vieran el vídeo y ver qué cosas se pueden adelantar
#
# 1
#  Sí, lo acabo al ratito
#
# 1
#  Jacobo nos va a hacer paro ?
#
# 1
#  O que pex
#
# 0
#  Mañana le pedimos jajaja
#
# 0
#  Ah bueno
#
# 1
#  Avisan
#
# 0
#  que cosa
#
# 0
#  La reunión de hoy
#
# 0
#  Gabo solo puede de 5-6
#
# 0
#  Si no mañana
#
# 0
#  Acabando jacogod
#
# 1
#  11
#
# -2
#  Les late?
#
# 0
#  Tenemos clase
#
# 0
#  @5215543376293
#
# -2
#  Si puedes hoy?
#
# 0
#  no
#
# 0
#  voy a estar jalando en el servisio
#
# 0
#  A que hora sales?
#
# 0
#  Este pedo va ser tardado?
#
# -1
#  Osea de que max 30 minutos?
#
# 0
#  Esque podria conectarme a la 1 am
#
# 0
#  Pero si va a durar mucho no jalo jaja
#
# -1
#  O si no urge, el fin de semana si a la hora que digan
#
# 1
#  mmm a las 8 estoy available
#
# 1
#  .
#
# -2
#  Pues
#
# 0
#  <Multimedia omitido>
#
# -2
#  Yo la neta no he visto el de las 2 horas completo
#
# -1
#  si yo vi un cachooo el que dijiste que es importante
#
# 1
#  el de 2 si
#
# 0
#  Pues tampoco es todooo
#
# 0
#  Bueno o sea te explican cosas chidas
#
# 1
#  Llevo nada
#
# -1
#  15 min
#
# 0
#  Aunque con la primera parte como conceptual creo que la armas para decir a si ahuevo hacer esto y esto
#
# 1
#  Jajajajajaja
#
# 1
#  Esque si esta de hueva
#
# -1
#  Jaja
#
# 1
#  Las 2 horas
#
# 0
#  Osea si ocupas querer verlo
#
# 1
#  Jajajajajaja pues si, pa tener de fondo no está xd
#
# -1
#  Pero bueno entonces, les late que lo hagamos en la noche cuando la mayoría pueda, le damos viada a gabo que se vea más info y ya luego lo ponemos al tanto?
#
# 0
#  O la posponemos
#
# 0
#  Cómo gusten
#
# 0
#  <Multimedia omitido>
#
# -2
#  si yo si quiero en la noche
#
# 0
#  Va
#
# 0
#  Entonces onda 8-9 les funciona a todos?
#
# 1
#  Sí
#
# 0
#  Va
#
# 1
#  Le digo al profe jajajaja
#
# 0
#  Si quieren
#
# 0
#  A jl digo jajaja
#
# 0
#  La verdad como que lo veo perdidisimo
#
# -1
#  Sí jajajaja
#
# 1
#  No creo que le sepa
#
# -1
#  Pero... puede estar ahí
#
# 0
#  Ei
#
# 0
#  Tal vez ayuda en la organización
#
# 1
#  Pues si comentale para no abrirlo tan culero
#
# -1
#  Vas a preguntar @5215543376293? Jajaja
#
# 0
#  si pero no se cuando se el momento indicad
#
# 0
#  si quieren preguntwn ustedes
#
# 0
#  yo me espero al final
#
# 0
#  Jajajaajja no era al revés? Porque lo nuestro sí es muuuy independiente de la clase
#
# 0
#  Sí, siento que es mejor que le pregunten de una vez porque probablemente se extienda mucho
#
# 0
#  Y esa cosa pues ya es en dos semanas, no?
#
# 0
#  Ya le preguntamos, no?  O creen que veamos otro tema?
#
# 0
#  Va
#
# 1
#  Van
#
# 1
# //testnet.bit.country/nft/0x2543-00
#
# -2
# //testnet.bit.country/login
#
# -2
#  <Multimedia omitido>
#
# -2
#  Oigan, alguno ha podido instalar R en Jupyter?
#
# 0
#  O ha tenido algún problema con devtools en R?
#
# 0
#  yo no he tenido problema
#
# 0
#  Me puedes decir cómo hiciste la instalación?
#
# 0
#  Plsss
#
# 0
#  <Multimedia omitido>
#
# -2
#  puedo
#
# 1
#  no puedo
#
# -1
#  lo siento
#
# -1
#  no use devtools
#
# 0
#  hice
#
# 0
#  exactamente esto
#
# 1
#  para que salga en jupyterlab
#
# 1
#  sudo apt update
#
# -2
#  sudo apt upgrade
#
# -2
#  sudo apt install r-base r-base-dev
#
# -2
#  luego abri R escribiendo R
#
# -2
#  asi
#
# 0
#  R
#
# -2
#  y adentro de R puse
#
# 0
#  install.packages(c('repr', 'IRdisplay', 'IRkernel'), type = 'source')
#
# -2
#  escribi yes a todo
#
# 1
#  cuando se acabe la isntalacion
#
# 0
#  puse
#
# 0
# installspec()
#
# -2
#  y ya
#
# 0
#  <Multimedia omitido>
#
# -2
#  Ayyyyyyyyyyyyy
#
# -1
#  Sí pudeeeeeeeeeee
#
# 1
#  Muchísimas muchísimas gracias!!!!!!
#
# 1
#  Lo estuve intentando un buen y de verdad no salía
#
# -1
#  !!!!!!!!!
#
# 1
#  Muchas muchas gracias hirmapau!!!!
#
# 1
#  me pagan por googlear
#
# 1
#  Jacobo me puso a exponer lo del hackathon en la clase de MAC 🤣
#
# 1
#  Les dijo " Cámara ya ven como si sirve el metaverso y los NFT"
#
# 1
#  Estamos de acuerdo en que ese horario fuchi?
#
# -1
#  7-9, 11-13 y luego hasta las 18??
#
# 0
#  Si es asi?
#
# 0
#  Sí
#
# 0
#  Justo
#
# 1
#  Pregunta quien es el profe jaja
#
# 0
#  Jajajajajaja
#
# 1
#  Si es gustavo que se vaya alv
#
# -1
#  Uy, si la da en línea
#
# 0
#  Estaría bien
#
# 1
#  Igual no me gusta
#
# -1
#  Pero si la da así pues podría ser
#
# 0
#  Esque si esta muy pasado de burger
#
# -1
#  De por sí las 2 horas de hueco ahi
#
# 0
#  Ajá
#
# 0
#  !!!!
#
# 0
#  Ojalá ojalá no jaja
#
# -1
#  Pero hay que ver qué dicen los demás
#
# 0
#  nokiero
#
# -1
#  Sí está culeron por si trabajamos o algo
#
# -1
#  yo no puedo en ese horario
#
# -1
#  sera que lo podemos negociar?
#
# 0
# (
#
# -2
#  No sé
#
# 0
#  Yo creo que sí, por algo nos mandó mensaje
#
# 0
#  Si no, ni siquiera nos hubiera preguntado
#
# 0
#  Yo le diría "prefiero que todo sea en el mismo turno, o en todo caso en sábado como le hemos hecho"
#
# 1
#  Tal vez es más aviso que pregunta
#
# -1
#  No creo
#
# 0
#  O no quiero creerlo...
#
# -1
#  Jajaja
#
# 1
#  Es que si pudiera en otro horario no lo pondría en ese
#
# -1
#  Pero tal vez no ha considerado los sábados
#
# 0
#  jodwr no sera tu Shakespeare
#
# 1
#  Va, pues esperamos a Gus y si estamos de acuerdo, mandamos eso
#
# 1
#  @5215516576015 dime tu opinión de este mensaje
#
# 0
#  ya te vimos que andas aki
#
# 0
#  Jajajajaja
#
# 1
#  Él reaccionó aquí
#
# 0
#  Entonces ya tenemos su pov
#
# 0
#  <Multimedia omitido>
#
# -2
#  <Multimedia omitido>
#
# -2
#  Ah jajaja ok
#
# 1
#  jajajajajajajaj
#
# 1
#  aaaa si perdon perdon
#
# -1
#  feliz cumple pasatela bonito mi buen con tus seres amados <3
#
# 1
#  <Multimedia omitido>
#
# -2
#  HBD🥳
#
# 1
#  Muchas gracias amigos!!
#
# 1
# A ver si luego vamos por unas alitas del BarBQ y unos azulitos 👀
#
# 1
#  No, esas están muy ligeras, sak las bbq hot
#
# 1
#  Muchas felicidades
#
# 1
#  Sí jalo por el azulito, aunque nos detengan en la puerta
#
# 1
#  <Multimedia omitido>
#
# -2
#  Feliz cumple amigo
#
# 1
#  <Multimedia omitido>
#
# -2
#  entonces mañana hay mineria de datosv
#
# 0
#  ?
#
# -2
#  mando link?
#
# 0
#  <Multimedia omitido>
#
# -2
#  ni idea
#
# -1
#  oigan, no quieren pasar los pedazos de code para limpiar el dataset del aborto?
#
# 0
#  hubo una actualización el 15 de septiembre
#
# 0
#  ya tenemos un poquito más de datos
#
# 1
#  pensaba limpiarlo ahorita porque el último dataset que usamos tenía fallos jeje
#
# -1
#  Salaverga no me puedo dormir porque vergo de mensajes
#
# -1
#  Concuerdo
#
# 1
#  perdona a francisco por nacer un 11 de octubre
#
# -1
#  Por cierto, feliz cumple @5215516576015, espero haya estado mamalona la peda el sábado y hoy algo más relajado pero que se disfrute igual
#
# 1
#  JAJAJAJAJAJAJAJAJ
#
# 1
#  mean_value=int(df['nile'].mean())
#
# -2
# df['nile'].fillna(value=mean_value, inplace=True)
#
# -2
# mode_value=df['alc_o_municipio'].mode()
#
# -2
# df['alc_o_municipio'].fillna(value=mode_value[0], inplace=True)
#
# -2
#  Ammm
#
# 0
#  El mío son varias cosas
#
# 0
#  <Multimedia omitido>
#
# -2
#  Bueno, solo mandé la limpieza
#
# 0
#  Si quieren también la segmentación
#
# 0
#  <Multimedia omitido>
#
# -2
#  Tendrían que darme tiempo pa acomadorlo
#
# 0
#  <Multimedia omitido>
#
# -2
#  O mando mis 2 Notebooks que creo que use?
#
# 0
#  <Multimedia omitido>
#
# -2
#  Esta semana no creo que de clase de eso
#
# 0
#  yo no tengo problema, la neta, solo lo estaba haciendo porque recordé que teníamos que hacerlo jaja no porque lo quisiera para mañana
#
# 0
#  Va
#
# 1
#  mando link para mañana?
#
# 0
#  puede rolar pls
#
# 0
#  No que sepa
#
# 0
#  mariano es tu momento
#
# 1
#  Fuck, voy
#
# -1
#  Pues lo intenté
#
# -1
#  <Multimedia omitido>
#
# -2
#  JAJAJAJAJAJA
#
# 1
#  Ese temario no suena a lo mio la neta
#
# -1
#  A mí me agrada el temario
#
# 1
#  Jajajaja
#
# 1
#  Por favor elimina ese mensaje
#
# -1
#  Yo no se que es xd
#
# -1
#  Es que sí es muy muy market intelligence, tal cual es lo que ven en el trabajo
#
# 0
#  Es más para análisis
#
# 0
#  Pero qué otras propuestas podríamos dar?
#
# 0
#  <Multimedia omitido>
#
# -2
#  Lo que ven en el trabajo lo quiero ver en el trabajo
#
# 0
#  X2
#
# 0
#  JAJAJAJAJAJAJAJAJA
#
# 1
#  Jajajajajajajajajaj
#
# 1
#  Ya dense en su madre
#
# -1
#  <Multimedia omitido>
#
# -2
#  Jajajajaja no, pues sí no veo otra opción
#
# -1
#  Y creo sí nos sería util
#
# 1
#  Oscarin no propuso nada a tiempo al parecer
#
# -1
#  Tampoco le dijeron nada conciso
#
# -1
#  Se mamo gabo
#
# -1
#  Sí
#
# 0
#  Hablamos con el
#
# 0
#  En la semana de mac
#
# 0
#  Y le preguntamos si nos podía armar un temario de temas selectos
#
# 0
#  Y me pidió que le mandara las opciones
#
# 0
#  Sí
#
# 0
#  Sí
#
# 0
#  Sí
#
# -2
#  Jajaja
#
# 1
#  <Multimedia omitido>
#
# -2
#  <Multimedia omitido>
#
# -2
#  Pero neta, qué más podríamos proponer?
# 0
# Cómo qué se les antoja?
#
# 0
# Más modelos o qué?
#
# 0
#  Saben qué?
#
# 0
#  Podríamos preguntarle a alondra
#
# 1
#  Y decirle que nos dé sugerencias
#
# 0
#  Jajajajaajajaja
#
# 1
#  Alguien tiene su contacto?
#
# 0
#  <Multimedia omitido>
#
# -2
#  esta cagado el temario no?
#
# -1
#  Bueeeeeeeno hiram
#
# 1
#  Al chile está cutre
#
# -1
#  <Multimedia omitido>
#
# -2
#  Creo que el temario solo nos gustó a Cisco y a mí jaja
#
# 1
#  Sí
#
# 0
#  Qué es cutre?
#
# 0
#  Ammm
#
# 0
#  Culero abreviado
#
# -1
#  Cómo así todo sencillo y feo
#
# -1
#  Escueto?
#
# -1
#  Jajajajajajajajajaja
#
# 1
#  Entonces tenías razón
#
# 1
#  Lo chido sería tener el contacto de los de la generación anterior
#
# 1
#  Para preguntarles que tal estuvo
#
# 0
#  Oh
#
# 0
#  No están en discord?
#
# 0
#  Ese puedo conseguirlo
#
# 0
#  <Multimedia omitido>
#
# -2
#  No sé, ahí yo no estoy
#
# 0
#  Bueno su Facebook al menos
#
# 0
#  Y ya yo me basaría 100% en lo que ellos digan, ya llevan tiempo en el campo laboral
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_9444/3396488222.py in <module>
#       2 for indice,fila in df.iloc[inicio:].iterrows():
#       3     print(fila[0])
# ----> 4     sentimiento=int(input())
#       5     lista.append(sentimiento)
#
# ValueError: invalid literal for int() with base 10: ''

# %%
## 616
final=len(lista)
final
# Out:
# 583

# %%
df2=df.iloc[inicio:inicio+final].copy()

# %%
df2=df2.reset_index()

# %%
df2['sentimiento']=pd.Series(lista)

# %%
df2=df2.drop('index',axis=1)
df2
# Out:
#                                  0  sentimiento
# 0                 Mandan el link\n            0
# 1           <Multimedia omitido>\n           -2
# 2                 Si se conecto?\n            0
# 3                             Sí\n            0
# 4           <Multimedia omitido>\n           -2
# ..                             ...          ...
# 578         No están en discord?\n            0
# 579        Ese puedo conseguirlo\n            0
# 580         <Multimedia omitido>\n           -2
# 581       No sé, ahí yo no estoy\n            0
# 582   Bueno su Facebook al menos\n            0
#
# [583 rows x 2 columns]

# %%
df2.to_csv('final.csv',index=False,mode='a',index_label=False)
